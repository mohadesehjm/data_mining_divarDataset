# %%
pip install efficient-apriori
# Out:
# Collecting efficient-apriori
#   Downloading https://files.pythonhosted.org/packages/20/5b/a93622c9cc91fc4fb5c29bfeb8689ec4bf1e2b3d0f3579f34975051e6716/efficient_apriori-2.0.1-py3-none-any.whl
# Installing collected packages: efficient-apriori
# Successfully installed efficient-apriori-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyfpgrowth
# Out:
# Collecting pyfpgrowth
#   Using cached https://files.pythonhosted.org/packages/d2/4c/8b7cd90b4118ff0286d6584909b99e1ca5642bdc9072fa5a8dd361c864a0/pyfpgrowth-1.0.tar.gz
# Building wheels for collected packages: pyfpgrowth
#   Building wheel for pyfpgrowth (setup.py) ... done
#   Stored in directory: /Users/mohadeseh/Library/Caches/pip/wheels/3b/3f/0d/a04bb8b17887c1eca7d0f1a48d4aa0c09c96eb221ff7fa56c1
# Successfully built pyfpgrowth
# Installing collected packages: pyfpgrowth
# Successfully installed pyfpgrowth-1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyfpgrowth
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
from efficient_apriori import apriori

# %%
orders = pd.read_csv("/Users/mohadeseh/Documents/me/AllTaskOfLessons/session8/data_mining/FDM_Project_dataset-99-2/digikala_dataset/orders.csv")
orders
# Out:
#         ID_Order  ID_Customer  ID_Item    DateTime_CartFinalize  \
# 0        2714054       469662    21386  2015-10-15 08:50:56.000
# 1       11104039      3063877   248497  2018-02-11 00:29:26.000
# 2        4228130      3184893    50144  2016-06-14 00:30:08.000
# 3       22225624      6888562    70208  2018-09-03 14:37:19.000
# 4        4068771      2533490    67627  2016-05-21 11:51:02.000
# ...          ...          ...      ...                      ...
# 199995  12172771      4403268   445940  2018-04-03 12:07:01.000
# 199996   4425393      3745774   131645  2016-07-09 19:14:09.000
# 199997   6671889      4845514   215045  2017-03-08 23:47:06.000
# 199998   6315995      2541418   264021  2017-02-08 14:59:39.000
# 199999   7584127      1342585    89427  2017-06-17 10:08:06.000
#
#         Amount_Gross_Order city_name_fa  Quantity_item
# 0                 597982.0   محمود آباد            1.0
# 1                 980000.0       خرمدره            1.0
# 2                 229358.0         قرچک            1.0
# 3                  16514.0           قم            1.0
# 4                 133028.0        تهران            1.0
# ...                    ...          ...            ...
# 199995            344037.0        تهران            2.0
# 199996            600000.0       محمدیه            1.0
# 199997            450000.0       اصفهان            1.0
# 199998            193486.0        همدان            1.0
# 199999             55046.0   بندر انزلی            1.0
#
# [200000 rows x 7 columns]

# %%
df = pd.read_csv ("/Users/mohadeseh/Documents/me/session8/data_mining/FDM_Project_dataset-99-2/divar_dataset/divar_posts_dataset.csv") 
df
# Out:
#         Unnamed: 0  archive_by_user                   brand  \
# 0                0            False                     NaN
# 1                1            False                     NaN
# 2                2            False                     NaN
# 3                3            False                     NaN
# 4                4            False                     NaN
# ...            ...              ...                     ...
# 947630      947630             True                     NaN
# 947631      947631             True                     NaN
# 947632      947632             True  پراید صندوق‌دار::Pride
# 947633      947633             True                     NaN
# 947634      947634             True                     NaN
#
#                       cat1                       cat2  \
# 0             for-the-home  furniture-and-home-decore
# 1             for-the-home  furniture-and-home-decore
# 2                 vehicles                       cars
# 3             for-the-home  furniture-and-home-decore
# 4                 personal              baby-and-toys
# ...                    ...                        ...
# 947630        for-the-home        building-and-garden
# 947631  electronic-devices                audio-video
# 947632            vehicles                       cars
# 947633  electronic-devices              mobile-tablet
# 947634            personal        jewelry-and-watches
#
#                              cat3     city    created_at  \
# 0                   sofa-armchair   Tehran  Tuesday 07PM
# 1                antiques-and-art  Mashhad  Tuesday 07PM
# 2                           heavy  Mashhad  Tuesday 07PM
# 3                   sofa-armchair   Tehran  Tuesday 07PM
# 4                   personal-toys    Karaj  Tuesday 08PM
# ...                           ...      ...           ...
# 947630          stove-and-heating   Shiraz   Friday 07AM
# 947631           camera-camcoders   Tehran   Friday 02PM
# 947632                      light   Shiraz   Friday 04PM
# 947633  mobile-tablet-accessories  Mashhad   Friday 05PM
# 947634                    watches   Shiraz   Friday 05PM
#
#                                                      desc              id  \
# 0       کلاسیک و شیک و استثنایی\nچرم مالزی\nچوب راش\nف...  54761638662241
# 1       سلام,یک عدد گلدون نخل سه طبقه ی سالم دارم با پ...  42727631379133
# 2       سریال 43j$NUMبدون شکستگی سه حلقه لاستیک نو یک ...  63194439667302
# 3       مبل راحتی هفت نفره شامل سه نفره یک عدد دونفره ...  19133025491169
# 4       شارژی کنترلی سویچ حمل تا 35 کیلو صندلی برای دو...  58998998335444
# ...                                                   ...             ...
# 947630  دوعدد یکی یک متری و دیگری 1.4 متری موجود است\n...  16127180351093
# 947631  دوربین هندی کم کنون مدل لگریا fs36\n\nعکاسی و ...  29805298491725
# 947632  پراید دوگانه کارخانه میباشد و کم کارکرد.روکش ....  55514317985619
# 947633  مونو پد یانگ تد همراه با پایه و اینه عقبش\nواس...  65938921533442
# 947634                           جواب فقط تماس و. وات ساپ  18312774360687
#
#         image_count  mileage platform     price  \
# 0                 5      NaN   mobile   3850000
# 1                 1      NaN   mobile     30000
# 2                 4      NaN   mobile        -1
# 3                 4      NaN   mobile    600000
# 4                 2      NaN   mobile    450000
# ...             ...      ...      ...       ...
# 947630            1      NaN      web    180000
# 947631            1      NaN   mobile    350000
# 947632            3  43000.0   mobile  17400000
# 947633            1      NaN   mobile     40000
# 947634            1      NaN   mobile     25000
#
#                                     title type  year
# 0             ست مبلمان و نهارخوری ٩ نفره  NaN   NaN
# 1                        گلدون مصنوعی نخل  NaN   NaN
# 2                     لودر کاتر پیلار 950  NaN   NaN
# 3       مبل راحتی هفت نفره بامیز جلو مبلی  NaN   NaN
# 4                             ماشین شارژی  NaN   NaN
# ...                                   ...  ...   ...
# 947630               رادیاتور پنلی نو ترک  NaN   NaN
# 947631               دوربین هندی کم  کنون  NaN   NaN
# 947632         پراید دوگانه کارخانه مدل93  NaN  1393
# 947633      مونوپد یانگ تد خیلی تمیز و نو  NaN   NaN
# 947634                          ساعت مارک  NaN   NaN
#
# [947635 rows x 17 columns]

# %%
df.tail()
# Out:
#         Unnamed: 0  archive_by_user                   brand  \
# 947630      947630             True                     NaN
# 947631      947631             True                     NaN
# 947632      947632             True  پراید صندوق‌دار::Pride
# 947633      947633             True                     NaN
# 947634      947634             True                     NaN
#
#                       cat1                 cat2                       cat3  \
# 947630        for-the-home  building-and-garden          stove-and-heating
# 947631  electronic-devices          audio-video           camera-camcoders
# 947632            vehicles                 cars                      light
# 947633  electronic-devices        mobile-tablet  mobile-tablet-accessories
# 947634            personal  jewelry-and-watches                    watches
#
#            city   created_at  \
# 947630   Shiraz  Friday 07AM
# 947631   Tehran  Friday 02PM
# 947632   Shiraz  Friday 04PM
# 947633  Mashhad  Friday 05PM
# 947634   Shiraz  Friday 05PM
#
#                                                      desc              id  \
# 947630  دوعدد یکی یک متری و دیگری 1.4 متری موجود است\n...  16127180351093
# 947631  دوربین هندی کم کنون مدل لگریا fs36\n\nعکاسی و ...  29805298491725
# 947632  پراید دوگانه کارخانه میباشد و کم کارکرد.روکش ....  55514317985619
# 947633  مونو پد یانگ تد همراه با پایه و اینه عقبش\nواس...  65938921533442
# 947634                           جواب فقط تماس و. وات ساپ  18312774360687
#
#         image_count  mileage platform     price  \
# 947630            1      NaN      web    180000
# 947631            1      NaN   mobile    350000
# 947632            3  43000.0   mobile  17400000
# 947633            1      NaN   mobile     40000
# 947634            1      NaN   mobile     25000
#
#                                 title type  year
# 947630           رادیاتور پنلی نو ترک  NaN   NaN
# 947631           دوربین هندی کم  کنون  NaN   NaN
# 947632     پراید دوگانه کارخانه مدل93  NaN  1393
# 947633  مونوپد یانگ تد خیلی تمیز و نو  NaN   NaN
# 947634                      ساعت مارک  NaN   NaN

# %%
df[['day','houre']] = df.created_at.str.split(" ",expand=True,)
del df["created_at"]
df
# Out:
#         Unnamed: 0  archive_by_user                   brand  \
# 0                0            False                     NaN
# 1                1            False                     NaN
# 2                2            False                     NaN
# 3                3            False                     NaN
# 4                4            False                     NaN
# ...            ...              ...                     ...
# 947630      947630             True                     NaN
# 947631      947631             True                     NaN
# 947632      947632             True  پراید صندوق‌دار::Pride
# 947633      947633             True                     NaN
# 947634      947634             True                     NaN
#
#                       cat1                       cat2  \
# 0             for-the-home  furniture-and-home-decore
# 1             for-the-home  furniture-and-home-decore
# 2                 vehicles                       cars
# 3             for-the-home  furniture-and-home-decore
# 4                 personal              baby-and-toys
# ...                    ...                        ...
# 947630        for-the-home        building-and-garden
# 947631  electronic-devices                audio-video
# 947632            vehicles                       cars
# 947633  electronic-devices              mobile-tablet
# 947634            personal        jewelry-and-watches
#
#                              cat3     city  \
# 0                   sofa-armchair   Tehran
# 1                antiques-and-art  Mashhad
# 2                           heavy  Mashhad
# 3                   sofa-armchair   Tehran
# 4                   personal-toys    Karaj
# ...                           ...      ...
# 947630          stove-and-heating   Shiraz
# 947631           camera-camcoders   Tehran
# 947632                      light   Shiraz
# 947633  mobile-tablet-accessories  Mashhad
# 947634                    watches   Shiraz
#
#                                                      desc              id  \
# 0       کلاسیک و شیک و استثنایی\nچرم مالزی\nچوب راش\nف...  54761638662241
# 1       سلام,یک عدد گلدون نخل سه طبقه ی سالم دارم با پ...  42727631379133
# 2       سریال 43j$NUMبدون شکستگی سه حلقه لاستیک نو یک ...  63194439667302
# 3       مبل راحتی هفت نفره شامل سه نفره یک عدد دونفره ...  19133025491169
# 4       شارژی کنترلی سویچ حمل تا 35 کیلو صندلی برای دو...  58998998335444
# ...                                                   ...             ...
# 947630  دوعدد یکی یک متری و دیگری 1.4 متری موجود است\n...  16127180351093
# 947631  دوربین هندی کم کنون مدل لگریا fs36\n\nعکاسی و ...  29805298491725
# 947632  پراید دوگانه کارخانه میباشد و کم کارکرد.روکش ....  55514317985619
# 947633  مونو پد یانگ تد همراه با پایه و اینه عقبش\nواس...  65938921533442
# 947634                           جواب فقط تماس و. وات ساپ  18312774360687
#
#         image_count  mileage platform     price  \
# 0                 5      NaN   mobile   3850000
# 1                 1      NaN   mobile     30000
# 2                 4      NaN   mobile        -1
# 3                 4      NaN   mobile    600000
# 4                 2      NaN   mobile    450000
# ...             ...      ...      ...       ...
# 947630            1      NaN      web    180000
# 947631            1      NaN   mobile    350000
# 947632            3  43000.0   mobile  17400000
# 947633            1      NaN   mobile     40000
# 947634            1      NaN   mobile     25000
#
#                                     title type  year      day houre
# 0             ست مبلمان و نهارخوری ٩ نفره  NaN   NaN  Tuesday  07PM
# 1                        گلدون مصنوعی نخل  NaN   NaN  Tuesday  07PM
# 2                     لودر کاتر پیلار 950  NaN   NaN  Tuesday  07PM
# 3       مبل راحتی هفت نفره بامیز جلو مبلی  NaN   NaN  Tuesday  07PM
# 4                             ماشین شارژی  NaN   NaN  Tuesday  08PM
# ...                                   ...  ...   ...      ...   ...
# 947630               رادیاتور پنلی نو ترک  NaN   NaN   Friday  07AM
# 947631               دوربین هندی کم  کنون  NaN   NaN   Friday  02PM
# 947632         پراید دوگانه کارخانه مدل93  NaN  1393   Friday  04PM
# 947633      مونوپد یانگ تد خیلی تمیز و نو  NaN   NaN   Friday  05PM
# 947634                          ساعت مارک  NaN   NaN   Friday  05PM
#
# [947635 rows x 18 columns]

# %% [markdown]
# # •	استخراج الگوهای قرار دادن پست فروش  محصولات در شهرهای مختلف در دیتاست دیوار

# %%
groupby_cities = df.groupby(by = ['city'])
transactions_of_cities = []
cities =[]
for group, pdf in groupby_cities:
    transactions_of_cities.append(pdf['cat1'].values.tolist())
    cities.append(pdf['city'].tolist()[0])
    
print("number of cities:", len(transactions_of_cities))
transactions_of_cities
# Out:
# number of cities: 9
# [['vehicles',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'leisure-hobbies',
#   'personal',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'personal',
#   'vehicles',
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'personal',
#   'personal',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'leisure-hobbies',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'leisure-hobbies',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'businesses',
#   'for-the-home',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'leisure-hobbies',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'businesses',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'electronic-devices',
#   'leisure-hobbies',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'leisure-hobbies',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'personal',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'personal',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'personal',
#   'leisure-hobbies',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'leisure-hobbies',
#   'personal',
#   'for-the-home',
#   'businesses',
#   'leisure-hobbies',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'leisure-hobbies',
#   'vehicles',
#   'businesses',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'leisure-hobbies',
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'leisure-hobbies',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'personal',
#   'electronic-devices',
#   'electronic-devices',
#   'businesses',
#   'electronic-devices',
#   'personal',
#   'electronic-devices',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'personal',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'businesses',
#   'vehicles',
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'electronic-devices',
#   'electronic-devices',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'businesses',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'electronic-devices',
#   'leisure-hobbies',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'personal',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'businesses',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'personal',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'personal',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'leisure-hobbies',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'leisure-hobbies',
#   'electronic-devices',
#   'personal',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'personal',
#   'vehicles',
#   'personal',
#   'businesses',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'businesses',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'businesses',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'leisure-hobbies',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'leisure-hobbies',
#   'personal',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'businesses',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'leisure-hobbies',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'businesses',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'leisure-hobbies',
#   'vehicles',
#   'vehicles',
#   'businesses',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'leisure-hobbies',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'leisure-hobbies',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'electronic-devices',
#   'leisure-hobbies',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'businesses',
#   'electronic-devices',
#   'personal',
#   'leisure-hobbies',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'vehicles',
#   'businesses',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'personal',
#   'vehicles',
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'leisure-hobbies',
#   'electronic-devices',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'personal',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'leisure-hobbies',
#   'personal',
#   'vehicles',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'leisure-hobbies',
#   'vehicles',
#   'leisure-hobbies',
#   'electronic-devices',
#   'businesses',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'businesses',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'vehicles',
#   'leisure-hobbies',
#   'electronic-devices',
#   'personal',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'businesses',
#   'businesses',
#   'vehicles',
#   'leisure-hobbies',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'businesses',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'businesses',
#   'businesses',
#   'vehicles',
#   'leisure-hobbies',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'businesses',
#   'electronic-devices',
#   'vehicles',
#   'leisure-hobbies',
#   'electronic-devices',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'electronic-devices',
#   'businesses',
#   'businesses',
#   'for-the-home',
#   'personal',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'businesses',
#   'for-the-home',
#   'leisure-hobbies',
#   'personal',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'personal',
#   'electronic-devices',
#   'electronic-devices',
#   'electronic-devices',
#   'personal',
#   'for-the-home',
#   'businesses',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'personal',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'leisure-hobbies',
#   'leisure-hobbies',
#   'electronic-devices',
#   'leisure-hobbies',
#   'personal',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'vehicles',
#   'leisure-hobbies',
#   'for-the-home',
#   'leisure-hobbies',
#   'leisure-hobbies',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'leisure-hobbies',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'leisure-hobbies',
#   'businesses',
#   'electronic-devices',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'electronic-devices',
#   'businesses',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'businesses',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'leisure-hobbies',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'leisure-hobbies',
#   'vehicles',
#   'electronic-devices',
#   'electronic-devices',
#   'vehicles',
#   'leisure-hobbies',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'personal',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'personal',
#   'leisure-hobbies',
#   'personal',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'electronic-devices',
#   'electronic-devices',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'businesses',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'leisure-hobbies',
#   'electronic-devices',
#   'personal',
#   'electronic-devices',
#   'leisure-hobbies',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'leisure-hobbies',
#   'vehicles',
#   'personal',
#   'businesses',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'leisure-hobbies',
#   'for-the-home',
#   'personal',
#   'personal',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'leisure-hobbies',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'businesses',
#   'leisure-hobbies',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'personal',
#   'for-the-home',
#   'personal',
#   'personal',
#   'leisure-hobbies',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'businesses',
#   'for-the-home',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'businesses',
#   'vehicles',
#   'leisure-hobbies',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'businesses',
#   'leisure-hobbies',
#   'personal',
#   'businesses',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'leisure-hobbies',
#   'personal',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'leisure-hobbies',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'electronic-devices',
#   'electronic-devices',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'leisure-hobbies',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'leisure-hobbies',
#   'leisure-hobbies',
#   'vehicles',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'electronic-devices',
#   'personal',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'electronic-devices',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'electronic-devices',
#   'electronic-devices',
#   'personal',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'businesses',
#   'personal',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'electronic-devices',
#   ...],
#  ['electronic-devices',
#   'businesses',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'businesses',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'businesses',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'businesses',
#   'for-the-home',
#   'leisure-hobbies',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'businesses',
#   'personal',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'businesses',
#   'businesses',
#   'for-the-home',
#   'for-the-home',
#   'businesses',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'businesses',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'businesses',
#   'vehicles',
#   'leisure-hobbies',
#   'electronic-devices',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'leisure-hobbies',
#   'vehicles',
#   'vehicles',
#   'businesses',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'businesses',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'personal',
#   'leisure-hobbies',
#   'for-the-home',
#   'electronic-devices',
#   'electronic-devices',
#   'leisure-hobbies',
#   'for-the-home',
#   'leisure-hobbies',
#   'leisure-hobbies',
#   'electronic-devices',
#   'vehicles',
#   'leisure-hobbies',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'leisure-hobbies',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'electronic-devices',
#   'leisure-hobbies',
#   'for-the-home',
#   'businesses',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'personal',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'leisure-hobbies',
#   'businesses',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'businesses',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'businesses',
#   'electronic-devices',
#   'leisure-hobbies',
#   'leisure-hobbies',
#   'personal',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'personal',
#   'personal',
#   'electronic-devices',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'businesses',
#   'personal',
#   'for-the-home',
#   'personal',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'leisure-hobbies',
#   'businesses',
#   'electronic-devices',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'electronic-devices',
#   'leisure-hobbies',
#   'vehicles',
#   'businesses',
#   'leisure-hobbies',
#   'businesses',
#   'vehicles',
#   'personal',
#   'personal',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'leisure-hobbies',
#   'vehicles',
#   'personal',
#   'vehicles',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'electronic-devices',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'leisure-hobbies',
#   'businesses',
#   'personal',
#   'electronic-devices',
#   'businesses',
#   'vehicles',
#   'for-the-home',
#   'businesses',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'leisure-hobbies',
#   'personal',
#   'for-the-home',
#   'leisure-hobbies',
#   'electronic-devices',
#   'personal',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'personal',
#   'personal',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'businesses',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'leisure-hobbies',
#   'vehicles',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'leisure-hobbies',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'businesses',
#   'vehicles',
#   'leisure-hobbies',
#   'leisure-hobbies',
#   'electronic-devices',
#   'businesses',
#   'personal',
#   'electronic-devices',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'leisure-hobbies',
#   'for-the-home',
#   'leisure-hobbies',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'personal',
#   'electronic-devices',
#   'for-the-home',
#   'leisure-hobbies',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'leisure-hobbies',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'leisure-hobbies',
#   'businesses',
#   'leisure-hobbies',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'businesses',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'leisure-hobbies',
#   'personal',
#   'personal',
#   'leisure-hobbies',
#   'vehicles',
#   'personal',
#   'vehicles',
#   'leisure-hobbies',
#   'leisure-hobbies',
#   'for-the-home',
#   'leisure-hobbies',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'leisure-hobbies',
#   'personal',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'leisure-hobbies',
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'businesses',
#   'vehicles',
#   'personal',
#   'leisure-hobbies',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'leisure-hobbies',
#   'businesses',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'businesses',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'leisure-hobbies',
#   'vehicles',
#   'for-the-home',
#   'businesses',
#   'for-the-home',
#   'businesses',
#   'electronic-devices',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'leisure-hobbies',
#   'leisure-hobbies',
#   'businesses',
#   'electronic-devices',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'electronic-devices',
#   'electronic-devices',
#   'vehicles',
#   'personal',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'businesses',
#   'for-the-home',
#   'leisure-hobbies',
#   'leisure-hobbies',
#   'vehicles',
#   'businesses',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'businesses',
#   'for-the-home',
#   'for-the-home',
#   'businesses',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'personal',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'businesses',
#   'leisure-hobbies',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'businesses',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'electronic-devices',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'leisure-hobbies',
#   'leisure-hobbies',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'businesses',
#   'vehicles',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'businesses',
#   'businesses',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'leisure-hobbies',
#   'for-the-home',
#   'businesses',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'businesses',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'electronic-devices',
#   'leisure-hobbies',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'businesses',
#   'businesses',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'leisure-hobbies',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'businesses',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'leisure-hobbies',
#   'electronic-devices',
#   'vehicles',
#   'personal',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'businesses',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'leisure-hobbies',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'businesses',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'electronic-devices',
#   'businesses',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'personal',
#   'for-the-home',
#   'electronic-devices',
#   'electronic-devices',
#   'vehicles',
#   'leisure-hobbies',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'leisure-hobbies',
#   'personal',
#   'for-the-home',
#   'electronic-devices',
#   'leisure-hobbies',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'businesses',
#   'vehicles',
#   'leisure-hobbies',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'leisure-hobbies',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'vehicles',
#   'personal',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'leisure-hobbies',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'personal',
#   'personal',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'for-the-home',
#   'leisure-hobbies',
#   'leisure-hobbies',
#   'vehicles',
#   'leisure-hobbies',
#   'personal',
#   'electronic-devices',
#   'leisure-hobbies',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'personal',
#   'vehicles',
#   'businesses',
#   'vehicles',
#   'leisure-hobbies',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'electronic-devices',
#   'businesses',
#   'vehicles',
#   'leisure-hobbies',
#   'vehicles',
#   'leisure-hobbies',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'businesses',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'electronic-devices',
#   'leisure-hobbies',
#   'personal',
#   'businesses',
#   'electronic-devices',
#   'personal',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'personal',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'leisure-hobbies',
#   'electronic-devices',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'leisure-hobbies',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'personal',
#   'vehicles',
#   'personal',
#   'businesses',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'leisure-hobbies',
#   'businesses',
#   'personal',
#   'personal',
#   'leisure-hobbies',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'leisure-hobbies',
#   'leisure-hobbies',
#   'leisure-hobbies',
#   'vehicles',
#   'vehicles',
#   'leisure-hobbies',
#   'for-the-home',
#   'electronic-devices',
#   'leisure-hobbies',
#   'for-the-home',
#   'for-the-home',
#   'businesses',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'personal',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'businesses',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'businesses',
#   'businesses',
#   'leisure-hobbies',
#   'vehicles',
#   'for-the-home',
#   'businesses',
#   'businesses',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'electronic-devices',
#   'businesses',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'personal',
#   'businesses',
#   'leisure-hobbies',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'vehicles',
#   'businesses',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'leisure-hobbies',
#   'businesses',
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'electronic-devices',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'leisure-hobbies',
#   'personal',
#   'electronic-devices',
#   'for-the-home',
#   'leisure-hobbies',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'leisure-hobbies',
#   'electronic-devices',
#   'electronic-devices',
#   'businesses',
#   'for-the-home',
#   'electronic-devices',
#   'personal',
#   'electronic-devices',
#   'personal',
#   'for-the-home',
#   'electronic-devices',
#   'businesses',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'leisure-hobbies',
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'leisure-hobbies',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'personal',
#   'electronic-devices',
#   'vehicles',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'leisure-hobbies',
#   'personal',
#   'vehicles',
#   'leisure-hobbies',
#   'leisure-hobbies',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'leisure-hobbies',
#   'leisure-hobbies',
#   'personal',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'personal',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'vehicles',
#   'leisure-hobbies',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'businesses',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'businesses',
#   'personal',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'leisure-hobbies',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'electronic-devices',
#   'electronic-devices',
#   'electronic-devices',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'businesses',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'leisure-hobbies',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'leisure-hobbies',
#   'electronic-devices',
#   'electronic-devices',
#   ...],
#  ['personal',
#   'personal',
#   'vehicles',
#   'electronic-devices',
#   'personal',
#   'leisure-hobbies',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'businesses',
#   'vehicles',
#   'businesses',
#   'for-the-home',
#   'electronic-devices',
#   'personal',
#   'electronic-devices',
#   'personal',
#   'personal',
#   'personal',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'businesses',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'businesses',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'personal',
#   'businesses',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'businesses',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'businesses',
#   'vehicles',
#   'electronic-devices',
#   'electronic-devices',
#   'leisure-hobbies',
#   'vehicles',
#   'vehicles',
#   'personal',
#   'vehicles',
#   'personal',
#   'personal',
#   'for-the-home',
#   'leisure-hobbies',
#   'businesses',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'electronic-devices',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'vehicles',
#   'vehicles',
#   'personal',
#   'leisure-hobbies',
#   'for-the-home',
#   'businesses',
#   'vehicles',
#   'electronic-devices',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'personal',
#   'leisure-hobbies',
#   'vehicles',
#   'electronic-devices',
#   'leisure-hobbies',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'personal',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'businesses',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'businesses',
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'personal',
#   'vehicles',
#   'electronic-devices',
#   'personal',
#   'vehicles',
#   'vehicles',
#   'businesses',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'electronic-devices',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'leisure-hobbies',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'electronic-devices',
#   'businesses',
#   'for-the-home',
#   'businesses',
#   'electronic-devices',
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'leisure-hobbies',
#   'personal',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'electronic-devices',
#   'electronic-devices',
#   'electronic-devices',
#   'personal',
#   'personal',
#   'personal',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'businesses',
#   'businesses',
#   'for-the-home',
#   'personal',
#   'businesses',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'businesses',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'businesses',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'personal',
#   'for-the-home',
#   'personal',
#   'personal',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'personal',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'leisure-hobbies',
#   'businesses',
#   'personal',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'leisure-hobbies',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'leisure-hobbies',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'leisure-hobbies',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'businesses',
#   'personal',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'vehicles',
#   'leisure-hobbies',
#   'vehicles',
#   'vehicles',
#   'personal',
#   'leisure-hobbies',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'leisure-hobbies',
#   'leisure-hobbies',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'businesses',
#   'for-the-home',
#   'businesses',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'leisure-hobbies',
#   'vehicles',
#   'for-the-home',
#   'businesses',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'leisure-hobbies',
#   'personal',
#   'personal',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'businesses',
#   'electronic-devices',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'vehicles',
#   'leisure-hobbies',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'leisure-hobbies',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'businesses',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'personal',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'for-the-home',
#   'businesses',
#   'businesses',
#   'vehicles',
#   'for-the-home',
#   'businesses',
#   'businesses',
#   'businesses',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'leisure-hobbies',
#   'for-the-home',
#   'for-the-home',
#   'businesses',
#   'for-the-home',
#   'personal',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'leisure-hobbies',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'personal',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'electronic-devices',
#   'leisure-hobbies',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'businesses',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'leisure-hobbies',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'businesses',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'leisure-hobbies',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'personal',
#   'for-the-home',
#   'electronic-devices',
#   'businesses',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'leisure-hobbies',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'vehicles',
#   'vehicles',
#   'personal',
#   'personal',
#   'personal',
#   'electronic-devices',
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'businesses',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'electronic-devices',
#   'vehicles',
#   'businesses',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'leisure-hobbies',
#   'electronic-devices',
#   'personal',
#   'businesses',
#   'leisure-hobbies',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'businesses',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
# ...
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'electronic-devices',
#   'vehicles',
#   'businesses',
#   'businesses',
#   'leisure-hobbies',
#   'personal',
#   'personal',
#   'businesses',
#   'personal',
#   'for-the-home',
#   'electronic-devices',
#   'leisure-hobbies',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'personal',
#   'personal',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'electronic-devices',
#   'personal',
#   'leisure-hobbies',
#   'businesses',
#   'vehicles',
#   'businesses',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'electronic-devices',
#   'leisure-hobbies',
#   'electronic-devices',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'leisure-hobbies',
#   'personal',
#   'personal',
#   'businesses',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'businesses',
#   'electronic-devices',
#   'for-the-home',
#   'businesses',
#   'electronic-devices',
#   'personal',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'businesses',
#   'businesses',
#   'personal',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'electronic-devices',
#   'vehicles',
#   'businesses',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'personal',
#   'leisure-hobbies',
#   'vehicles',
#   'personal',
#   'electronic-devices',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'businesses',
#   'vehicles',
#   'businesses',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'personal',
#   'leisure-hobbies',
#   'leisure-hobbies',
#   'electronic-devices',
#   'leisure-hobbies',
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'vehicles',
#   'personal',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'leisure-hobbies',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'leisure-hobbies',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'personal',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'personal',
#   'personal',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'personal',
#   'personal',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'vehicles',
#   'businesses',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'electronic-devices',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'leisure-hobbies',
#   'personal',
#   'vehicles',
#   'personal',
#   'leisure-hobbies',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'businesses',
#   'personal',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'electronic-devices',
#   'businesses',
#   'personal',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'businesses',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'personal',
#   'for-the-home',
#   'businesses',
#   'personal',
#   'vehicles',
#   'personal',
#   'electronic-devices',
#   'leisure-hobbies',
#   'leisure-hobbies',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'for-the-home',
#   'leisure-hobbies',
#   'vehicles',
#   'personal',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'leisure-hobbies',
#   'personal',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'electronic-devices',
#   'businesses',
#   'for-the-home',
#   'leisure-hobbies',
#   'personal',
#   'personal',
#   'personal',
#   'leisure-hobbies',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'leisure-hobbies',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'personal',
#   'electronic-devices',
#   'businesses',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'businesses',
#   'for-the-home',
#   'businesses',
#   'for-the-home',
#   'vehicles',
#   'businesses',
#   'businesses',
#   'personal',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'businesses',
#   'electronic-devices',
#   'electronic-devices',
#   'leisure-hobbies',
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'leisure-hobbies',
#   'personal',
#   'personal',
#   'vehicles',
#   'businesses',
#   'personal',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'vehicles',
#   'leisure-hobbies',
#   'personal',
#   'personal',
#   'businesses',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'personal',
#   'personal',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'personal',
#   'vehicles',
#   'leisure-hobbies',
#   'vehicles',
#   'vehicles',
#   'businesses',
#   'vehicles',
#   'businesses',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'electronic-devices',
#   'leisure-hobbies',
#   'vehicles',
#   'vehicles',
#   'personal',
#   'businesses',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'businesses',
#   'for-the-home',
#   'businesses',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'electronic-devices',
#   'personal',
#   'businesses',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'electronic-devices',
#   'electronic-devices',
#   'personal',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'personal',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'businesses',
#   'businesses',
#   'leisure-hobbies',
#   'for-the-home',
#   'businesses',
#   'businesses',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'personal',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'electronic-devices',
#   'vehicles',
#   'personal',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'businesses',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'personal',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'businesses',
#   'electronic-devices',
#   'leisure-hobbies',
#   'leisure-hobbies',
#   'businesses',
#   'businesses',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'leisure-hobbies',
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'personal',
#   'leisure-hobbies',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'leisure-hobbies',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'leisure-hobbies',
#   'electronic-devices',
#   'leisure-hobbies',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'businesses',
#   'electronic-devices',
#   'for-the-home',
#   'leisure-hobbies',
#   'leisure-hobbies',
#   'personal',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'electronic-devices',
#   'personal',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'personal',
#   'electronic-devices',
#   'electronic-devices',
#   'leisure-hobbies',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'businesses',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'personal',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'vehicles',
#   'businesses',
#   'personal',
#   'electronic-devices',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'personal',
#   'electronic-devices',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'personal',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'personal',
#   'for-the-home',
#   'businesses',
#   'businesses',
#   'for-the-home',
#   'electronic-devices',
#   'leisure-hobbies',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'leisure-hobbies',
#   'businesses',
#   'electronic-devices',
#   'businesses',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'leisure-hobbies',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'electronic-devices',
#   'businesses',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'businesses',
#   'businesses',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'businesses',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'electronic-devices',
#   'personal',
#   'leisure-hobbies',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'businesses',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'vehicles',
#   'businesses',
#   'leisure-hobbies',
#   'leisure-hobbies',
#   'personal',
#   'for-the-home',
#   'personal',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'businesses',
#   'vehicles',
#   'businesses',
#   'electronic-devices',
#   'vehicles',
#   'personal',
#   'vehicles',
#   'personal',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'leisure-hobbies',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'personal',
#   'personal',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'for-the-home',
#   'electronic-devices',
#   'electronic-devices',
#   'vehicles',
#   'vehicles',
#   'businesses',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'for-the-home',
#   'businesses',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'leisure-hobbies',
#   'vehicles',
#   'personal',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'personal',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'businesses',
#   'electronic-devices',
#   'personal',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'leisure-hobbies',
#   'personal',
#   'electronic-devices',
#   'for-the-home',
#   'personal',
#   'personal',
#   'vehicles',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'businesses',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'leisure-hobbies',
#   'electronic-devices',
#   'personal',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'leisure-hobbies',
#   'personal',
#   'for-the-home',
#   'businesses',
#   'vehicles',
#   'vehicles',
#   'leisure-hobbies',
#   'vehicles',
#   'for-the-home',
#   'electronic-devices',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   'electronic-devices',
#   'personal',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'businesses',
#   'for-the-home',
#   'vehicles',
#   'electronic-devices',
#   'electronic-devices',
#   'leisure-hobbies',
#   'vehicles',
#   'vehicles',
#   'for-the-home',
#   'personal',
#   'personal',
#   'for-the-home',
#   'personal',
#   'for-the-home',
#   'for-the-home',
#   'vehicles',
#   'personal',
#   'personal',
#   'businesses',
#   'electronic-devices',
#   'personal',
#   'vehicles',
#   'personal',
#   'electronic-devices',
#   'personal',
#   'for-the-home',
#   'leisure-hobbies',
#   'for-the-home',
#   'vehicles',
#   'for-the-home',
#   'vehicles',
#   'vehicles',
#   'electronic-devices',
#   'electronic-devices',
#   'for-the-home',
#   'for-the-home',
#   'for-the-home',
#   ...]]

# %%
ct = []
for ele in transactions_of_cities:
    ct.append(len(ele))

ctt = ct.copy()
ctt.sort()
top_ten_cities = []
for i in range(9):
    top_ten_cities.append(cities[ct.index(ctt[i])])
    print(ctt[i])
    print(top_ten_cities[-1])
    print()
# Out:
# 23130
# Kermanshah
#
# 32002
# Qom
#
# 34014
# Tabriz
#
# 47163
# Ahvaz
#
# 61803
# Isfahan
#
# 83736
# Karaj
#
# 83970
# Shiraz
#
# 138879
# Mashhad
#
# 442938
# Tehran

# %%
transactionsCities = []
for tr in transactions_of_cities:
    if len(tr) > 2:
        transactionsCities.append(tr)
    else:
        print("here")
print("total transactions      : ", len(transactions_of_cities))
print("cleaning for finding FP : ", len(transactionsCities))
# Out:
# total transactions      :  9
# cleaning for finding FP :  9

# %%
df['cat1'].isnull().sum()
# Out:
# 0

# %%
itemsets, rules = apriori(transactionsCities,min_support=0.9, min_confidence=0.9)
itemsets
# Out:
# {1: {('personal',): 9,
#   ('businesses',): 9,
#   ('leisure-hobbies',): 9,
#   ('for-the-home',): 9,
#   ('vehicles',): 9,
#   ('electronic-devices',): 9},
#  2: {('businesses', 'electronic-devices'): 9,
#   ('businesses', 'for-the-home'): 9,
#   ('businesses', 'leisure-hobbies'): 9,
#   ('businesses', 'personal'): 9,
#   ('businesses', 'vehicles'): 9,
#   ('electronic-devices', 'for-the-home'): 9,
#   ('electronic-devices', 'leisure-hobbies'): 9,
#   ('electronic-devices', 'personal'): 9,
#   ('electronic-devices', 'vehicles'): 9,
#   ('for-the-home', 'leisure-hobbies'): 9,
#   ('for-the-home', 'personal'): 9,
#   ('for-the-home', 'vehicles'): 9,
#   ('leisure-hobbies', 'personal'): 9,
#   ('leisure-hobbies', 'vehicles'): 9,
#   ('personal', 'vehicles'): 9},
#  3: {('businesses', 'electronic-devices', 'for-the-home'): 9,
#   ('businesses', 'electronic-devices', 'leisure-hobbies'): 9,
#   ('businesses', 'electronic-devices', 'personal'): 9,
#   ('businesses', 'electronic-devices', 'vehicles'): 9,
#   ('businesses', 'for-the-home', 'leisure-hobbies'): 9,
#   ('businesses', 'for-the-home', 'personal'): 9,
#   ('businesses', 'for-the-home', 'vehicles'): 9,
#   ('businesses', 'leisure-hobbies', 'personal'): 9,
#   ('businesses', 'leisure-hobbies', 'vehicles'): 9,
#   ('businesses', 'personal', 'vehicles'): 9,
#   ('electronic-devices', 'for-the-home', 'leisure-hobbies'): 9,
#   ('electronic-devices', 'for-the-home', 'personal'): 9,
#   ('electronic-devices', 'for-the-home', 'vehicles'): 9,
#   ('electronic-devices', 'leisure-hobbies', 'personal'): 9,
#   ('electronic-devices', 'leisure-hobbies', 'vehicles'): 9,
#   ('electronic-devices', 'personal', 'vehicles'): 9,
#   ('for-the-home', 'leisure-hobbies', 'personal'): 9,
#   ('for-the-home', 'leisure-hobbies', 'vehicles'): 9,
#   ('for-the-home', 'personal', 'vehicles'): 9,
#   ('leisure-hobbies', 'personal', 'vehicles'): 9},
#  4: {('businesses',
#    'electronic-devices',
#    'for-the-home',
#    'leisure-hobbies'): 9,
#   ('businesses', 'electronic-devices', 'for-the-home', 'personal'): 9,
#   ('businesses', 'electronic-devices', 'for-the-home', 'vehicles'): 9,
#   ('businesses', 'electronic-devices', 'leisure-hobbies', 'personal'): 9,
#   ('businesses', 'electronic-devices', 'leisure-hobbies', 'vehicles'): 9,
#   ('businesses', 'electronic-devices', 'personal', 'vehicles'): 9,
#   ('businesses', 'for-the-home', 'leisure-hobbies', 'personal'): 9,
#   ('businesses', 'for-the-home', 'leisure-hobbies', 'vehicles'): 9,
#   ('businesses', 'for-the-home', 'personal', 'vehicles'): 9,
#   ('businesses', 'leisure-hobbies', 'personal', 'vehicles'): 9,
#   ('electronic-devices', 'for-the-home', 'leisure-hobbies', 'personal'): 9,
#   ('electronic-devices', 'for-the-home', 'leisure-hobbies', 'vehicles'): 9,
#   ('electronic-devices', 'for-the-home', 'personal', 'vehicles'): 9,
#   ('electronic-devices', 'leisure-hobbies', 'personal', 'vehicles'): 9,
#   ('for-the-home', 'leisure-hobbies', 'personal', 'vehicles'): 9},
#  5: {('businesses',
#    'electronic-devices',
#    'for-the-home',
#    'leisure-hobbies',
#    'personal'): 9,
#   ('businesses',
#    'electronic-devices',
#    'for-the-home',
#    'leisure-hobbies',
#    'vehicles'): 9,
#   ('businesses',
#    'electronic-devices',
#    'for-the-home',
#    'personal',
#    'vehicles'): 9,
#   ('businesses',
#    'electronic-devices',
#    'leisure-hobbies',
#    'personal',
#    'vehicles'): 9,
#   ('businesses', 'for-the-home', 'leisure-hobbies', 'personal', 'vehicles'): 9,
#   ('electronic-devices',
#    'for-the-home',
#    'leisure-hobbies',
#    'personal',
#    'vehicles'): 9},
#  6: {('businesses',
#    'electronic-devices',
#    'for-the-home',
#    'leisure-hobbies',
#    'personal',
#    'vehicles'): 9}}

# %%
rules
# Out:
# [{electronic-devices} -> {businesses},
#  {businesses} -> {electronic-devices},
#  {for-the-home} -> {businesses},
#  {businesses} -> {for-the-home},
#  {leisure-hobbies} -> {businesses},
#  {businesses} -> {leisure-hobbies},
#  {personal} -> {businesses},
#  {businesses} -> {personal},
#  {vehicles} -> {businesses},
#  {businesses} -> {vehicles},
#  {for-the-home} -> {electronic-devices},
#  {electronic-devices} -> {for-the-home},
#  {leisure-hobbies} -> {electronic-devices},
#  {electronic-devices} -> {leisure-hobbies},
#  {personal} -> {electronic-devices},
#  {electronic-devices} -> {personal},
#  {vehicles} -> {electronic-devices},
#  {electronic-devices} -> {vehicles},
#  {leisure-hobbies} -> {for-the-home},
#  {for-the-home} -> {leisure-hobbies},
#  {personal} -> {for-the-home},
#  {for-the-home} -> {personal},
#  {vehicles} -> {for-the-home},
#  {for-the-home} -> {vehicles},
#  {personal} -> {leisure-hobbies},
#  {leisure-hobbies} -> {personal},
#  {vehicles} -> {leisure-hobbies},
#  {leisure-hobbies} -> {vehicles},
#  {vehicles} -> {personal},
#  {personal} -> {vehicles},
#  {electronic-devices, for-the-home} -> {businesses},
#  {businesses, for-the-home} -> {electronic-devices},
#  {businesses, electronic-devices} -> {for-the-home},
#  {for-the-home} -> {businesses, electronic-devices},
#  {electronic-devices} -> {businesses, for-the-home},
#  {businesses} -> {electronic-devices, for-the-home},
#  {electronic-devices, leisure-hobbies} -> {businesses},
#  {businesses, leisure-hobbies} -> {electronic-devices},
#  {businesses, electronic-devices} -> {leisure-hobbies},
#  {leisure-hobbies} -> {businesses, electronic-devices},
#  {electronic-devices} -> {businesses, leisure-hobbies},
#  {businesses} -> {electronic-devices, leisure-hobbies},
#  {electronic-devices, personal} -> {businesses},
#  {businesses, personal} -> {electronic-devices},
#  {businesses, electronic-devices} -> {personal},
#  {personal} -> {businesses, electronic-devices},
#  {electronic-devices} -> {businesses, personal},
#  {businesses} -> {electronic-devices, personal},
#  {electronic-devices, vehicles} -> {businesses},
#  {businesses, vehicles} -> {electronic-devices},
#  {businesses, electronic-devices} -> {vehicles},
#  {vehicles} -> {businesses, electronic-devices},
#  {electronic-devices} -> {businesses, vehicles},
#  {businesses} -> {electronic-devices, vehicles},
#  {for-the-home, leisure-hobbies} -> {businesses},
#  {businesses, leisure-hobbies} -> {for-the-home},
#  {businesses, for-the-home} -> {leisure-hobbies},
#  {leisure-hobbies} -> {businesses, for-the-home},
#  {for-the-home} -> {businesses, leisure-hobbies},
#  {businesses} -> {for-the-home, leisure-hobbies},
#  {for-the-home, personal} -> {businesses},
#  {businesses, personal} -> {for-the-home},
#  {businesses, for-the-home} -> {personal},
#  {personal} -> {businesses, for-the-home},
#  {for-the-home} -> {businesses, personal},
#  {businesses} -> {for-the-home, personal},
#  {for-the-home, vehicles} -> {businesses},
#  {businesses, vehicles} -> {for-the-home},
#  {businesses, for-the-home} -> {vehicles},
#  {vehicles} -> {businesses, for-the-home},
#  {for-the-home} -> {businesses, vehicles},
#  {businesses} -> {for-the-home, vehicles},
#  {leisure-hobbies, personal} -> {businesses},
#  {businesses, personal} -> {leisure-hobbies},
#  {businesses, leisure-hobbies} -> {personal},
#  {personal} -> {businesses, leisure-hobbies},
#  {leisure-hobbies} -> {businesses, personal},
#  {businesses} -> {leisure-hobbies, personal},
#  {leisure-hobbies, vehicles} -> {businesses},
#  {businesses, vehicles} -> {leisure-hobbies},
#  {businesses, leisure-hobbies} -> {vehicles},
#  {vehicles} -> {businesses, leisure-hobbies},
#  {leisure-hobbies} -> {businesses, vehicles},
#  {businesses} -> {leisure-hobbies, vehicles},
#  {personal, vehicles} -> {businesses},
#  {businesses, vehicles} -> {personal},
#  {businesses, personal} -> {vehicles},
#  {vehicles} -> {businesses, personal},
#  {personal} -> {businesses, vehicles},
#  {businesses} -> {personal, vehicles},
#  {for-the-home, leisure-hobbies} -> {electronic-devices},
#  {electronic-devices, leisure-hobbies} -> {for-the-home},
#  {electronic-devices, for-the-home} -> {leisure-hobbies},
#  {leisure-hobbies} -> {electronic-devices, for-the-home},
#  {for-the-home} -> {electronic-devices, leisure-hobbies},
#  {electronic-devices} -> {for-the-home, leisure-hobbies},
#  {for-the-home, personal} -> {electronic-devices},
#  {electronic-devices, personal} -> {for-the-home},
#  {electronic-devices, for-the-home} -> {personal},
#  {personal} -> {electronic-devices, for-the-home},
#  {for-the-home} -> {electronic-devices, personal},
#  {electronic-devices} -> {for-the-home, personal},
#  {for-the-home, vehicles} -> {electronic-devices},
#  {electronic-devices, vehicles} -> {for-the-home},
#  {electronic-devices, for-the-home} -> {vehicles},
#  {vehicles} -> {electronic-devices, for-the-home},
#  {for-the-home} -> {electronic-devices, vehicles},
#  {electronic-devices} -> {for-the-home, vehicles},
#  {leisure-hobbies, personal} -> {electronic-devices},
#  {electronic-devices, personal} -> {leisure-hobbies},
#  {electronic-devices, leisure-hobbies} -> {personal},
#  {personal} -> {electronic-devices, leisure-hobbies},
#  {leisure-hobbies} -> {electronic-devices, personal},
#  {electronic-devices} -> {leisure-hobbies, personal},
#  {leisure-hobbies, vehicles} -> {electronic-devices},
#  {electronic-devices, vehicles} -> {leisure-hobbies},
#  {electronic-devices, leisure-hobbies} -> {vehicles},
#  {vehicles} -> {electronic-devices, leisure-hobbies},
#  {leisure-hobbies} -> {electronic-devices, vehicles},
#  {electronic-devices} -> {leisure-hobbies, vehicles},
#  {personal, vehicles} -> {electronic-devices},
#  {electronic-devices, vehicles} -> {personal},
#  {electronic-devices, personal} -> {vehicles},
#  {vehicles} -> {electronic-devices, personal},
#  {personal} -> {electronic-devices, vehicles},
#  {electronic-devices} -> {personal, vehicles},
#  {leisure-hobbies, personal} -> {for-the-home},
#  {for-the-home, personal} -> {leisure-hobbies},
#  {for-the-home, leisure-hobbies} -> {personal},
#  {personal} -> {for-the-home, leisure-hobbies},
#  {leisure-hobbies} -> {for-the-home, personal},
#  {for-the-home} -> {leisure-hobbies, personal},
#  {leisure-hobbies, vehicles} -> {for-the-home},
#  {for-the-home, vehicles} -> {leisure-hobbies},
#  {for-the-home, leisure-hobbies} -> {vehicles},
#  {vehicles} -> {for-the-home, leisure-hobbies},
#  {leisure-hobbies} -> {for-the-home, vehicles},
#  {for-the-home} -> {leisure-hobbies, vehicles},
#  {personal, vehicles} -> {for-the-home},
#  {for-the-home, vehicles} -> {personal},
#  {for-the-home, personal} -> {vehicles},
#  {vehicles} -> {for-the-home, personal},
#  {personal} -> {for-the-home, vehicles},
#  {for-the-home} -> {personal, vehicles},
#  {personal, vehicles} -> {leisure-hobbies},
#  {leisure-hobbies, vehicles} -> {personal},
#  {leisure-hobbies, personal} -> {vehicles},
#  {vehicles} -> {leisure-hobbies, personal},
#  {personal} -> {leisure-hobbies, vehicles},
#  {leisure-hobbies} -> {personal, vehicles},
#  {electronic-devices, for-the-home, leisure-hobbies} -> {businesses},
#  {businesses, for-the-home, leisure-hobbies} -> {electronic-devices},
#  {businesses, electronic-devices, leisure-hobbies} -> {for-the-home},
#  {businesses, electronic-devices, for-the-home} -> {leisure-hobbies},
#  {for-the-home, leisure-hobbies} -> {businesses, electronic-devices},
#  {electronic-devices, leisure-hobbies} -> {businesses, for-the-home},
#  {electronic-devices, for-the-home} -> {businesses, leisure-hobbies},
#  {businesses, leisure-hobbies} -> {electronic-devices, for-the-home},
#  {businesses, for-the-home} -> {electronic-devices, leisure-hobbies},
#  {businesses, electronic-devices} -> {for-the-home, leisure-hobbies},
#  {leisure-hobbies} -> {businesses, electronic-devices, for-the-home},
#  {for-the-home} -> {businesses, electronic-devices, leisure-hobbies},
#  {electronic-devices} -> {businesses, for-the-home, leisure-hobbies},
#  {businesses} -> {electronic-devices, for-the-home, leisure-hobbies},
#  {electronic-devices, for-the-home, personal} -> {businesses},
#  {businesses, for-the-home, personal} -> {electronic-devices},
#  {businesses, electronic-devices, personal} -> {for-the-home},
#  {businesses, electronic-devices, for-the-home} -> {personal},
#  {for-the-home, personal} -> {businesses, electronic-devices},
#  {electronic-devices, personal} -> {businesses, for-the-home},
#  {electronic-devices, for-the-home} -> {businesses, personal},
#  {businesses, personal} -> {electronic-devices, for-the-home},
#  {businesses, for-the-home} -> {electronic-devices, personal},
#  {businesses, electronic-devices} -> {for-the-home, personal},
#  {personal} -> {businesses, electronic-devices, for-the-home},
#  {for-the-home} -> {businesses, electronic-devices, personal},
#  {electronic-devices} -> {businesses, for-the-home, personal},
#  {businesses} -> {electronic-devices, for-the-home, personal},
#  {electronic-devices, for-the-home, vehicles} -> {businesses},
#  {businesses, for-the-home, vehicles} -> {electronic-devices},
#  {businesses, electronic-devices, vehicles} -> {for-the-home},
#  {businesses, electronic-devices, for-the-home} -> {vehicles},
#  {for-the-home, vehicles} -> {businesses, electronic-devices},
#  {electronic-devices, vehicles} -> {businesses, for-the-home},
#  {electronic-devices, for-the-home} -> {businesses, vehicles},
#  {businesses, vehicles} -> {electronic-devices, for-the-home},
#  {businesses, for-the-home} -> {electronic-devices, vehicles},
#  {businesses, electronic-devices} -> {for-the-home, vehicles},
#  {vehicles} -> {businesses, electronic-devices, for-the-home},
#  {for-the-home} -> {businesses, electronic-devices, vehicles},
#  {electronic-devices} -> {businesses, for-the-home, vehicles},
#  {businesses} -> {electronic-devices, for-the-home, vehicles},
#  {electronic-devices, leisure-hobbies, personal} -> {businesses},
#  {businesses, leisure-hobbies, personal} -> {electronic-devices},
#  {businesses, electronic-devices, personal} -> {leisure-hobbies},
#  {businesses, electronic-devices, leisure-hobbies} -> {personal},
#  {leisure-hobbies, personal} -> {businesses, electronic-devices},
#  {electronic-devices, personal} -> {businesses, leisure-hobbies},
#  {electronic-devices, leisure-hobbies} -> {businesses, personal},
#  {businesses, personal} -> {electronic-devices, leisure-hobbies},
#  {businesses, leisure-hobbies} -> {electronic-devices, personal},
#  {businesses, electronic-devices} -> {leisure-hobbies, personal},
#  {personal} -> {businesses, electronic-devices, leisure-hobbies},
#  {leisure-hobbies} -> {businesses, electronic-devices, personal},
#  {electronic-devices} -> {businesses, leisure-hobbies, personal},
#  {businesses} -> {electronic-devices, leisure-hobbies, personal},
#  {electronic-devices, leisure-hobbies, vehicles} -> {businesses},
#  {businesses, leisure-hobbies, vehicles} -> {electronic-devices},
#  {businesses, electronic-devices, vehicles} -> {leisure-hobbies},
#  {businesses, electronic-devices, leisure-hobbies} -> {vehicles},
#  {leisure-hobbies, vehicles} -> {businesses, electronic-devices},
#  {electronic-devices, vehicles} -> {businesses, leisure-hobbies},
#  {electronic-devices, leisure-hobbies} -> {businesses, vehicles},
#  {businesses, vehicles} -> {electronic-devices, leisure-hobbies},
#  {businesses, leisure-hobbies} -> {electronic-devices, vehicles},
#  {businesses, electronic-devices} -> {leisure-hobbies, vehicles},
#  {vehicles} -> {businesses, electronic-devices, leisure-hobbies},
#  {leisure-hobbies} -> {businesses, electronic-devices, vehicles},
#  {electronic-devices} -> {businesses, leisure-hobbies, vehicles},
#  {businesses} -> {electronic-devices, leisure-hobbies, vehicles},
#  {electronic-devices, personal, vehicles} -> {businesses},
#  {businesses, personal, vehicles} -> {electronic-devices},
#  {businesses, electronic-devices, vehicles} -> {personal},
#  {businesses, electronic-devices, personal} -> {vehicles},
#  {personal, vehicles} -> {businesses, electronic-devices},
#  {electronic-devices, vehicles} -> {businesses, personal},
#  {electronic-devices, personal} -> {businesses, vehicles},
#  {businesses, vehicles} -> {electronic-devices, personal},
#  {businesses, personal} -> {electronic-devices, vehicles},
#  {businesses, electronic-devices} -> {personal, vehicles},
#  {vehicles} -> {businesses, electronic-devices, personal},
#  {personal} -> {businesses, electronic-devices, vehicles},
#  {electronic-devices} -> {businesses, personal, vehicles},
#  {businesses} -> {electronic-devices, personal, vehicles},
#  {for-the-home, leisure-hobbies, personal} -> {businesses},
#  {businesses, leisure-hobbies, personal} -> {for-the-home},
#  {businesses, for-the-home, personal} -> {leisure-hobbies},
#  {businesses, for-the-home, leisure-hobbies} -> {personal},
#  {leisure-hobbies, personal} -> {businesses, for-the-home},
#  {for-the-home, personal} -> {businesses, leisure-hobbies},
#  {for-the-home, leisure-hobbies} -> {businesses, personal},
#  {businesses, personal} -> {for-the-home, leisure-hobbies},
#  {businesses, leisure-hobbies} -> {for-the-home, personal},
#  {businesses, for-the-home} -> {leisure-hobbies, personal},
#  {personal} -> {businesses, for-the-home, leisure-hobbies},
#  {leisure-hobbies} -> {businesses, for-the-home, personal},
#  {for-the-home} -> {businesses, leisure-hobbies, personal},
#  {businesses} -> {for-the-home, leisure-hobbies, personal},
#  {for-the-home, leisure-hobbies, vehicles} -> {businesses},
#  {businesses, leisure-hobbies, vehicles} -> {for-the-home},
#  {businesses, for-the-home, vehicles} -> {leisure-hobbies},
#  {businesses, for-the-home, leisure-hobbies} -> {vehicles},
#  {leisure-hobbies, vehicles} -> {businesses, for-the-home},
#  {for-the-home, vehicles} -> {businesses, leisure-hobbies},
#  {for-the-home, leisure-hobbies} -> {businesses, vehicles},
#  {businesses, vehicles} -> {for-the-home, leisure-hobbies},
#  {businesses, leisure-hobbies} -> {for-the-home, vehicles},
#  {businesses, for-the-home} -> {leisure-hobbies, vehicles},
#  {vehicles} -> {businesses, for-the-home, leisure-hobbies},
#  {leisure-hobbies} -> {businesses, for-the-home, vehicles},
#  {for-the-home} -> {businesses, leisure-hobbies, vehicles},
#  {businesses} -> {for-the-home, leisure-hobbies, vehicles},
#  {for-the-home, personal, vehicles} -> {businesses},
#  {businesses, personal, vehicles} -> {for-the-home},
#  {businesses, for-the-home, vehicles} -> {personal},
#  {businesses, for-the-home, personal} -> {vehicles},
#  {personal, vehicles} -> {businesses, for-the-home},
#  {for-the-home, vehicles} -> {businesses, personal},
#  {for-the-home, personal} -> {businesses, vehicles},
#  {businesses, vehicles} -> {for-the-home, personal},
#  {businesses, personal} -> {for-the-home, vehicles},
#  {businesses, for-the-home} -> {personal, vehicles},
#  {vehicles} -> {businesses, for-the-home, personal},
#  {personal} -> {businesses, for-the-home, vehicles},
#  {for-the-home} -> {businesses, personal, vehicles},
#  {businesses} -> {for-the-home, personal, vehicles},
#  {leisure-hobbies, personal, vehicles} -> {businesses},
#  {businesses, personal, vehicles} -> {leisure-hobbies},
#  {businesses, leisure-hobbies, vehicles} -> {personal},
#  {businesses, leisure-hobbies, personal} -> {vehicles},
#  {personal, vehicles} -> {businesses, leisure-hobbies},
#  {leisure-hobbies, vehicles} -> {businesses, personal},
#  {leisure-hobbies, personal} -> {businesses, vehicles},
#  {businesses, vehicles} -> {leisure-hobbies, personal},
#  {businesses, personal} -> {leisure-hobbies, vehicles},
#  {businesses, leisure-hobbies} -> {personal, vehicles},
#  {vehicles} -> {businesses, leisure-hobbies, personal},
#  {personal} -> {businesses, leisure-hobbies, vehicles},
#  {leisure-hobbies} -> {businesses, personal, vehicles},
#  {businesses} -> {leisure-hobbies, personal, vehicles},
#  {for-the-home, leisure-hobbies, personal} -> {electronic-devices},
#  {electronic-devices, leisure-hobbies, personal} -> {for-the-home},
#  {electronic-devices, for-the-home, personal} -> {leisure-hobbies},
#  {electronic-devices, for-the-home, leisure-hobbies} -> {personal},
#  {leisure-hobbies, personal} -> {electronic-devices, for-the-home},
#  {for-the-home, personal} -> {electronic-devices, leisure-hobbies},
#  {for-the-home, leisure-hobbies} -> {electronic-devices, personal},
#  {electronic-devices, personal} -> {for-the-home, leisure-hobbies},
#  {electronic-devices, leisure-hobbies} -> {for-the-home, personal},
#  {electronic-devices, for-the-home} -> {leisure-hobbies, personal},
#  {personal} -> {electronic-devices, for-the-home, leisure-hobbies},
#  {leisure-hobbies} -> {electronic-devices, for-the-home, personal},
#  {for-the-home} -> {electronic-devices, leisure-hobbies, personal},
#  {electronic-devices} -> {for-the-home, leisure-hobbies, personal},
#  {for-the-home, leisure-hobbies, vehicles} -> {electronic-devices},
#  {electronic-devices, leisure-hobbies, vehicles} -> {for-the-home},
#  {electronic-devices, for-the-home, vehicles} -> {leisure-hobbies},
#  {electronic-devices, for-the-home, leisure-hobbies} -> {vehicles},
#  {leisure-hobbies, vehicles} -> {electronic-devices, for-the-home},
#  {for-the-home, vehicles} -> {electronic-devices, leisure-hobbies},
#  {for-the-home, leisure-hobbies} -> {electronic-devices, vehicles},
#  {electronic-devices, vehicles} -> {for-the-home, leisure-hobbies},
#  {electronic-devices, leisure-hobbies} -> {for-the-home, vehicles},
#  {electronic-devices, for-the-home} -> {leisure-hobbies, vehicles},
#  {vehicles} -> {electronic-devices, for-the-home, leisure-hobbies},
#  {leisure-hobbies} -> {electronic-devices, for-the-home, vehicles},
#  {for-the-home} -> {electronic-devices, leisure-hobbies, vehicles},
#  {electronic-devices} -> {for-the-home, leisure-hobbies, vehicles},
#  {for-the-home, personal, vehicles} -> {electronic-devices},
#  {electronic-devices, personal, vehicles} -> {for-the-home},
#  {electronic-devices, for-the-home, vehicles} -> {personal},
#  {electronic-devices, for-the-home, personal} -> {vehicles},
#  {personal, vehicles} -> {electronic-devices, for-the-home},
#  {for-the-home, vehicles} -> {electronic-devices, personal},
#  {for-the-home, personal} -> {electronic-devices, vehicles},
#  {electronic-devices, vehicles} -> {for-the-home, personal},
#  {electronic-devices, personal} -> {for-the-home, vehicles},
#  {electronic-devices, for-the-home} -> {personal, vehicles},
#  {vehicles} -> {electronic-devices, for-the-home, personal},
#  {personal} -> {electronic-devices, for-the-home, vehicles},
#  {for-the-home} -> {electronic-devices, personal, vehicles},
#  {electronic-devices} -> {for-the-home, personal, vehicles},
#  {leisure-hobbies, personal, vehicles} -> {electronic-devices},
#  {electronic-devices, personal, vehicles} -> {leisure-hobbies},
#  {electronic-devices, leisure-hobbies, vehicles} -> {personal},
#  {electronic-devices, leisure-hobbies, personal} -> {vehicles},
#  {personal, vehicles} -> {electronic-devices, leisure-hobbies},
#  {leisure-hobbies, vehicles} -> {electronic-devices, personal},
#  {leisure-hobbies, personal} -> {electronic-devices, vehicles},
#  {electronic-devices, vehicles} -> {leisure-hobbies, personal},
#  {electronic-devices, personal} -> {leisure-hobbies, vehicles},
#  {electronic-devices, leisure-hobbies} -> {personal, vehicles},
#  {vehicles} -> {electronic-devices, leisure-hobbies, personal},
#  {personal} -> {electronic-devices, leisure-hobbies, vehicles},
#  {leisure-hobbies} -> {electronic-devices, personal, vehicles},
#  {electronic-devices} -> {leisure-hobbies, personal, vehicles},
#  {leisure-hobbies, personal, vehicles} -> {for-the-home},
#  {for-the-home, personal, vehicles} -> {leisure-hobbies},
#  {for-the-home, leisure-hobbies, vehicles} -> {personal},
#  {for-the-home, leisure-hobbies, personal} -> {vehicles},
#  {personal, vehicles} -> {for-the-home, leisure-hobbies},
#  {leisure-hobbies, vehicles} -> {for-the-home, personal},
#  {leisure-hobbies, personal} -> {for-the-home, vehicles},
#  {for-the-home, vehicles} -> {leisure-hobbies, personal},
#  {for-the-home, personal} -> {leisure-hobbies, vehicles},
#  {for-the-home, leisure-hobbies} -> {personal, vehicles},
#  {vehicles} -> {for-the-home, leisure-hobbies, personal},
#  {personal} -> {for-the-home, leisure-hobbies, vehicles},
#  {leisure-hobbies} -> {for-the-home, personal, vehicles},
#  {for-the-home} -> {leisure-hobbies, personal, vehicles},
#  {electronic-devices, for-the-home, leisure-hobbies, personal} -> {businesses},
#  {businesses, for-the-home, leisure-hobbies, personal} -> {electronic-devices},
#  {businesses, electronic-devices, leisure-hobbies, personal} -> {for-the-home},
#  {businesses, electronic-devices, for-the-home, personal} -> {leisure-hobbies},
#  {businesses, electronic-devices, for-the-home, leisure-hobbies} -> {personal},
#  {for-the-home, leisure-hobbies, personal} -> {businesses, electronic-devices},
#  {electronic-devices, leisure-hobbies, personal} -> {businesses, for-the-home},
#  {electronic-devices, for-the-home, personal} -> {businesses, leisure-hobbies},
#  {electronic-devices, for-the-home, leisure-hobbies} -> {businesses, personal},
#  {businesses, leisure-hobbies, personal} -> {electronic-devices, for-the-home},
#  {businesses, for-the-home, personal} -> {electronic-devices, leisure-hobbies},
#  {businesses, for-the-home, leisure-hobbies} -> {electronic-devices, personal},
#  {businesses, electronic-devices, personal} -> {for-the-home, leisure-hobbies},
#  {businesses, electronic-devices, leisure-hobbies} -> {for-the-home, personal},
#  {businesses, electronic-devices, for-the-home} -> {leisure-hobbies, personal},
#  {leisure-hobbies, personal} -> {businesses, electronic-devices, for-the-home},
#  {for-the-home, personal} -> {businesses, electronic-devices, leisure-hobbies},
#  {for-the-home, leisure-hobbies} -> {businesses, electronic-devices, personal},
#  {electronic-devices, personal} -> {businesses, for-the-home, leisure-hobbies},
#  {electronic-devices, leisure-hobbies} -> {businesses, for-the-home, personal},
#  {electronic-devices, for-the-home} -> {businesses, leisure-hobbies, personal},
#  {businesses, personal} -> {electronic-devices, for-the-home, leisure-hobbies},
#  {businesses, leisure-hobbies} -> {electronic-devices, for-the-home, personal},
#  {businesses, for-the-home} -> {electronic-devices, leisure-hobbies, personal},
#  {businesses, electronic-devices} -> {for-the-home, leisure-hobbies, personal},
#  {personal} -> {businesses, electronic-devices, for-the-home, leisure-hobbies},
#  {leisure-hobbies} -> {businesses, electronic-devices, for-the-home, personal},
#  {for-the-home} -> {businesses, electronic-devices, leisure-hobbies, personal},
#  {electronic-devices} -> {businesses, for-the-home, leisure-hobbies, personal},
#  {businesses} -> {electronic-devices, for-the-home, leisure-hobbies, personal},
#  {electronic-devices, for-the-home, leisure-hobbies, vehicles} -> {businesses},
#  {businesses, for-the-home, leisure-hobbies, vehicles} -> {electronic-devices},
#  {businesses, electronic-devices, leisure-hobbies, vehicles} -> {for-the-home},
#  {businesses, electronic-devices, for-the-home, vehicles} -> {leisure-hobbies},
#  {businesses, electronic-devices, for-the-home, leisure-hobbies} -> {vehicles},
#  {for-the-home, leisure-hobbies, vehicles} -> {businesses, electronic-devices},
#  {electronic-devices, leisure-hobbies, vehicles} -> {businesses, for-the-home},
#  {electronic-devices, for-the-home, vehicles} -> {businesses, leisure-hobbies},
#  {electronic-devices, for-the-home, leisure-hobbies} -> {businesses, vehicles},
#  {businesses, leisure-hobbies, vehicles} -> {electronic-devices, for-the-home},
#  {businesses, for-the-home, vehicles} -> {electronic-devices, leisure-hobbies},
#  {businesses, for-the-home, leisure-hobbies} -> {electronic-devices, vehicles},
#  {businesses, electronic-devices, vehicles} -> {for-the-home, leisure-hobbies},
#  {businesses, electronic-devices, leisure-hobbies} -> {for-the-home, vehicles},
#  {businesses, electronic-devices, for-the-home} -> {leisure-hobbies, vehicles},
#  {leisure-hobbies, vehicles} -> {businesses, electronic-devices, for-the-home},
#  {for-the-home, vehicles} -> {businesses, electronic-devices, leisure-hobbies},
#  {for-the-home, leisure-hobbies} -> {businesses, electronic-devices, vehicles},
#  {electronic-devices, vehicles} -> {businesses, for-the-home, leisure-hobbies},
#  {electronic-devices, leisure-hobbies} -> {businesses, for-the-home, vehicles},
#  {electronic-devices, for-the-home} -> {businesses, leisure-hobbies, vehicles},
#  {businesses, vehicles} -> {electronic-devices, for-the-home, leisure-hobbies},
#  {businesses, leisure-hobbies} -> {electronic-devices, for-the-home, vehicles},
#  {businesses, for-the-home} -> {electronic-devices, leisure-hobbies, vehicles},
#  {businesses, electronic-devices} -> {for-the-home, leisure-hobbies, vehicles},
#  {vehicles} -> {businesses, electronic-devices, for-the-home, leisure-hobbies},
#  {leisure-hobbies} -> {businesses, electronic-devices, for-the-home, vehicles},
#  {for-the-home} -> {businesses, electronic-devices, leisure-hobbies, vehicles},
#  {electronic-devices} -> {businesses, for-the-home, leisure-hobbies, vehicles},
#  {businesses} -> {electronic-devices, for-the-home, leisure-hobbies, vehicles},
#  {electronic-devices, for-the-home, personal, vehicles} -> {businesses},
#  {businesses, for-the-home, personal, vehicles} -> {electronic-devices},
#  {businesses, electronic-devices, personal, vehicles} -> {for-the-home},
#  {businesses, electronic-devices, for-the-home, vehicles} -> {personal},
#  {businesses, electronic-devices, for-the-home, personal} -> {vehicles},
#  {for-the-home, personal, vehicles} -> {businesses, electronic-devices},
#  {electronic-devices, personal, vehicles} -> {businesses, for-the-home},
#  {electronic-devices, for-the-home, vehicles} -> {businesses, personal},
#  {electronic-devices, for-the-home, personal} -> {businesses, vehicles},
#  {businesses, personal, vehicles} -> {electronic-devices, for-the-home},
#  {businesses, for-the-home, vehicles} -> {electronic-devices, personal},
#  {businesses, for-the-home, personal} -> {electronic-devices, vehicles},
#  {businesses, electronic-devices, vehicles} -> {for-the-home, personal},
#  {businesses, electronic-devices, personal} -> {for-the-home, vehicles},
#  {businesses, electronic-devices, for-the-home} -> {personal, vehicles},
#  {personal, vehicles} -> {businesses, electronic-devices, for-the-home},
#  {for-the-home, vehicles} -> {businesses, electronic-devices, personal},
#  {for-the-home, personal} -> {businesses, electronic-devices, vehicles},
#  {electronic-devices, vehicles} -> {businesses, for-the-home, personal},
#  {electronic-devices, personal} -> {businesses, for-the-home, vehicles},
#  {electronic-devices, for-the-home} -> {businesses, personal, vehicles},
#  {businesses, vehicles} -> {electronic-devices, for-the-home, personal},
#  {businesses, personal} -> {electronic-devices, for-the-home, vehicles},
#  {businesses, for-the-home} -> {electronic-devices, personal, vehicles},
#  {businesses, electronic-devices} -> {for-the-home, personal, vehicles},
#  {vehicles} -> {businesses, electronic-devices, for-the-home, personal},
#  {personal} -> {businesses, electronic-devices, for-the-home, vehicles},
#  {for-the-home} -> {businesses, electronic-devices, personal, vehicles},
#  {electronic-devices} -> {businesses, for-the-home, personal, vehicles},
#  {businesses} -> {electronic-devices, for-the-home, personal, vehicles},
#  {electronic-devices, leisure-hobbies, personal, vehicles} -> {businesses},
#  {businesses, leisure-hobbies, personal, vehicles} -> {electronic-devices},
#  {businesses, electronic-devices, personal, vehicles} -> {leisure-hobbies},
#  {businesses, electronic-devices, leisure-hobbies, vehicles} -> {personal},
#  {businesses, electronic-devices, leisure-hobbies, personal} -> {vehicles},
#  {leisure-hobbies, personal, vehicles} -> {businesses, electronic-devices},
#  {electronic-devices, personal, vehicles} -> {businesses, leisure-hobbies},
#  {electronic-devices, leisure-hobbies, vehicles} -> {businesses, personal},
#  {electronic-devices, leisure-hobbies, personal} -> {businesses, vehicles},
#  {businesses, personal, vehicles} -> {electronic-devices, leisure-hobbies},
#  {businesses, leisure-hobbies, vehicles} -> {electronic-devices, personal},
#  {businesses, leisure-hobbies, personal} -> {electronic-devices, vehicles},
#  {businesses, electronic-devices, vehicles} -> {leisure-hobbies, personal},
#  {businesses, electronic-devices, personal} -> {leisure-hobbies, vehicles},
#  {businesses, electronic-devices, leisure-hobbies} -> {personal, vehicles},
#  {personal, vehicles} -> {businesses, electronic-devices, leisure-hobbies},
#  {leisure-hobbies, vehicles} -> {businesses, electronic-devices, personal},
#  {leisure-hobbies, personal} -> {businesses, electronic-devices, vehicles},
#  {electronic-devices, vehicles} -> {businesses, leisure-hobbies, personal},
#  {electronic-devices, personal} -> {businesses, leisure-hobbies, vehicles},
#  {electronic-devices, leisure-hobbies} -> {businesses, personal, vehicles},
#  {businesses, vehicles} -> {electronic-devices, leisure-hobbies, personal},
#  {businesses, personal} -> {electronic-devices, leisure-hobbies, vehicles},
#  {businesses, leisure-hobbies} -> {electronic-devices, personal, vehicles},
#  {businesses, electronic-devices} -> {leisure-hobbies, personal, vehicles},
#  {vehicles} -> {businesses, electronic-devices, leisure-hobbies, personal},
#  {personal} -> {businesses, electronic-devices, leisure-hobbies, vehicles},
#  {leisure-hobbies} -> {businesses, electronic-devices, personal, vehicles},
#  {electronic-devices} -> {businesses, leisure-hobbies, personal, vehicles},
#  {businesses} -> {electronic-devices, leisure-hobbies, personal, vehicles},
#  {for-the-home, leisure-hobbies, personal, vehicles} -> {businesses},
#  {businesses, leisure-hobbies, personal, vehicles} -> {for-the-home},
#  {businesses, for-the-home, personal, vehicles} -> {leisure-hobbies},
#  {businesses, for-the-home, leisure-hobbies, vehicles} -> {personal},
#  {businesses, for-the-home, leisure-hobbies, personal} -> {vehicles},
#  {leisure-hobbies, personal, vehicles} -> {businesses, for-the-home},
#  {for-the-home, personal, vehicles} -> {businesses, leisure-hobbies},
#  {for-the-home, leisure-hobbies, vehicles} -> {businesses, personal},
#  {for-the-home, leisure-hobbies, personal} -> {businesses, vehicles},
#  {businesses, personal, vehicles} -> {for-the-home, leisure-hobbies},
#  {businesses, leisure-hobbies, vehicles} -> {for-the-home, personal},
#  {businesses, leisure-hobbies, personal} -> {for-the-home, vehicles},
#  {businesses, for-the-home, vehicles} -> {leisure-hobbies, personal},
#  {businesses, for-the-home, personal} -> {leisure-hobbies, vehicles},
#  {businesses, for-the-home, leisure-hobbies} -> {personal, vehicles},
#  {personal, vehicles} -> {businesses, for-the-home, leisure-hobbies},
#  {leisure-hobbies, vehicles} -> {businesses, for-the-home, personal},
#  {leisure-hobbies, personal} -> {businesses, for-the-home, vehicles},
#  {for-the-home, vehicles} -> {businesses, leisure-hobbies, personal},
#  {for-the-home, personal} -> {businesses, leisure-hobbies, vehicles},
#  {for-the-home, leisure-hobbies} -> {businesses, personal, vehicles},
#  {businesses, vehicles} -> {for-the-home, leisure-hobbies, personal},
#  {businesses, personal} -> {for-the-home, leisure-hobbies, vehicles},
#  {businesses, leisure-hobbies} -> {for-the-home, personal, vehicles},
#  {businesses, for-the-home} -> {leisure-hobbies, personal, vehicles},
#  {vehicles} -> {businesses, for-the-home, leisure-hobbies, personal},
#  {personal} -> {businesses, for-the-home, leisure-hobbies, vehicles},
#  {leisure-hobbies} -> {businesses, for-the-home, personal, vehicles},
#  {for-the-home} -> {businesses, leisure-hobbies, personal, vehicles},
#  {businesses} -> {for-the-home, leisure-hobbies, personal, vehicles},
#  {for-the-home, leisure-hobbies, personal, vehicles} -> {electronic-devices},
#  {electronic-devices, leisure-hobbies, personal, vehicles} -> {for-the-home},
#  {electronic-devices, for-the-home, personal, vehicles} -> {leisure-hobbies},
#  {electronic-devices, for-the-home, leisure-hobbies, vehicles} -> {personal},
#  {electronic-devices, for-the-home, leisure-hobbies, personal} -> {vehicles},
#  {leisure-hobbies, personal, vehicles} -> {electronic-devices, for-the-home},
#  {for-the-home, personal, vehicles} -> {electronic-devices, leisure-hobbies},
#  {for-the-home, leisure-hobbies, vehicles} -> {electronic-devices, personal},
#  {for-the-home, leisure-hobbies, personal} -> {electronic-devices, vehicles},
#  {electronic-devices, personal, vehicles} -> {for-the-home, leisure-hobbies},
#  {electronic-devices, leisure-hobbies, vehicles} -> {for-the-home, personal},
#  {electronic-devices, leisure-hobbies, personal} -> {for-the-home, vehicles},
#  {electronic-devices, for-the-home, vehicles} -> {leisure-hobbies, personal},
#  {electronic-devices, for-the-home, personal} -> {leisure-hobbies, vehicles},
#  {electronic-devices, for-the-home, leisure-hobbies} -> {personal, vehicles},
#  {personal, vehicles} -> {electronic-devices, for-the-home, leisure-hobbies},
#  {leisure-hobbies, vehicles} -> {electronic-devices, for-the-home, personal},
#  {leisure-hobbies, personal} -> {electronic-devices, for-the-home, vehicles},
#  {for-the-home, vehicles} -> {electronic-devices, leisure-hobbies, personal},
#  {for-the-home, personal} -> {electronic-devices, leisure-hobbies, vehicles},
#  {for-the-home, leisure-hobbies} -> {electronic-devices, personal, vehicles},
#  {electronic-devices, vehicles} -> {for-the-home, leisure-hobbies, personal},
#  {electronic-devices, personal} -> {for-the-home, leisure-hobbies, vehicles},
#  {electronic-devices, leisure-hobbies} -> {for-the-home, personal, vehicles},
#  {electronic-devices, for-the-home} -> {leisure-hobbies, personal, vehicles},
#  {vehicles} -> {electronic-devices, for-the-home, leisure-hobbies, personal},
#  {personal} -> {electronic-devices, for-the-home, leisure-hobbies, vehicles},
#  {leisure-hobbies} -> {electronic-devices, for-the-home, personal, vehicles},
#  {for-the-home} -> {electronic-devices, leisure-hobbies, personal, vehicles},
#  {electronic-devices} -> {for-the-home, leisure-hobbies, personal, vehicles},
#  {electronic-devices, for-the-home, leisure-hobbies, personal, vehicles} -> {businesses},
#  {businesses, for-the-home, leisure-hobbies, personal, vehicles} -> {electronic-devices},
#  {businesses, electronic-devices, leisure-hobbies, personal, vehicles} -> {for-the-home},
#  {businesses, electronic-devices, for-the-home, personal, vehicles} -> {leisure-hobbies},
#  {businesses, electronic-devices, for-the-home, leisure-hobbies, vehicles} -> {personal},
#  {businesses, electronic-devices, for-the-home, leisure-hobbies, personal} -> {vehicles},
#  {for-the-home, leisure-hobbies, personal, vehicles} -> {businesses, electronic-devices},
#  {electronic-devices, leisure-hobbies, personal, vehicles} -> {businesses, for-the-home},
#  {electronic-devices, for-the-home, personal, vehicles} -> {businesses, leisure-hobbies},
#  {electronic-devices, for-the-home, leisure-hobbies, vehicles} -> {businesses, personal},
#  {electronic-devices, for-the-home, leisure-hobbies, personal} -> {businesses, vehicles},
#  {businesses, leisure-hobbies, personal, vehicles} -> {electronic-devices, for-the-home},
#  {businesses, for-the-home, personal, vehicles} -> {electronic-devices, leisure-hobbies},
#  {businesses, for-the-home, leisure-hobbies, vehicles} -> {electronic-devices, personal},
#  {businesses, for-the-home, leisure-hobbies, personal} -> {electronic-devices, vehicles},
#  {businesses, electronic-devices, personal, vehicles} -> {for-the-home, leisure-hobbies},
#  {businesses, electronic-devices, leisure-hobbies, vehicles} -> {for-the-home, personal},
#  {businesses, electronic-devices, leisure-hobbies, personal} -> {for-the-home, vehicles},
#  {businesses, electronic-devices, for-the-home, vehicles} -> {leisure-hobbies, personal},
#  {businesses, electronic-devices, for-the-home, personal} -> {leisure-hobbies, vehicles},
#  {businesses, electronic-devices, for-the-home, leisure-hobbies} -> {personal, vehicles},
#  {leisure-hobbies, personal, vehicles} -> {businesses, electronic-devices, for-the-home},
#  {for-the-home, personal, vehicles} -> {businesses, electronic-devices, leisure-hobbies},
#  {for-the-home, leisure-hobbies, vehicles} -> {businesses, electronic-devices, personal},
#  {for-the-home, leisure-hobbies, personal} -> {businesses, electronic-devices, vehicles},
#  {electronic-devices, personal, vehicles} -> {businesses, for-the-home, leisure-hobbies},
#  {electronic-devices, leisure-hobbies, vehicles} -> {businesses, for-the-home, personal},
#  {electronic-devices, leisure-hobbies, personal} -> {businesses, for-the-home, vehicles},
#  {electronic-devices, for-the-home, vehicles} -> {businesses, leisure-hobbies, personal},
#  {electronic-devices, for-the-home, personal} -> {businesses, leisure-hobbies, vehicles},
#  {electronic-devices, for-the-home, leisure-hobbies} -> {businesses, personal, vehicles},
#  {businesses, personal, vehicles} -> {electronic-devices, for-the-home, leisure-hobbies},
#  {businesses, leisure-hobbies, vehicles} -> {electronic-devices, for-the-home, personal},
#  {businesses, leisure-hobbies, personal} -> {electronic-devices, for-the-home, vehicles},
#  {businesses, for-the-home, vehicles} -> {electronic-devices, leisure-hobbies, personal},
#  {businesses, for-the-home, personal} -> {electronic-devices, leisure-hobbies, vehicles},
#  {businesses, for-the-home, leisure-hobbies} -> {electronic-devices, personal, vehicles},
#  {businesses, electronic-devices, vehicles} -> {for-the-home, leisure-hobbies, personal},
#  {businesses, electronic-devices, personal} -> {for-the-home, leisure-hobbies, vehicles},
#  {businesses, electronic-devices, leisure-hobbies} -> {for-the-home, personal, vehicles},
#  {businesses, electronic-devices, for-the-home} -> {leisure-hobbies, personal, vehicles},
#  {personal, vehicles} -> {businesses, electronic-devices, for-the-home, leisure-hobbies},
#  {leisure-hobbies, vehicles} -> {businesses, electronic-devices, for-the-home, personal},
#  {leisure-hobbies, personal} -> {businesses, electronic-devices, for-the-home, vehicles},
#  {for-the-home, vehicles} -> {businesses, electronic-devices, leisure-hobbies, personal},
#  {for-the-home, personal} -> {businesses, electronic-devices, leisure-hobbies, vehicles},
#  {for-the-home, leisure-hobbies} -> {businesses, electronic-devices, personal, vehicles},
#  {electronic-devices, vehicles} -> {businesses, for-the-home, leisure-hobbies, personal},
#  {electronic-devices, personal} -> {businesses, for-the-home, leisure-hobbies, vehicles},
#  {electronic-devices, leisure-hobbies} -> {businesses, for-the-home, personal, vehicles},
#  {electronic-devices, for-the-home} -> {businesses, leisure-hobbies, personal, vehicles},
#  {businesses, vehicles} -> {electronic-devices, for-the-home, leisure-hobbies, personal},
#  {businesses, personal} -> {electronic-devices, for-the-home, leisure-hobbies, vehicles},
#  {businesses, leisure-hobbies} -> {electronic-devices, for-the-home, personal, vehicles},
#  {businesses, for-the-home} -> {electronic-devices, leisure-hobbies, personal, vehicles},
#  {businesses, electronic-devices} -> {for-the-home, leisure-hobbies, personal, vehicles},
#  {vehicles} -> {businesses, electronic-devices, for-the-home, leisure-hobbies, personal},
#  {personal} -> {businesses, electronic-devices, for-the-home, leisure-hobbies, vehicles},
#  {leisure-hobbies} -> {businesses, electronic-devices, for-the-home, personal, vehicles},
#  {for-the-home} -> {businesses, electronic-devices, leisure-hobbies, personal, vehicles},
#  {electronic-devices} -> {businesses, for-the-home, leisure-hobbies, personal, vehicles},
#  {businesses} -> {electronic-devices, for-the-home, leisure-hobbies, personal, vehicles}]

# %% [markdown]
# # 2.	استخراج الگوهای فروش محصولات مختلف در دیتاست دیجیکالا

# %%
groupby_customer = orders.groupby(by = ['ID_Customer'])

transactions_of_customers = []
for group, pdf in groupby_customer:
    transactions_of_customers.append(pdf['ID_Item'].values.tolist())

# %%
print("number of transactions:", len(transactions_of_customers))
transactions_of_customers[:10]
# Out:
# number of transactions: 151634
# [[42545,
#   361304,
#   1523292,
#   1671385,
#   369749,
#   1711488,
#   5265,
#   75068,
#   80046,
#   1771143,
#   81692],
#  [43418],
#  [137418, 242763, 295740],
#  [46854],
#  [76901, 1390734, 87941],
#  [2015151],
#  [189732, 4631],
#  [767994],
#  [61363, 91566, 20173],
#  [180116]]

# %%
transactions = []
for tr in transactions_of_customers:
    if len(tr) > 1:
        transactions.append(tr)
        
print("total transactions      : ", len(transactions_of_customers))
print("cleaning for finding FP : ", len(transactions))
# Out:
# total transactions      :  151634
# cleaning for finding FP :  28700

# %% [markdown]
# ## Frequent patterns with support_threshold 3

# %%
patterns = pyfpgrowth.find_frequent_patterns(transactions, 3)
{k: patterns[k] for k in list(patterns)[:20]}
# Out:
# {(369749,): 3,
#  (189732,): 3,
#  (114994,): 3,
#  (175451,): 3,
#  (22105,): 3,
#  (66491,): 3,
#  (43533,): 3,
#  (134937,): 3,
#  (1150874,): 3,
#  (161233,): 3,
#  (388826,): 3,
#  (295644,): 3,
#  (169960,): 3,
#  (10373,): 3,
#  (199429,): 3,
#  (44445,): 3,
#  (478445,): 3,
#  (51734,): 3,
#  (299504,): 3,
#  (424039,): 3}

# %%
len(patterns)
# Out:
# 5244

# %% [markdown]
# ### Generate association rules with min confidence threshold 0.25

# %%
rules = pyfpgrowth.generate_association_rules(patterns, 0.25)
rules
# Out:
# {(875835,): ((294942,), 0.75),
#  (31619,): ((294942,), 1.0),
#  (388778,): ((104031,), 1.0),
#  (90776,): ((12011,), 0.5),
#  (12011, 12011): ((90776,), 1.0),
#  (12011, 90776): ((), 1.0),
#  (100245,): ((294942,), 0.375),
#  (223359,): ((294942,), 0.3333333333333333),
#  (434176,): ((), 0.5)}

# %%
best_seller_items = pyfpgrowth.find_frequent_patterns(transactions_of_customers, 100)
best_seller_items
# Out:
# {(164602,): 100,
#  (254946,): 100,
#  (43106,): 102,
#  (479349,): 102,
#  (137583,): 106,
#  (44653,): 107,
#  (295740,): 108,
#  (54850,): 108,
#  (128133,): 111,
#  (163090,): 114,
#  (82966,): 115,
#  (94233,): 119,
#  (143130,): 119,
#  (20215,): 122,
#  (245223,): 124,
#  (77707,): 127,
#  (12532,): 128,
#  (129574,): 129,
#  (118375,): 131,
#  (294923,): 131,
#  (42124,): 141,
#  (7225,): 146,
#  (153067,): 149,
#  (294943,): 155,
#  (22839,): 160,
#  (19890,): 168,
#  (416448,): 175,
#  (8289,): 233,
#  (45121,): 259,
#  (51778,): 288,
#  (36871,): 367,
#  (294942,): 481}

# %% [markdown]
# # 3.	استخراج الگوهای مکرر میان روز انتشار پست و پلتفرم استفاده شده

# %%
groupby_day_platform = df.groupby(by = ['cat1'])
transactions_of_day_platform = []
for group, pdf in groupby_day_platform:
    transactions_of_day_platform.append(tuple(map(tuple,pdf[['day','platform']].values)))
transactions_of_day_platform
# Out:
# [(('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'web'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'web'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'web'),
#   ('Tuesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'web'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'web'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'web'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'web'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'web'),
#   ('Friday', 'mobile'),
#   ('Friday', 'web'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'web'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'web'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'web'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'web'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'web'),
#   ('Monday', 'web'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'web'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Monday', 'web'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Tuesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'web'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'web'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'web'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'web'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Sunday', 'web'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'web'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Sunday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'web'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'web'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'web'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Friday', 'web'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'web'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'web'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Monday', 'web'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'web'),
#   ('Monday', 'web'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'web'),
#   ('Friday', 'web'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'web'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'web'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'web'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'web'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'web'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'web'),
#   ('Thursday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'web'),
#   ('Monday', 'web'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'web'),
#   ('Tuesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'web'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'web'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Friday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'web'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'web'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ...),
#  (('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'web'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'web'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'web'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'web'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'web'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'web'),
#   ('Tuesday', 'web'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'web'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'web'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'web'),
#   ('Tuesday', 'web'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'web'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'web'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'web'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'web'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'web'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'web'),
#   ('Monday', 'web'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'web'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'web'),
#   ('Monday', 'web'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'web'),
#   ('Friday', 'web'),
#   ('Friday', 'mobile'),
#   ('Friday', 'web'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'web'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'web'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'web'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'web'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'web'),
#   ('Friday', 'mobile'),
#   ('Friday', 'web'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'web'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'web'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'web'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'web'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'web'),
#   ('Monday', 'web'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'web'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'web'),
#   ('Monday', 'web'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'web'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'web'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'web'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'web'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'web'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Thursday', 'mobile'),
# ...
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'web'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'web'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'web'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'web'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'web'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'web'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'web'),
#   ('Tuesday', 'web'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'web'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'web'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'web'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'web'),
#   ('Tuesday', 'web'),
#   ('Tuesday', 'web'),
#   ('Tuesday', 'web'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'web'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'web'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'web'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'web'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'web'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'web'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'web'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'web'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Sunday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Monday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Tuesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Wednesday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'web'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Thursday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Friday', 'web'),
#   ('Friday', 'mobile'),
#   ('Friday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ('Saturday', 'mobile'),
#   ...)]

# %%
transactionsDayPlatfrom = []
for tr in transactions_of_day_platform:
    if len(tr) > 1:
        transactionsDayPlatfrom.append(tr)
        
print("total transactions      : ", len(transactions_of_day_platform))
print("cleaning for finding FP : ", len(transactionsDayPlatfrom))
# Out:
# total transactions      :  6
# cleaning for finding FP :  6

# %%
print(len(transactions_of_day_platform))
# Out:
# 6

# %%
itemsets, rules = apriori(transactionsDayPlatfrom,min_support=0.9, min_confidence=0.8)
itemsets
# Out:
# {1: {(('Tuesday', 'web'),): 6,
#   (('Sunday', 'mobile'),): 6,
#   (('Sunday', 'web'),): 6,
#   (('Friday', 'web'),): 6,
#   (('Friday', 'mobile'),): 6,
#   (('Monday', 'mobile'),): 6,
#   (('Wednesday', 'mobile'),): 6,
#   (('Thursday', 'mobile'),): 6,
#   (('Monday', 'web'),): 6,
#   (('Wednesday', 'web'),): 6,
#   (('Thursday', 'web'),): 6,
#   (('Saturday', 'web'),): 6,
#   (('Saturday', 'mobile'),): 6,
#   (('Tuesday', 'mobile'),): 6},
#  2: {(('Friday', 'mobile'), ('Friday', 'web')): 6,
#   (('Friday', 'mobile'), ('Monday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Monday', 'web')): 6,
#   (('Friday', 'mobile'), ('Saturday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Saturday', 'web')): 6,
#   (('Friday', 'mobile'), ('Sunday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Sunday', 'web')): 6,
#   (('Friday', 'mobile'), ('Thursday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'), ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Friday', 'web'), ('Monday', 'mobile')): 6,
#   (('Friday', 'web'), ('Monday', 'web')): 6,
#   (('Friday', 'web'), ('Saturday', 'mobile')): 6,
#   (('Friday', 'web'), ('Saturday', 'web')): 6,
#   (('Friday', 'web'), ('Sunday', 'mobile')): 6,
#   (('Friday', 'web'), ('Sunday', 'web')): 6,
#   (('Friday', 'web'), ('Thursday', 'mobile')): 6,
#   (('Friday', 'web'), ('Thursday', 'web')): 6,
#   (('Friday', 'web'), ('Tuesday', 'mobile')): 6,
#   (('Friday', 'web'), ('Tuesday', 'web')): 6,
#   (('Friday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Friday', 'web'), ('Wednesday', 'web')): 6,
#   (('Monday', 'mobile'), ('Monday', 'web')): 6,
#   (('Monday', 'mobile'), ('Saturday', 'mobile')): 6,
#   (('Monday', 'mobile'), ('Saturday', 'web')): 6,
#   (('Monday', 'mobile'), ('Sunday', 'mobile')): 6,
#   (('Monday', 'mobile'), ('Sunday', 'web')): 6,
#   (('Monday', 'mobile'), ('Thursday', 'mobile')): 6,
#   (('Monday', 'mobile'), ('Thursday', 'web')): 6,
#   (('Monday', 'mobile'), ('Tuesday', 'mobile')): 6,
#   (('Monday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Monday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Monday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Monday', 'web'), ('Saturday', 'mobile')): 6,
#   (('Monday', 'web'), ('Saturday', 'web')): 6,
#   (('Monday', 'web'), ('Sunday', 'mobile')): 6,
#   (('Monday', 'web'), ('Sunday', 'web')): 6,
#   (('Monday', 'web'), ('Thursday', 'mobile')): 6,
#   (('Monday', 'web'), ('Thursday', 'web')): 6,
#   (('Monday', 'web'), ('Tuesday', 'mobile')): 6,
#   (('Monday', 'web'), ('Tuesday', 'web')): 6,
#   (('Monday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Monday', 'web'), ('Wednesday', 'web')): 6,
#   (('Saturday', 'mobile'), ('Saturday', 'web')): 6,
#   (('Saturday', 'mobile'), ('Sunday', 'mobile')): 6,
#   (('Saturday', 'mobile'), ('Sunday', 'web')): 6,
#   (('Saturday', 'mobile'), ('Thursday', 'mobile')): 6,
#   (('Saturday', 'mobile'), ('Thursday', 'web')): 6,
#   (('Saturday', 'mobile'), ('Tuesday', 'mobile')): 6,
#   (('Saturday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Saturday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Saturday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Saturday', 'web'), ('Sunday', 'mobile')): 6,
#   (('Saturday', 'web'), ('Sunday', 'web')): 6,
#   (('Saturday', 'web'), ('Thursday', 'mobile')): 6,
#   (('Saturday', 'web'), ('Thursday', 'web')): 6,
#   (('Saturday', 'web'), ('Tuesday', 'mobile')): 6,
#   (('Saturday', 'web'), ('Tuesday', 'web')): 6,
#   (('Saturday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Saturday', 'web'), ('Wednesday', 'web')): 6,
#   (('Sunday', 'mobile'), ('Sunday', 'web')): 6,
#   (('Sunday', 'mobile'), ('Thursday', 'mobile')): 6,
#   (('Sunday', 'mobile'), ('Thursday', 'web')): 6,
#   (('Sunday', 'mobile'), ('Tuesday', 'mobile')): 6,
#   (('Sunday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Sunday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Sunday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Sunday', 'web'), ('Thursday', 'mobile')): 6,
#   (('Sunday', 'web'), ('Thursday', 'web')): 6,
#   (('Sunday', 'web'), ('Tuesday', 'mobile')): 6,
#   (('Sunday', 'web'), ('Tuesday', 'web')): 6,
#   (('Sunday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Sunday', 'web'), ('Wednesday', 'web')): 6,
#   (('Thursday', 'mobile'), ('Thursday', 'web')): 6,
#   (('Thursday', 'mobile'), ('Tuesday', 'mobile')): 6,
#   (('Thursday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Thursday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Thursday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Thursday', 'web'), ('Tuesday', 'mobile')): 6,
#   (('Thursday', 'web'), ('Tuesday', 'web')): 6,
#   (('Thursday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Thursday', 'web'), ('Wednesday', 'web')): 6,
#   (('Tuesday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Tuesday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Tuesday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Tuesday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Tuesday', 'web'), ('Wednesday', 'web')): 6,
#   (('Wednesday', 'mobile'), ('Wednesday', 'web')): 6},
#  3: {(('Friday', 'mobile'), ('Friday', 'web'), ('Monday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Friday', 'web'), ('Monday', 'web')): 6,
#   (('Friday', 'mobile'), ('Friday', 'web'), ('Saturday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Friday', 'web'), ('Saturday', 'web')): 6,
#   (('Friday', 'mobile'), ('Friday', 'web'), ('Sunday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Friday', 'web'), ('Sunday', 'web')): 6,
#   (('Friday', 'mobile'), ('Friday', 'web'), ('Thursday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Friday', 'web'), ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'), ('Friday', 'web'), ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Friday', 'web'), ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'), ('Friday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Friday', 'web'), ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'), ('Monday', 'mobile'), ('Monday', 'web')): 6,
#   (('Friday', 'mobile'), ('Monday', 'mobile'), ('Saturday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Monday', 'mobile'), ('Saturday', 'web')): 6,
#   (('Friday', 'mobile'), ('Monday', 'mobile'), ('Sunday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Monday', 'mobile'), ('Sunday', 'web')): 6,
#   (('Friday', 'mobile'), ('Monday', 'mobile'), ('Thursday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Monday', 'mobile'), ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'), ('Monday', 'mobile'), ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Monday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'), ('Monday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Monday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'), ('Monday', 'web'), ('Saturday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Monday', 'web'), ('Saturday', 'web')): 6,
#   (('Friday', 'mobile'), ('Monday', 'web'), ('Sunday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Monday', 'web'), ('Sunday', 'web')): 6,
#   (('Friday', 'mobile'), ('Monday', 'web'), ('Thursday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Monday', 'web'), ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'), ('Monday', 'web'), ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Monday', 'web'), ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'), ('Monday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Monday', 'web'), ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'), ('Saturday', 'mobile'), ('Saturday', 'web')): 6,
#   (('Friday', 'mobile'), ('Saturday', 'mobile'), ('Sunday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Saturday', 'mobile'), ('Sunday', 'web')): 6,
#   (('Friday', 'mobile'), ('Saturday', 'mobile'), ('Thursday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Saturday', 'mobile'), ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'), ('Saturday', 'mobile'), ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Saturday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'), ('Saturday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Saturday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'), ('Saturday', 'web'), ('Sunday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Saturday', 'web'), ('Sunday', 'web')): 6,
#   (('Friday', 'mobile'), ('Saturday', 'web'), ('Thursday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Saturday', 'web'), ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'), ('Saturday', 'web'), ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Saturday', 'web'), ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'), ('Saturday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Saturday', 'web'), ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'), ('Sunday', 'mobile'), ('Sunday', 'web')): 6,
#   (('Friday', 'mobile'), ('Sunday', 'mobile'), ('Thursday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Sunday', 'mobile'), ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'), ('Sunday', 'mobile'), ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Sunday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'), ('Sunday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Sunday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'), ('Sunday', 'web'), ('Thursday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Sunday', 'web'), ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'), ('Sunday', 'web'), ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Sunday', 'web'), ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'), ('Sunday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Sunday', 'web'), ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'), ('Thursday', 'mobile'), ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'), ('Thursday', 'mobile'), ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Thursday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'), ('Thursday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Thursday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'), ('Thursday', 'web'), ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Thursday', 'web'), ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'), ('Thursday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Thursday', 'web'), ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'), ('Tuesday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'), ('Tuesday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Tuesday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'), ('Tuesday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'), ('Tuesday', 'web'), ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'), ('Wednesday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Friday', 'web'), ('Monday', 'mobile'), ('Monday', 'web')): 6,
#   (('Friday', 'web'), ('Monday', 'mobile'), ('Saturday', 'mobile')): 6,
#   (('Friday', 'web'), ('Monday', 'mobile'), ('Saturday', 'web')): 6,
#   (('Friday', 'web'), ('Monday', 'mobile'), ('Sunday', 'mobile')): 6,
#   (('Friday', 'web'), ('Monday', 'mobile'), ('Sunday', 'web')): 6,
#   (('Friday', 'web'), ('Monday', 'mobile'), ('Thursday', 'mobile')): 6,
#   (('Friday', 'web'), ('Monday', 'mobile'), ('Thursday', 'web')): 6,
#   (('Friday', 'web'), ('Monday', 'mobile'), ('Tuesday', 'mobile')): 6,
#   (('Friday', 'web'), ('Monday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Friday', 'web'), ('Monday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Friday', 'web'), ('Monday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Friday', 'web'), ('Monday', 'web'), ('Saturday', 'mobile')): 6,
#   (('Friday', 'web'), ('Monday', 'web'), ('Saturday', 'web')): 6,
#   (('Friday', 'web'), ('Monday', 'web'), ('Sunday', 'mobile')): 6,
#   (('Friday', 'web'), ('Monday', 'web'), ('Sunday', 'web')): 6,
#   (('Friday', 'web'), ('Monday', 'web'), ('Thursday', 'mobile')): 6,
#   (('Friday', 'web'), ('Monday', 'web'), ('Thursday', 'web')): 6,
#   (('Friday', 'web'), ('Monday', 'web'), ('Tuesday', 'mobile')): 6,
#   (('Friday', 'web'), ('Monday', 'web'), ('Tuesday', 'web')): 6,
#   (('Friday', 'web'), ('Monday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Friday', 'web'), ('Monday', 'web'), ('Wednesday', 'web')): 6,
#   (('Friday', 'web'), ('Saturday', 'mobile'), ('Saturday', 'web')): 6,
#   (('Friday', 'web'), ('Saturday', 'mobile'), ('Sunday', 'mobile')): 6,
#   (('Friday', 'web'), ('Saturday', 'mobile'), ('Sunday', 'web')): 6,
#   (('Friday', 'web'), ('Saturday', 'mobile'), ('Thursday', 'mobile')): 6,
#   (('Friday', 'web'), ('Saturday', 'mobile'), ('Thursday', 'web')): 6,
#   (('Friday', 'web'), ('Saturday', 'mobile'), ('Tuesday', 'mobile')): 6,
#   (('Friday', 'web'), ('Saturday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Friday', 'web'), ('Saturday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Friday', 'web'), ('Saturday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Friday', 'web'), ('Saturday', 'web'), ('Sunday', 'mobile')): 6,
#   (('Friday', 'web'), ('Saturday', 'web'), ('Sunday', 'web')): 6,
#   (('Friday', 'web'), ('Saturday', 'web'), ('Thursday', 'mobile')): 6,
#   (('Friday', 'web'), ('Saturday', 'web'), ('Thursday', 'web')): 6,
#   (('Friday', 'web'), ('Saturday', 'web'), ('Tuesday', 'mobile')): 6,
#   (('Friday', 'web'), ('Saturday', 'web'), ('Tuesday', 'web')): 6,
#   (('Friday', 'web'), ('Saturday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Friday', 'web'), ('Saturday', 'web'), ('Wednesday', 'web')): 6,
#   (('Friday', 'web'), ('Sunday', 'mobile'), ('Sunday', 'web')): 6,
#   (('Friday', 'web'), ('Sunday', 'mobile'), ('Thursday', 'mobile')): 6,
#   (('Friday', 'web'), ('Sunday', 'mobile'), ('Thursday', 'web')): 6,
#   (('Friday', 'web'), ('Sunday', 'mobile'), ('Tuesday', 'mobile')): 6,
#   (('Friday', 'web'), ('Sunday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Friday', 'web'), ('Sunday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Friday', 'web'), ('Sunday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Friday', 'web'), ('Sunday', 'web'), ('Thursday', 'mobile')): 6,
#   (('Friday', 'web'), ('Sunday', 'web'), ('Thursday', 'web')): 6,
#   (('Friday', 'web'), ('Sunday', 'web'), ('Tuesday', 'mobile')): 6,
#   (('Friday', 'web'), ('Sunday', 'web'), ('Tuesday', 'web')): 6,
#   (('Friday', 'web'), ('Sunday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Friday', 'web'), ('Sunday', 'web'), ('Wednesday', 'web')): 6,
#   (('Friday', 'web'), ('Thursday', 'mobile'), ('Thursday', 'web')): 6,
#   (('Friday', 'web'), ('Thursday', 'mobile'), ('Tuesday', 'mobile')): 6,
#   (('Friday', 'web'), ('Thursday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Friday', 'web'), ('Thursday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Friday', 'web'), ('Thursday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Friday', 'web'), ('Thursday', 'web'), ('Tuesday', 'mobile')): 6,
#   (('Friday', 'web'), ('Thursday', 'web'), ('Tuesday', 'web')): 6,
#   (('Friday', 'web'), ('Thursday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Friday', 'web'), ('Thursday', 'web'), ('Wednesday', 'web')): 6,
#   (('Friday', 'web'), ('Tuesday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Friday', 'web'), ('Tuesday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Friday', 'web'), ('Tuesday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Friday', 'web'), ('Tuesday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Friday', 'web'), ('Tuesday', 'web'), ('Wednesday', 'web')): 6,
#   (('Friday', 'web'), ('Wednesday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Monday', 'mobile'), ('Monday', 'web'), ('Saturday', 'mobile')): 6,
#   (('Monday', 'mobile'), ('Monday', 'web'), ('Saturday', 'web')): 6,
#   (('Monday', 'mobile'), ('Monday', 'web'), ('Sunday', 'mobile')): 6,
#   (('Monday', 'mobile'), ('Monday', 'web'), ('Sunday', 'web')): 6,
#   (('Monday', 'mobile'), ('Monday', 'web'), ('Thursday', 'mobile')): 6,
#   (('Monday', 'mobile'), ('Monday', 'web'), ('Thursday', 'web')): 6,
#   (('Monday', 'mobile'), ('Monday', 'web'), ('Tuesday', 'mobile')): 6,
#   (('Monday', 'mobile'), ('Monday', 'web'), ('Tuesday', 'web')): 6,
#   (('Monday', 'mobile'), ('Monday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Monday', 'mobile'), ('Monday', 'web'), ('Wednesday', 'web')): 6,
#   (('Monday', 'mobile'), ('Saturday', 'mobile'), ('Saturday', 'web')): 6,
#   (('Monday', 'mobile'), ('Saturday', 'mobile'), ('Sunday', 'mobile')): 6,
#   (('Monday', 'mobile'), ('Saturday', 'mobile'), ('Sunday', 'web')): 6,
#   (('Monday', 'mobile'), ('Saturday', 'mobile'), ('Thursday', 'mobile')): 6,
#   (('Monday', 'mobile'), ('Saturday', 'mobile'), ('Thursday', 'web')): 6,
#   (('Monday', 'mobile'), ('Saturday', 'mobile'), ('Tuesday', 'mobile')): 6,
#   (('Monday', 'mobile'), ('Saturday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Monday', 'mobile'), ('Saturday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Monday', 'mobile'), ('Saturday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Monday', 'mobile'), ('Saturday', 'web'), ('Sunday', 'mobile')): 6,
#   (('Monday', 'mobile'), ('Saturday', 'web'), ('Sunday', 'web')): 6,
#   (('Monday', 'mobile'), ('Saturday', 'web'), ('Thursday', 'mobile')): 6,
#   (('Monday', 'mobile'), ('Saturday', 'web'), ('Thursday', 'web')): 6,
#   (('Monday', 'mobile'), ('Saturday', 'web'), ('Tuesday', 'mobile')): 6,
#   (('Monday', 'mobile'), ('Saturday', 'web'), ('Tuesday', 'web')): 6,
#   (('Monday', 'mobile'), ('Saturday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Monday', 'mobile'), ('Saturday', 'web'), ('Wednesday', 'web')): 6,
#   (('Monday', 'mobile'), ('Sunday', 'mobile'), ('Sunday', 'web')): 6,
#   (('Monday', 'mobile'), ('Sunday', 'mobile'), ('Thursday', 'mobile')): 6,
#   (('Monday', 'mobile'), ('Sunday', 'mobile'), ('Thursday', 'web')): 6,
#   (('Monday', 'mobile'), ('Sunday', 'mobile'), ('Tuesday', 'mobile')): 6,
#   (('Monday', 'mobile'), ('Sunday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Monday', 'mobile'), ('Sunday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Monday', 'mobile'), ('Sunday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Monday', 'mobile'), ('Sunday', 'web'), ('Thursday', 'mobile')): 6,
#   (('Monday', 'mobile'), ('Sunday', 'web'), ('Thursday', 'web')): 6,
#   (('Monday', 'mobile'), ('Sunday', 'web'), ('Tuesday', 'mobile')): 6,
#   (('Monday', 'mobile'), ('Sunday', 'web'), ('Tuesday', 'web')): 6,
#   (('Monday', 'mobile'), ('Sunday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Monday', 'mobile'), ('Sunday', 'web'), ('Wednesday', 'web')): 6,
#   (('Monday', 'mobile'), ('Thursday', 'mobile'), ('Thursday', 'web')): 6,
#   (('Monday', 'mobile'), ('Thursday', 'mobile'), ('Tuesday', 'mobile')): 6,
#   (('Monday', 'mobile'), ('Thursday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Monday', 'mobile'), ('Thursday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Monday', 'mobile'), ('Thursday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Monday', 'mobile'), ('Thursday', 'web'), ('Tuesday', 'mobile')): 6,
#   (('Monday', 'mobile'), ('Thursday', 'web'), ('Tuesday', 'web')): 6,
#   (('Monday', 'mobile'), ('Thursday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Monday', 'mobile'), ('Thursday', 'web'), ('Wednesday', 'web')): 6,
#   (('Monday', 'mobile'), ('Tuesday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Monday', 'mobile'), ('Tuesday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Monday', 'mobile'), ('Tuesday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Monday', 'mobile'), ('Tuesday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Monday', 'mobile'), ('Tuesday', 'web'), ('Wednesday', 'web')): 6,
#   (('Monday', 'mobile'), ('Wednesday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Monday', 'web'), ('Saturday', 'mobile'), ('Saturday', 'web')): 6,
#   (('Monday', 'web'), ('Saturday', 'mobile'), ('Sunday', 'mobile')): 6,
#   (('Monday', 'web'), ('Saturday', 'mobile'), ('Sunday', 'web')): 6,
#   (('Monday', 'web'), ('Saturday', 'mobile'), ('Thursday', 'mobile')): 6,
#   (('Monday', 'web'), ('Saturday', 'mobile'), ('Thursday', 'web')): 6,
#   (('Monday', 'web'), ('Saturday', 'mobile'), ('Tuesday', 'mobile')): 6,
#   (('Monday', 'web'), ('Saturday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Monday', 'web'), ('Saturday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Monday', 'web'), ('Saturday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Monday', 'web'), ('Saturday', 'web'), ('Sunday', 'mobile')): 6,
#   (('Monday', 'web'), ('Saturday', 'web'), ('Sunday', 'web')): 6,
#   (('Monday', 'web'), ('Saturday', 'web'), ('Thursday', 'mobile')): 6,
#   (('Monday', 'web'), ('Saturday', 'web'), ('Thursday', 'web')): 6,
#   (('Monday', 'web'), ('Saturday', 'web'), ('Tuesday', 'mobile')): 6,
#   (('Monday', 'web'), ('Saturday', 'web'), ('Tuesday', 'web')): 6,
#   (('Monday', 'web'), ('Saturday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Monday', 'web'), ('Saturday', 'web'), ('Wednesday', 'web')): 6,
#   (('Monday', 'web'), ('Sunday', 'mobile'), ('Sunday', 'web')): 6,
#   (('Monday', 'web'), ('Sunday', 'mobile'), ('Thursday', 'mobile')): 6,
#   (('Monday', 'web'), ('Sunday', 'mobile'), ('Thursday', 'web')): 6,
#   (('Monday', 'web'), ('Sunday', 'mobile'), ('Tuesday', 'mobile')): 6,
#   (('Monday', 'web'), ('Sunday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Monday', 'web'), ('Sunday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Monday', 'web'), ('Sunday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Monday', 'web'), ('Sunday', 'web'), ('Thursday', 'mobile')): 6,
#   (('Monday', 'web'), ('Sunday', 'web'), ('Thursday', 'web')): 6,
#   (('Monday', 'web'), ('Sunday', 'web'), ('Tuesday', 'mobile')): 6,
#   (('Monday', 'web'), ('Sunday', 'web'), ('Tuesday', 'web')): 6,
#   (('Monday', 'web'), ('Sunday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Monday', 'web'), ('Sunday', 'web'), ('Wednesday', 'web')): 6,
#   (('Monday', 'web'), ('Thursday', 'mobile'), ('Thursday', 'web')): 6,
#   (('Monday', 'web'), ('Thursday', 'mobile'), ('Tuesday', 'mobile')): 6,
#   (('Monday', 'web'), ('Thursday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Monday', 'web'), ('Thursday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Monday', 'web'), ('Thursday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Monday', 'web'), ('Thursday', 'web'), ('Tuesday', 'mobile')): 6,
#   (('Monday', 'web'), ('Thursday', 'web'), ('Tuesday', 'web')): 6,
#   (('Monday', 'web'), ('Thursday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Monday', 'web'), ('Thursday', 'web'), ('Wednesday', 'web')): 6,
#   (('Monday', 'web'), ('Tuesday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Monday', 'web'), ('Tuesday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Monday', 'web'), ('Tuesday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Monday', 'web'), ('Tuesday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Monday', 'web'), ('Tuesday', 'web'), ('Wednesday', 'web')): 6,
#   (('Monday', 'web'), ('Wednesday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Saturday', 'mobile'), ('Saturday', 'web'), ('Sunday', 'mobile')): 6,
#   (('Saturday', 'mobile'), ('Saturday', 'web'), ('Sunday', 'web')): 6,
#   (('Saturday', 'mobile'), ('Saturday', 'web'), ('Thursday', 'mobile')): 6,
#   (('Saturday', 'mobile'), ('Saturday', 'web'), ('Thursday', 'web')): 6,
#   (('Saturday', 'mobile'), ('Saturday', 'web'), ('Tuesday', 'mobile')): 6,
#   (('Saturday', 'mobile'), ('Saturday', 'web'), ('Tuesday', 'web')): 6,
#   (('Saturday', 'mobile'), ('Saturday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Saturday', 'mobile'), ('Saturday', 'web'), ('Wednesday', 'web')): 6,
#   (('Saturday', 'mobile'), ('Sunday', 'mobile'), ('Sunday', 'web')): 6,
#   (('Saturday', 'mobile'), ('Sunday', 'mobile'), ('Thursday', 'mobile')): 6,
#   (('Saturday', 'mobile'), ('Sunday', 'mobile'), ('Thursday', 'web')): 6,
#   (('Saturday', 'mobile'), ('Sunday', 'mobile'), ('Tuesday', 'mobile')): 6,
#   (('Saturday', 'mobile'), ('Sunday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Saturday', 'mobile'), ('Sunday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Saturday', 'mobile'), ('Sunday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Saturday', 'mobile'), ('Sunday', 'web'), ('Thursday', 'mobile')): 6,
#   (('Saturday', 'mobile'), ('Sunday', 'web'), ('Thursday', 'web')): 6,
#   (('Saturday', 'mobile'), ('Sunday', 'web'), ('Tuesday', 'mobile')): 6,
#   (('Saturday', 'mobile'), ('Sunday', 'web'), ('Tuesday', 'web')): 6,
#   (('Saturday', 'mobile'), ('Sunday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Saturday', 'mobile'), ('Sunday', 'web'), ('Wednesday', 'web')): 6,
#   (('Saturday', 'mobile'), ('Thursday', 'mobile'), ('Thursday', 'web')): 6,
#   (('Saturday', 'mobile'), ('Thursday', 'mobile'), ('Tuesday', 'mobile')): 6,
#   (('Saturday', 'mobile'), ('Thursday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Saturday', 'mobile'), ('Thursday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Saturday', 'mobile'), ('Thursday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Saturday', 'mobile'), ('Thursday', 'web'), ('Tuesday', 'mobile')): 6,
#   (('Saturday', 'mobile'), ('Thursday', 'web'), ('Tuesday', 'web')): 6,
#   (('Saturday', 'mobile'), ('Thursday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Saturday', 'mobile'), ('Thursday', 'web'), ('Wednesday', 'web')): 6,
#   (('Saturday', 'mobile'), ('Tuesday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Saturday', 'mobile'), ('Tuesday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Saturday', 'mobile'), ('Tuesday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Saturday', 'mobile'), ('Tuesday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Saturday', 'mobile'), ('Tuesday', 'web'), ('Wednesday', 'web')): 6,
#   (('Saturday', 'mobile'), ('Wednesday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Saturday', 'web'), ('Sunday', 'mobile'), ('Sunday', 'web')): 6,
#   (('Saturday', 'web'), ('Sunday', 'mobile'), ('Thursday', 'mobile')): 6,
#   (('Saturday', 'web'), ('Sunday', 'mobile'), ('Thursday', 'web')): 6,
#   (('Saturday', 'web'), ('Sunday', 'mobile'), ('Tuesday', 'mobile')): 6,
#   (('Saturday', 'web'), ('Sunday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Saturday', 'web'), ('Sunday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Saturday', 'web'), ('Sunday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Saturday', 'web'), ('Sunday', 'web'), ('Thursday', 'mobile')): 6,
#   (('Saturday', 'web'), ('Sunday', 'web'), ('Thursday', 'web')): 6,
#   (('Saturday', 'web'), ('Sunday', 'web'), ('Tuesday', 'mobile')): 6,
#   (('Saturday', 'web'), ('Sunday', 'web'), ('Tuesday', 'web')): 6,
#   (('Saturday', 'web'), ('Sunday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Saturday', 'web'), ('Sunday', 'web'), ('Wednesday', 'web')): 6,
#   (('Saturday', 'web'), ('Thursday', 'mobile'), ('Thursday', 'web')): 6,
#   (('Saturday', 'web'), ('Thursday', 'mobile'), ('Tuesday', 'mobile')): 6,
#   (('Saturday', 'web'), ('Thursday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Saturday', 'web'), ('Thursday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Saturday', 'web'), ('Thursday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Saturday', 'web'), ('Thursday', 'web'), ('Tuesday', 'mobile')): 6,
#   (('Saturday', 'web'), ('Thursday', 'web'), ('Tuesday', 'web')): 6,
#   (('Saturday', 'web'), ('Thursday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Saturday', 'web'), ('Thursday', 'web'), ('Wednesday', 'web')): 6,
#   (('Saturday', 'web'), ('Tuesday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Saturday', 'web'), ('Tuesday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Saturday', 'web'), ('Tuesday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Saturday', 'web'), ('Tuesday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Saturday', 'web'), ('Tuesday', 'web'), ('Wednesday', 'web')): 6,
#   (('Saturday', 'web'), ('Wednesday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Sunday', 'mobile'), ('Sunday', 'web'), ('Thursday', 'mobile')): 6,
#   (('Sunday', 'mobile'), ('Sunday', 'web'), ('Thursday', 'web')): 6,
#   (('Sunday', 'mobile'), ('Sunday', 'web'), ('Tuesday', 'mobile')): 6,
#   (('Sunday', 'mobile'), ('Sunday', 'web'), ('Tuesday', 'web')): 6,
#   (('Sunday', 'mobile'), ('Sunday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Sunday', 'mobile'), ('Sunday', 'web'), ('Wednesday', 'web')): 6,
#   (('Sunday', 'mobile'), ('Thursday', 'mobile'), ('Thursday', 'web')): 6,
#   (('Sunday', 'mobile'), ('Thursday', 'mobile'), ('Tuesday', 'mobile')): 6,
#   (('Sunday', 'mobile'), ('Thursday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Sunday', 'mobile'), ('Thursday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Sunday', 'mobile'), ('Thursday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Sunday', 'mobile'), ('Thursday', 'web'), ('Tuesday', 'mobile')): 6,
#   (('Sunday', 'mobile'), ('Thursday', 'web'), ('Tuesday', 'web')): 6,
#   (('Sunday', 'mobile'), ('Thursday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Sunday', 'mobile'), ('Thursday', 'web'), ('Wednesday', 'web')): 6,
#   (('Sunday', 'mobile'), ('Tuesday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Sunday', 'mobile'), ('Tuesday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Sunday', 'mobile'), ('Tuesday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Sunday', 'mobile'), ('Tuesday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Sunday', 'mobile'), ('Tuesday', 'web'), ('Wednesday', 'web')): 6,
#   (('Sunday', 'mobile'), ('Wednesday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Sunday', 'web'), ('Thursday', 'mobile'), ('Thursday', 'web')): 6,
#   (('Sunday', 'web'), ('Thursday', 'mobile'), ('Tuesday', 'mobile')): 6,
#   (('Sunday', 'web'), ('Thursday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Sunday', 'web'), ('Thursday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Sunday', 'web'), ('Thursday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Sunday', 'web'), ('Thursday', 'web'), ('Tuesday', 'mobile')): 6,
#   (('Sunday', 'web'), ('Thursday', 'web'), ('Tuesday', 'web')): 6,
#   (('Sunday', 'web'), ('Thursday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Sunday', 'web'), ('Thursday', 'web'), ('Wednesday', 'web')): 6,
#   (('Sunday', 'web'), ('Tuesday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Sunday', 'web'), ('Tuesday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Sunday', 'web'), ('Tuesday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Sunday', 'web'), ('Tuesday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Sunday', 'web'), ('Tuesday', 'web'), ('Wednesday', 'web')): 6,
#   (('Sunday', 'web'), ('Wednesday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Thursday', 'mobile'), ('Thursday', 'web'), ('Tuesday', 'mobile')): 6,
#   (('Thursday', 'mobile'), ('Thursday', 'web'), ('Tuesday', 'web')): 6,
#   (('Thursday', 'mobile'), ('Thursday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Thursday', 'mobile'), ('Thursday', 'web'), ('Wednesday', 'web')): 6,
#   (('Thursday', 'mobile'), ('Tuesday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Thursday', 'mobile'), ('Tuesday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Thursday', 'mobile'), ('Tuesday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Thursday', 'mobile'), ('Tuesday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Thursday', 'mobile'), ('Tuesday', 'web'), ('Wednesday', 'web')): 6,
#   (('Thursday', 'mobile'), ('Wednesday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Thursday', 'web'), ('Tuesday', 'mobile'), ('Tuesday', 'web')): 6,
#   (('Thursday', 'web'), ('Tuesday', 'mobile'), ('Wednesday', 'mobile')): 6,
#   (('Thursday', 'web'), ('Tuesday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Thursday', 'web'), ('Tuesday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Thursday', 'web'), ('Tuesday', 'web'), ('Wednesday', 'web')): 6,
#   (('Thursday', 'web'), ('Wednesday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Tuesday', 'mobile'), ('Tuesday', 'web'), ('Wednesday', 'mobile')): 6,
#   (('Tuesday', 'mobile'), ('Tuesday', 'web'), ('Wednesday', 'web')): 6,
#   (('Tuesday', 'mobile'), ('Wednesday', 'mobile'), ('Wednesday', 'web')): 6,
#   (('Tuesday', 'web'), ('Wednesday', 'mobile'), ('Wednesday', 'web')): 6},
#  4: {(('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Monday', 'mobile'),
#    ('Saturday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Monday', 'mobile'),
#    ('Saturday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Monday', 'mobile'),
#    ('Sunday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Monday', 'mobile'),
#    ('Sunday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Monday', 'mobile'),
#    ('Thursday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Monday', 'mobile'),
#    ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Monday', 'mobile'),
#    ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Monday', 'mobile'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Monday', 'mobile'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Monday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Monday', 'web'),
#    ('Saturday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Monday', 'web'),
#    ('Sunday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Monday', 'web'),
#    ('Sunday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Monday', 'web'),
#    ('Thursday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Monday', 'web'),
#    ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Monday', 'web'),
#    ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Monday', 'web'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Monday', 'web'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Monday', 'web'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Sunday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Sunday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Thursday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Saturday', 'web'),
#    ('Sunday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Saturday', 'web'),
#    ('Sunday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Saturday', 'web'),
#    ('Thursday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Saturday', 'web'),
#    ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Saturday', 'web'),
#    ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Saturday', 'web'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Saturday', 'web'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Saturday', 'web'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Sunday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Thursday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Sunday', 'web'),
#    ('Thursday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Sunday', 'web'),
#    ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Sunday', 'web'),
#    ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Sunday', 'web'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Sunday', 'web'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Sunday', 'web'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Thursday', 'web'),
#    ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Thursday', 'web'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Thursday', 'web'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Thursday', 'web'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Tuesday', 'mobile'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Tuesday', 'mobile'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Tuesday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Tuesday', 'web'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Tuesday', 'web'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Wednesday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Sunday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Sunday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Thursday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Saturday', 'mobile'),
#    ('Sunday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Saturday', 'mobile'),
#    ('Sunday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Saturday', 'mobile'),
#    ('Thursday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Saturday', 'mobile'),
#    ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Saturday', 'mobile'),
#    ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Saturday', 'mobile'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Saturday', 'mobile'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Saturday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Thursday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Sunday', 'mobile'),
#    ('Sunday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Sunday', 'mobile'),
#    ('Thursday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Sunday', 'mobile'),
#    ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Sunday', 'mobile'),
#    ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Sunday', 'mobile'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Sunday', 'mobile'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Sunday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Sunday', 'web'),
#    ('Thursday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Sunday', 'web'),
#    ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Sunday', 'web'),
#    ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Sunday', 'web'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Sunday', 'web'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Sunday', 'web'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Thursday', 'mobile'),
#    ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Thursday', 'mobile'),
#    ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Thursday', 'mobile'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Thursday', 'mobile'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Thursday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Thursday', 'web'),
#    ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Thursday', 'web'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Thursday', 'web'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Thursday', 'web'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Tuesday', 'mobile'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Tuesday', 'mobile'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Tuesday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Tuesday', 'web'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Tuesday', 'web'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Wednesday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Sunday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Sunday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Thursday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'web'),
#    ('Sunday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'web'),
#    ('Sunday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'web'),
#    ('Thursday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'web'),
#    ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'web'),
#    ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'web'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'web'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'web'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Sunday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Thursday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Sunday', 'web'),
#    ('Thursday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Sunday', 'web'),
#    ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Sunday', 'web'),
#    ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Sunday', 'web'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Sunday', 'web'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Sunday', 'web'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Thursday', 'web'),
#    ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Thursday', 'web'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Thursday', 'web'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Thursday', 'web'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Tuesday', 'mobile'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Tuesday', 'mobile'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Tuesday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Tuesday', 'web'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'web'),
#    ('Tuesday', 'web'),
#    ('Wednesday', 'web')): 6,
# ...
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Sunday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Tuesday', 'mobile'),
#    ('Tuesday', 'web'),
#    ('Wednesday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Sunday', 'web'),
#    ('Thursday', 'web'),
#    ('Tuesday', 'mobile'),
#    ('Tuesday', 'web'),
#    ('Wednesday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Friday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Thursday', 'web'),
#    ('Tuesday', 'mobile'),
#    ('Tuesday', 'web'),
#    ('Wednesday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Sunday', 'web'),
#    ('Thursday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Sunday', 'web'),
#    ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Sunday', 'web'),
#    ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Sunday', 'web'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Sunday', 'web'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Sunday', 'web'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Thursday', 'mobile'),
#    ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Thursday', 'mobile'),
#    ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Thursday', 'mobile'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Thursday', 'mobile'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Thursday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Thursday', 'web'),
#    ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Thursday', 'web'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Thursday', 'web'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Thursday', 'web'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Tuesday', 'mobile'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Tuesday', 'mobile'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Tuesday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Tuesday', 'web'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Tuesday', 'web'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'mobile'),
#    ('Wednesday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'web'),
#    ('Thursday', 'web'),
#    ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'web'),
#    ('Thursday', 'web'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'web'),
#    ('Thursday', 'web'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'web'),
#    ('Thursday', 'web'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'web'),
#    ('Tuesday', 'mobile'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'web'),
#    ('Tuesday', 'mobile'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'web'),
#    ('Tuesday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'web'),
#    ('Tuesday', 'web'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'web'),
#    ('Tuesday', 'web'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Sunday', 'web'),
#    ('Wednesday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Thursday', 'web'),
#    ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Thursday', 'web'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Thursday', 'web'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Thursday', 'web'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Tuesday', 'mobile'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Tuesday', 'mobile'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Tuesday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Tuesday', 'web'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Tuesday', 'web'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Wednesday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Thursday', 'web'),
#    ('Tuesday', 'mobile'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Thursday', 'web'),
#    ('Tuesday', 'mobile'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Thursday', 'web'),
#    ('Tuesday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Thursday', 'web'),
#    ('Tuesday', 'web'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Thursday', 'web'),
#    ('Tuesday', 'web'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Thursday', 'web'),
#    ('Wednesday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Tuesday', 'mobile'),
#    ('Tuesday', 'web'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Tuesday', 'mobile'),
#    ('Tuesday', 'web'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Tuesday', 'mobile'),
#    ('Wednesday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Saturday', 'web'),
#    ('Tuesday', 'web'),
#    ('Wednesday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Sunday', 'mobile'),
#    ('Sunday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Thursday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Sunday', 'mobile'),
#    ('Sunday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Sunday', 'mobile'),
#    ('Sunday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Sunday', 'mobile'),
#    ('Sunday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Sunday', 'mobile'),
#    ('Sunday', 'web'),
#    ('Thursday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Sunday', 'mobile'),
#    ('Sunday', 'web'),
#    ('Thursday', 'web'),
#    ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Sunday', 'mobile'),
#    ('Sunday', 'web'),
#    ('Thursday', 'web'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Sunday', 'mobile'),
#    ('Sunday', 'web'),
#    ('Thursday', 'web'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Sunday', 'mobile'),
#    ('Sunday', 'web'),
#    ('Thursday', 'web'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Sunday', 'mobile'),
#    ('Sunday', 'web'),
#    ('Tuesday', 'mobile'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Sunday', 'mobile'),
#    ('Sunday', 'web'),
#    ('Tuesday', 'mobile'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Sunday', 'mobile'),
#    ('Sunday', 'web'),
#    ('Tuesday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Sunday', 'mobile'),
#    ('Sunday', 'web'),
#    ('Tuesday', 'web'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Sunday', 'mobile'),
#    ('Sunday', 'web'),
#    ('Tuesday', 'web'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Sunday', 'mobile'),
#    ('Sunday', 'web'),
#    ('Wednesday', 'mobile'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Sunday', 'mobile'),
#    ('Thursday', 'mobile'),
#    ('Thursday', 'web'),
#    ('Tuesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Sunday', 'mobile'),
#    ('Thursday', 'mobile'),
#    ('Thursday', 'web'),
#    ('Tuesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Sunday', 'mobile'),
#    ('Thursday', 'mobile'),
#    ('Thursday', 'web'),
#    ('Wednesday', 'mobile')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Sunday', 'mobile'),
#    ('Thursday', 'mobile'),
#    ('Thursday', 'web'),
#    ('Wednesday', 'web')): 6,
#   (('Friday', 'mobile'),
#    ('Monday', 'mobile'),
#    ('Monday', 'web'),
#    ('Saturday', 'mobile'),
#    ('Sunday', 'mobile'),
#    ('Thursday', 'mobile'),
#    ('Tuesday', 'mobile'),
#    ('Tuesday', 'web')): 6,
#   ...}}

# %% [markdown]
# #	۴. استخراج الگوهای مکرر برای محصول و پلتفرم استفاده شده

# %%
groupby_product_platform = df.groupby(by = ['city'])
transactions_of_product_platform = []
for group, pdf in groupby_product_platform:
    transactions_of_product_platform.append(tuple(map(tuple,pdf[['cat1','platform']].values)))
transactions_of_product_platform
# Out:
# [(('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'web'),
#   ('personal', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'web'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'web'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('personal', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'web'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'web'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('businesses', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'web'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('businesses', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'web'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'web'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'web'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('for-the-home', 'web'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('businesses', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'web'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'web'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'web'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'web'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('businesses', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('businesses', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('businesses', 'mobile'),
#   ('businesses', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('electronic-devices', 'mobile'),
#   ('businesses', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'web'),
#   ('personal', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'web'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'web'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'web'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'web'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('businesses', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('vehicles', 'web'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'web'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'web'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('personal', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'web'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('businesses', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'web'),
#   ('businesses', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('personal', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'web'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('personal', 'mobile'),
#   ('businesses', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'web'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('businesses', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ...),
#  (('electronic-devices', 'mobile'),
#   ('businesses', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'web'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'web'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'web'),
#   ('for-the-home', 'web'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('businesses', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'web'),
#   ('leisure-hobbies', 'web'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'web'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'web'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'web'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'web'),
#   ('personal', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'web'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'web'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('businesses', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('businesses', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'web'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'web'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('businesses', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'web'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('businesses', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('personal', 'web'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'web'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('businesses', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('businesses', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'web'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'web'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'web'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('businesses', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'web'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('businesses', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'web'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('personal', 'mobile'),
#   ('personal', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'web'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('leisure-hobbies', 'web'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('businesses', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('businesses', 'web'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'web'),
#   ('leisure-hobbies', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('businesses', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'web'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'web'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'web'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('businesses', 'web'),
#   ('electronic-devices', 'web'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'web'),
#   ('personal', 'mobile'),
#   ('vehicles', 'web'),
#   ('vehicles', 'web'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('businesses', 'mobile'),
#   ('businesses', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'web'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'web'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'web'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('businesses', 'web'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('personal', 'web'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
# ...
#   ('personal', 'web'),
#   ('personal', 'web'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'mobile'),
#   ('personal', 'mobile'),
#   ('personal', 'web'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'web'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('personal', 'mobile'),
#   ('personal', 'mobile'),
#   ('businesses', 'web'),
#   ('for-the-home', 'web'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'web'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'mobile'),
#   ('vehicles', 'web'),
#   ('businesses', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('businesses', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'web'),
#   ('businesses', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'web'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'web'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'web'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'web'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'web'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'web'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'web'),
#   ('for-the-home', 'web'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'web'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('businesses', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'web'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('leisure-hobbies', 'web'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'web'),
#   ('leisure-hobbies', 'web'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'web'),
#   ('personal', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('businesses', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'web'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('personal', 'web'),
#   ('for-the-home', 'web'),
#   ('electronic-devices', 'web'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('businesses', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'web'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'web'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'web'),
#   ('vehicles', 'web'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'web'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'web'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'mobile'),
#   ('leisure-hobbies', 'web'),
#   ('leisure-hobbies', 'mobile'),
#   ('personal', 'web'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'web'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'web'),
#   ('vehicles', 'web'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('personal', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'web'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('leisure-hobbies', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('personal', 'web'),
#   ('for-the-home', 'mobile'),
#   ('businesses', 'web'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('businesses', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'web'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'mobile'),
#   ('personal', 'mobile'),
#   ('businesses', 'mobile'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('personal', 'web'),
#   ('electronic-devices', 'mobile'),
#   ('personal', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('leisure-hobbies', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('for-the-home', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('vehicles', 'mobile'),
#   ('electronic-devices', 'web'),
#   ('electronic-devices', 'web'),
#   ('for-the-home', 'mobile'),
#   ('for-the-home', 'web'),
#   ('for-the-home', 'mobile'),
#   ...)]

# %%
print(len(transactions_of_product_platform))
# Out:
# 9

# %%
transactionsProductPlatfrom = []
for tr in transactions_of_product_platform:
    if len(tr) > 1:
        transactionsProductPlatfrom.append(tr)
        
print("total transactions      : ", len(transactions_of_product_platform))
print("cleaning for finding FP : ", len(transactionsProductPlatfrom))
# Out:
# total transactions      :  9
# cleaning for finding FP :  9

# %%
itemsets, rules = apriori(transactionsProductPlatfrom,min_support=0.8, min_confidence=0.8)
itemsets
# Out:
# {1: {(('personal', 'web'),): 9,
#   (('leisure-hobbies', 'web'),): 9,
#   (('leisure-hobbies', 'mobile'),): 9,
#   (('businesses', 'web'),): 9,
#   (('vehicles', 'web'),): 9,
#   (('vehicles', 'mobile'),): 9,
#   (('for-the-home', 'web'),): 9,
#   (('for-the-home', 'mobile'),): 9,
#   (('electronic-devices', 'web'),): 9,
#   (('electronic-devices', 'mobile'),): 9,
#   (('businesses', 'mobile'),): 9,
#   (('personal', 'mobile'),): 9},
#  2: {(('businesses', 'mobile'), ('businesses', 'web')): 9,
#   (('businesses', 'mobile'), ('electronic-devices', 'mobile')): 9,
#   (('businesses', 'mobile'), ('electronic-devices', 'web')): 9,
#   (('businesses', 'mobile'), ('for-the-home', 'mobile')): 9,
#   (('businesses', 'mobile'), ('for-the-home', 'web')): 9,
#   (('businesses', 'mobile'), ('leisure-hobbies', 'mobile')): 9,
#   (('businesses', 'mobile'), ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'mobile'), ('personal', 'mobile')): 9,
#   (('businesses', 'mobile'), ('personal', 'web')): 9,
#   (('businesses', 'mobile'), ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'), ('vehicles', 'web')): 9,
#   (('businesses', 'web'), ('electronic-devices', 'mobile')): 9,
#   (('businesses', 'web'), ('electronic-devices', 'web')): 9,
#   (('businesses', 'web'), ('for-the-home', 'mobile')): 9,
#   (('businesses', 'web'), ('for-the-home', 'web')): 9,
#   (('businesses', 'web'), ('leisure-hobbies', 'mobile')): 9,
#   (('businesses', 'web'), ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'web'), ('personal', 'mobile')): 9,
#   (('businesses', 'web'), ('personal', 'web')): 9,
#   (('businesses', 'web'), ('vehicles', 'mobile')): 9,
#   (('businesses', 'web'), ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'), ('electronic-devices', 'web')): 9,
#   (('electronic-devices', 'mobile'), ('for-the-home', 'mobile')): 9,
#   (('electronic-devices', 'mobile'), ('for-the-home', 'web')): 9,
#   (('electronic-devices', 'mobile'), ('leisure-hobbies', 'mobile')): 9,
#   (('electronic-devices', 'mobile'), ('leisure-hobbies', 'web')): 9,
#   (('electronic-devices', 'mobile'), ('personal', 'mobile')): 9,
#   (('electronic-devices', 'mobile'), ('personal', 'web')): 9,
#   (('electronic-devices', 'mobile'), ('vehicles', 'mobile')): 9,
#   (('electronic-devices', 'mobile'), ('vehicles', 'web')): 9,
#   (('electronic-devices', 'web'), ('for-the-home', 'mobile')): 9,
#   (('electronic-devices', 'web'), ('for-the-home', 'web')): 9,
#   (('electronic-devices', 'web'), ('leisure-hobbies', 'mobile')): 9,
#   (('electronic-devices', 'web'), ('leisure-hobbies', 'web')): 9,
#   (('electronic-devices', 'web'), ('personal', 'mobile')): 9,
#   (('electronic-devices', 'web'), ('personal', 'web')): 9,
#   (('electronic-devices', 'web'), ('vehicles', 'mobile')): 9,
#   (('electronic-devices', 'web'), ('vehicles', 'web')): 9,
#   (('for-the-home', 'mobile'), ('for-the-home', 'web')): 9,
#   (('for-the-home', 'mobile'), ('leisure-hobbies', 'mobile')): 9,
#   (('for-the-home', 'mobile'), ('leisure-hobbies', 'web')): 9,
#   (('for-the-home', 'mobile'), ('personal', 'mobile')): 9,
#   (('for-the-home', 'mobile'), ('personal', 'web')): 9,
#   (('for-the-home', 'mobile'), ('vehicles', 'mobile')): 9,
#   (('for-the-home', 'mobile'), ('vehicles', 'web')): 9,
#   (('for-the-home', 'web'), ('leisure-hobbies', 'mobile')): 9,
#   (('for-the-home', 'web'), ('leisure-hobbies', 'web')): 9,
#   (('for-the-home', 'web'), ('personal', 'mobile')): 9,
#   (('for-the-home', 'web'), ('personal', 'web')): 9,
#   (('for-the-home', 'web'), ('vehicles', 'mobile')): 9,
#   (('for-the-home', 'web'), ('vehicles', 'web')): 9,
#   (('leisure-hobbies', 'mobile'), ('leisure-hobbies', 'web')): 9,
#   (('leisure-hobbies', 'mobile'), ('personal', 'mobile')): 9,
#   (('leisure-hobbies', 'mobile'), ('personal', 'web')): 9,
#   (('leisure-hobbies', 'mobile'), ('vehicles', 'mobile')): 9,
#   (('leisure-hobbies', 'mobile'), ('vehicles', 'web')): 9,
#   (('leisure-hobbies', 'web'), ('personal', 'mobile')): 9,
#   (('leisure-hobbies', 'web'), ('personal', 'web')): 9,
#   (('leisure-hobbies', 'web'), ('vehicles', 'mobile')): 9,
#   (('leisure-hobbies', 'web'), ('vehicles', 'web')): 9,
#   (('personal', 'mobile'), ('personal', 'web')): 9,
#   (('personal', 'mobile'), ('vehicles', 'mobile')): 9,
#   (('personal', 'mobile'), ('vehicles', 'web')): 9,
#   (('personal', 'web'), ('vehicles', 'mobile')): 9,
#   (('personal', 'web'), ('vehicles', 'web')): 9,
#   (('vehicles', 'mobile'), ('vehicles', 'web')): 9},
#  3: {(('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('electronic-devices', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('electronic-devices', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('for-the-home', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('for-the-home', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('leisure-hobbies', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'mobile'), ('businesses', 'web'), ('personal', 'mobile')): 9,
#   (('businesses', 'mobile'), ('businesses', 'web'), ('personal', 'web')): 9,
#   (('businesses', 'mobile'), ('businesses', 'web'), ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'), ('businesses', 'web'), ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('leisure-hobbies', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'web'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'mobile'), ('for-the-home', 'web'), ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'), ('for-the-home', 'web'), ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'), ('personal', 'mobile'), ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('personal', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'), ('personal', 'mobile'), ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'), ('personal', 'web'), ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'), ('personal', 'web'), ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'), ('vehicles', 'mobile'), ('vehicles', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'mobile')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('personal', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'web'),
#    ('leisure-hobbies', 'mobile')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'web'),
#    ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'web'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'web'),
#    ('personal', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'web'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web')): 9,
#   (('businesses', 'web'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile')): 9,
#   (('businesses', 'web'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'web'),
#    ('for-the-home', 'mobile'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'web'), ('for-the-home', 'mobile'), ('personal', 'web')): 9,
#   (('businesses', 'web'),
#    ('for-the-home', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'web'), ('for-the-home', 'mobile'), ('vehicles', 'web')): 9,
#   (('businesses', 'web'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile')): 9,
#   (('businesses', 'web'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'web'), ('for-the-home', 'web'), ('personal', 'mobile')): 9,
#   (('businesses', 'web'), ('for-the-home', 'web'), ('personal', 'web')): 9,
#   (('businesses', 'web'), ('for-the-home', 'web'), ('vehicles', 'mobile')): 9,
#   (('businesses', 'web'), ('for-the-home', 'web'), ('vehicles', 'web')): 9,
#   (('businesses', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'web')): 9,
#   (('businesses', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'web'), ('leisure-hobbies', 'web'), ('personal', 'web')): 9,
#   (('businesses', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'web'), ('leisure-hobbies', 'web'), ('vehicles', 'web')): 9,
#   (('businesses', 'web'), ('personal', 'mobile'), ('personal', 'web')): 9,
#   (('businesses', 'web'), ('personal', 'mobile'), ('vehicles', 'mobile')): 9,
#   (('businesses', 'web'), ('personal', 'mobile'), ('vehicles', 'web')): 9,
#   (('businesses', 'web'), ('personal', 'web'), ('vehicles', 'mobile')): 9,
#   (('businesses', 'web'), ('personal', 'web'), ('vehicles', 'web')): 9,
#   (('businesses', 'web'), ('vehicles', 'mobile'), ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('leisure-hobbies', 'mobile')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('leisure-hobbies', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('personal', 'mobile')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('personal', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile')): 9,
#   (('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('personal', 'mobile')): 9,
#   (('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('personal', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile')): 9,
#   (('electronic-devices', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('for-the-home', 'web'),
#    ('personal', 'mobile')): 9,
#   (('electronic-devices', 'mobile'),
#    ('for-the-home', 'web'),
#    ('personal', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('for-the-home', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('electronic-devices', 'mobile'),
#    ('for-the-home', 'web'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'mobile')): 9,
#   (('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile')): 9,
#   (('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('personal', 'mobile'),
#    ('personal', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('personal', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('electronic-devices', 'mobile'),
#    ('personal', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('electronic-devices', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web')): 9,
#   (('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile')): 9,
#   (('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'web')): 9,
#   (('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('personal', 'mobile')): 9,
#   (('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('personal', 'web')): 9,
#   (('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'web'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile')): 9,
#   (('electronic-devices', 'web'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'web')): 9,
#   (('electronic-devices', 'web'),
#    ('for-the-home', 'web'),
#    ('personal', 'mobile')): 9,
#   (('electronic-devices', 'web'),
#    ('for-the-home', 'web'),
#    ('personal', 'web')): 9,
#   (('electronic-devices', 'web'),
#    ('for-the-home', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('electronic-devices', 'web'),
#    ('for-the-home', 'web'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web')): 9,
#   (('electronic-devices', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'mobile')): 9,
#   (('electronic-devices', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'web')): 9,
#   (('electronic-devices', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('electronic-devices', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile')): 9,
#   (('electronic-devices', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'web')): 9,
#   (('electronic-devices', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('electronic-devices', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web')): 9,
#   (('electronic-devices', 'web'),
#    ('personal', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('electronic-devices', 'web'),
#    ('personal', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'web'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('electronic-devices', 'web'), ('personal', 'web'), ('vehicles', 'web')): 9,
#   (('electronic-devices', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile')): 9,
#   (('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'web')): 9,
#   (('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('personal', 'mobile')): 9,
#   (('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('personal', 'web')): 9,
#   (('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('vehicles', 'web')): 9,
#   (('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web')): 9,
#   (('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'mobile')): 9,
#   (('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'web')): 9,
#   (('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile')): 9,
#   (('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'web')): 9,
#   (('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('vehicles', 'web')): 9,
#   (('for-the-home', 'mobile'), ('personal', 'mobile'), ('personal', 'web')): 9,
#   (('for-the-home', 'mobile'),
#    ('personal', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('for-the-home', 'mobile'), ('personal', 'mobile'), ('vehicles', 'web')): 9,
#   (('for-the-home', 'mobile'), ('personal', 'web'), ('vehicles', 'mobile')): 9,
#   (('for-the-home', 'mobile'), ('personal', 'web'), ('vehicles', 'web')): 9,
#   (('for-the-home', 'mobile'), ('vehicles', 'mobile'), ('vehicles', 'web')): 9,
#   (('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web')): 9,
#   (('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'mobile')): 9,
#   (('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'web')): 9,
#   (('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('for-the-home', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile')): 9,
#   (('for-the-home', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'web')): 9,
#   (('for-the-home', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('for-the-home', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('vehicles', 'web')): 9,
#   (('for-the-home', 'web'), ('personal', 'mobile'), ('personal', 'web')): 9,
#   (('for-the-home', 'web'), ('personal', 'mobile'), ('vehicles', 'mobile')): 9,
#   (('for-the-home', 'web'), ('personal', 'mobile'), ('vehicles', 'web')): 9,
#   (('for-the-home', 'web'), ('personal', 'web'), ('vehicles', 'mobile')): 9,
#   (('for-the-home', 'web'), ('personal', 'web'), ('vehicles', 'web')): 9,
#   (('for-the-home', 'web'), ('vehicles', 'mobile'), ('vehicles', 'web')): 9,
#   (('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile')): 9,
#   (('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'web')): 9,
#   (('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('vehicles', 'web')): 9,
#   (('leisure-hobbies', 'mobile'),
#    ('personal', 'mobile'),
#    ('personal', 'web')): 9,
#   (('leisure-hobbies', 'mobile'),
#    ('personal', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('leisure-hobbies', 'mobile'),
#    ('personal', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('leisure-hobbies', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('leisure-hobbies', 'mobile'), ('personal', 'web'), ('vehicles', 'web')): 9,
#   (('leisure-hobbies', 'mobile'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('leisure-hobbies', 'web'), ('personal', 'mobile'), ('personal', 'web')): 9,
#   (('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('leisure-hobbies', 'web'), ('personal', 'mobile'), ('vehicles', 'web')): 9,
#   (('leisure-hobbies', 'web'), ('personal', 'web'), ('vehicles', 'mobile')): 9,
#   (('leisure-hobbies', 'web'), ('personal', 'web'), ('vehicles', 'web')): 9,
#   (('leisure-hobbies', 'web'), ('vehicles', 'mobile'), ('vehicles', 'web')): 9,
#   (('personal', 'mobile'), ('personal', 'web'), ('vehicles', 'mobile')): 9,
#   (('personal', 'mobile'), ('personal', 'web'), ('vehicles', 'web')): 9,
#   (('personal', 'mobile'), ('vehicles', 'mobile'), ('vehicles', 'web')): 9,
#   (('personal', 'web'), ('vehicles', 'mobile'), ('vehicles', 'web')): 9},
#  4: {(('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('electronic-devices', 'web'),
#    ('leisure-hobbies', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('electronic-devices', 'web'),
#    ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('electronic-devices', 'web'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('electronic-devices', 'web'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('electronic-devices', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('electronic-devices', 'web'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('for-the-home', 'mobile'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('for-the-home', 'mobile'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('for-the-home', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('for-the-home', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('for-the-home', 'web'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('for-the-home', 'web'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('for-the-home', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('for-the-home', 'web'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('personal', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('personal', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('personal', 'web'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('businesses', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('leisure-hobbies', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'web'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'web'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'web'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('personal', 'mobile'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('personal', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('personal', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'mobile'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'web'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'web'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'web'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('personal', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('personal', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('personal', 'web'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('personal', 'mobile'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('personal', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('personal', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'web'),
#    ('personal', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'web'),
#    ('personal', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'web'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'web'),
#    ('personal', 'web'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('for-the-home', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'mobile'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'web'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'mobile'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('personal', 'mobile'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('leisure-hobbies', 'mobile')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('personal', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('personal', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'web'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'web'),
#    ('personal', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('for-the-home', 'web'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'web'),
# ...
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'web'),
#    ('electronic-devices', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('businesses', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'web'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('businesses', 'web'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('vehicles', 'mobile')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'web'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'mobile'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('electronic-devices', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile')): 9,
#   (('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'web'),
#    ('for-the-home', 'mobile'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('electronic-devices', 'web'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9,
#   (('for-the-home', 'mobile'),
#    ('for-the-home', 'web'),
#    ('leisure-hobbies', 'mobile'),
#    ('leisure-hobbies', 'web'),
#    ('personal', 'mobile'),
#    ('personal', 'web'),
#    ('vehicles', 'mobile'),
#    ('vehicles', 'web')): 9}}

# %%
rules
# Out:
# [{('businesses', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile')} -> {('businesses', 'web')},
#  {('electronic-devices', 'mobile')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile')} -> {('electronic-devices', 'web')},
#  {('for-the-home', 'mobile')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile')} -> {('for-the-home', 'mobile')},
#  {('for-the-home', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile')} -> {('for-the-home', 'web')},
#  {('leisure-hobbies', 'mobile')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile')} -> {('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile')} -> {('leisure-hobbies', 'web')},
#  {('personal', 'mobile')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile')} -> {('personal', 'mobile')},
#  {('personal', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile')} -> {('personal', 'web')},
#  {('vehicles', 'mobile')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile')} -> {('vehicles', 'mobile')},
#  {('vehicles', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile')} -> {('vehicles', 'web')},
#  {('electronic-devices', 'mobile')} -> {('businesses', 'web')},
#  {('businesses', 'web')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'web')} -> {('businesses', 'web')},
#  {('businesses', 'web')} -> {('electronic-devices', 'web')},
#  {('for-the-home', 'mobile')} -> {('businesses', 'web')},
#  {('businesses', 'web')} -> {('for-the-home', 'mobile')},
#  {('for-the-home', 'web')} -> {('businesses', 'web')},
#  {('businesses', 'web')} -> {('for-the-home', 'web')},
#  {('leisure-hobbies', 'mobile')} -> {('businesses', 'web')},
#  {('businesses', 'web')} -> {('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'web')} -> {('businesses', 'web')},
#  {('businesses', 'web')} -> {('leisure-hobbies', 'web')},
#  {('personal', 'mobile')} -> {('businesses', 'web')},
#  {('businesses', 'web')} -> {('personal', 'mobile')},
#  {('personal', 'web')} -> {('businesses', 'web')},
#  {('businesses', 'web')} -> {('personal', 'web')},
#  {('vehicles', 'mobile')} -> {('businesses', 'web')},
#  {('businesses', 'web')} -> {('vehicles', 'mobile')},
#  {('vehicles', 'web')} -> {('businesses', 'web')},
#  {('businesses', 'web')} -> {('vehicles', 'web')},
#  {('electronic-devices', 'web')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('electronic-devices', 'web')},
#  {('for-the-home', 'mobile')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('for-the-home', 'mobile')},
#  {('for-the-home', 'web')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('for-the-home', 'web')},
#  {('leisure-hobbies', 'mobile')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'web')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('leisure-hobbies', 'web')},
#  {('personal', 'mobile')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('personal', 'mobile')},
#  {('personal', 'web')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('personal', 'web')},
#  {('vehicles', 'mobile')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('vehicles', 'mobile')},
#  {('vehicles', 'web')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('vehicles', 'web')},
#  {('for-the-home', 'mobile')} -> {('electronic-devices', 'web')},
#  {('electronic-devices', 'web')} -> {('for-the-home', 'mobile')},
#  {('for-the-home', 'web')} -> {('electronic-devices', 'web')},
#  {('electronic-devices', 'web')} -> {('for-the-home', 'web')},
#  {('leisure-hobbies', 'mobile')} -> {('electronic-devices', 'web')},
#  {('electronic-devices', 'web')} -> {('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'web')} -> {('electronic-devices', 'web')},
#  {('electronic-devices', 'web')} -> {('leisure-hobbies', 'web')},
#  {('personal', 'mobile')} -> {('electronic-devices', 'web')},
#  {('electronic-devices', 'web')} -> {('personal', 'mobile')},
#  {('personal', 'web')} -> {('electronic-devices', 'web')},
#  {('electronic-devices', 'web')} -> {('personal', 'web')},
#  {('vehicles', 'mobile')} -> {('electronic-devices', 'web')},
#  {('electronic-devices', 'web')} -> {('vehicles', 'mobile')},
#  {('vehicles', 'web')} -> {('electronic-devices', 'web')},
#  {('electronic-devices', 'web')} -> {('vehicles', 'web')},
#  {('for-the-home', 'web')} -> {('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('for-the-home', 'web')},
#  {('leisure-hobbies', 'mobile')} -> {('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'web')} -> {('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('leisure-hobbies', 'web')},
#  {('personal', 'mobile')} -> {('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('personal', 'mobile')},
#  {('personal', 'web')} -> {('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('personal', 'web')},
#  {('vehicles', 'mobile')} -> {('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('vehicles', 'mobile')},
#  {('vehicles', 'web')} -> {('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('vehicles', 'web')},
#  {('leisure-hobbies', 'mobile')} -> {('for-the-home', 'web')},
#  {('for-the-home', 'web')} -> {('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'web')} -> {('for-the-home', 'web')},
#  {('for-the-home', 'web')} -> {('leisure-hobbies', 'web')},
#  {('personal', 'mobile')} -> {('for-the-home', 'web')},
#  {('for-the-home', 'web')} -> {('personal', 'mobile')},
#  {('personal', 'web')} -> {('for-the-home', 'web')},
#  {('for-the-home', 'web')} -> {('personal', 'web')},
#  {('vehicles', 'mobile')} -> {('for-the-home', 'web')},
#  {('for-the-home', 'web')} -> {('vehicles', 'mobile')},
#  {('vehicles', 'web')} -> {('for-the-home', 'web')},
#  {('for-the-home', 'web')} -> {('vehicles', 'web')},
#  {('leisure-hobbies', 'web')} -> {('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'mobile')} -> {('leisure-hobbies', 'web')},
#  {('personal', 'mobile')} -> {('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'mobile')} -> {('personal', 'mobile')},
#  {('personal', 'web')} -> {('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'mobile')} -> {('personal', 'web')},
#  {('vehicles', 'mobile')} -> {('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'mobile')} -> {('vehicles', 'mobile')},
#  {('vehicles', 'web')} -> {('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'mobile')} -> {('vehicles', 'web')},
#  {('personal', 'mobile')} -> {('leisure-hobbies', 'web')},
#  {('leisure-hobbies', 'web')} -> {('personal', 'mobile')},
#  {('personal', 'web')} -> {('leisure-hobbies', 'web')},
#  {('leisure-hobbies', 'web')} -> {('personal', 'web')},
#  {('vehicles', 'mobile')} -> {('leisure-hobbies', 'web')},
#  {('leisure-hobbies', 'web')} -> {('vehicles', 'mobile')},
#  {('vehicles', 'web')} -> {('leisure-hobbies', 'web')},
#  {('leisure-hobbies', 'web')} -> {('vehicles', 'web')},
#  {('personal', 'web')} -> {('personal', 'mobile')},
#  {('personal', 'mobile')} -> {('personal', 'web')},
#  {('vehicles', 'mobile')} -> {('personal', 'mobile')},
#  {('personal', 'mobile')} -> {('vehicles', 'mobile')},
#  {('vehicles', 'web')} -> {('personal', 'mobile')},
#  {('personal', 'mobile')} -> {('vehicles', 'web')},
#  {('vehicles', 'mobile')} -> {('personal', 'web')},
#  {('personal', 'web')} -> {('vehicles', 'mobile')},
#  {('vehicles', 'web')} -> {('personal', 'web')},
#  {('personal', 'web')} -> {('vehicles', 'web')},
#  {('vehicles', 'web')} -> {('vehicles', 'mobile')},
#  {('vehicles', 'mobile')} -> {('vehicles', 'web')},
#  {('businesses', 'web'), ('electronic-devices', 'mobile')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('electronic-devices', 'mobile')} -> {('businesses', 'web')},
#  {('businesses', 'mobile'), ('businesses', 'web')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('businesses', 'mobile'), ('businesses', 'web')},
#  {('businesses', 'web')} -> {('businesses', 'mobile'), ('electronic-devices', 'mobile')},
#  {('businesses', 'mobile')} -> {('businesses', 'web'), ('electronic-devices', 'mobile')},
#  {('businesses', 'web'), ('electronic-devices', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('electronic-devices', 'web')} -> {('businesses', 'web')},
#  {('businesses', 'mobile'), ('businesses', 'web')} -> {('electronic-devices', 'web')},
#  {('electronic-devices', 'web')} -> {('businesses', 'mobile'), ('businesses', 'web')},
#  {('businesses', 'web')} -> {('businesses', 'mobile'), ('electronic-devices', 'web')},
#  {('businesses', 'mobile')} -> {('businesses', 'web'), ('electronic-devices', 'web')},
#  {('businesses', 'web'), ('for-the-home', 'mobile')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('for-the-home', 'mobile')} -> {('businesses', 'web')},
#  {('businesses', 'mobile'), ('businesses', 'web')} -> {('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('businesses', 'mobile'), ('businesses', 'web')},
#  {('businesses', 'web')} -> {('businesses', 'mobile'), ('for-the-home', 'mobile')},
#  {('businesses', 'mobile')} -> {('businesses', 'web'), ('for-the-home', 'mobile')},
#  {('businesses', 'web'), ('for-the-home', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('for-the-home', 'web')} -> {('businesses', 'web')},
#  {('businesses', 'mobile'), ('businesses', 'web')} -> {('for-the-home', 'web')},
#  {('for-the-home', 'web')} -> {('businesses', 'mobile'), ('businesses', 'web')},
#  {('businesses', 'web')} -> {('businesses', 'mobile'), ('for-the-home', 'web')},
#  {('businesses', 'mobile')} -> {('businesses', 'web'), ('for-the-home', 'web')},
#  {('businesses', 'web'), ('leisure-hobbies', 'mobile')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('leisure-hobbies', 'mobile')} -> {('businesses', 'web')},
#  {('businesses', 'mobile'), ('businesses', 'web')} -> {('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'mobile')} -> {('businesses', 'mobile'), ('businesses', 'web')},
#  {('businesses', 'web')} -> {('businesses', 'mobile'), ('leisure-hobbies', 'mobile')},
#  {('businesses', 'mobile')} -> {('businesses', 'web'), ('leisure-hobbies', 'mobile')},
#  {('businesses', 'web'), ('leisure-hobbies', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('leisure-hobbies', 'web')} -> {('businesses', 'web')},
#  {('businesses', 'mobile'), ('businesses', 'web')} -> {('leisure-hobbies', 'web')},
#  {('leisure-hobbies', 'web')} -> {('businesses', 'mobile'), ('businesses', 'web')},
#  {('businesses', 'web')} -> {('businesses', 'mobile'), ('leisure-hobbies', 'web')},
#  {('businesses', 'mobile')} -> {('businesses', 'web'), ('leisure-hobbies', 'web')},
#  {('businesses', 'web'), ('personal', 'mobile')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('personal', 'mobile')} -> {('businesses', 'web')},
#  {('businesses', 'mobile'), ('businesses', 'web')} -> {('personal', 'mobile')},
#  {('personal', 'mobile')} -> {('businesses', 'mobile'), ('businesses', 'web')},
#  {('businesses', 'web')} -> {('businesses', 'mobile'), ('personal', 'mobile')},
#  {('businesses', 'mobile')} -> {('businesses', 'web'), ('personal', 'mobile')},
#  {('businesses', 'web'), ('personal', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('personal', 'web')} -> {('businesses', 'web')},
#  {('businesses', 'mobile'), ('businesses', 'web')} -> {('personal', 'web')},
#  {('personal', 'web')} -> {('businesses', 'mobile'), ('businesses', 'web')},
#  {('businesses', 'web')} -> {('businesses', 'mobile'), ('personal', 'web')},
#  {('businesses', 'mobile')} -> {('businesses', 'web'), ('personal', 'web')},
#  {('businesses', 'web'), ('vehicles', 'mobile')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('vehicles', 'mobile')} -> {('businesses', 'web')},
#  {('businesses', 'mobile'), ('businesses', 'web')} -> {('vehicles', 'mobile')},
#  {('vehicles', 'mobile')} -> {('businesses', 'mobile'), ('businesses', 'web')},
#  {('businesses', 'web')} -> {('businesses', 'mobile'), ('vehicles', 'mobile')},
#  {('businesses', 'mobile')} -> {('businesses', 'web'), ('vehicles', 'mobile')},
#  {('businesses', 'web'), ('vehicles', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('vehicles', 'web')} -> {('businesses', 'web')},
#  {('businesses', 'mobile'), ('businesses', 'web')} -> {('vehicles', 'web')},
#  {('vehicles', 'web')} -> {('businesses', 'mobile'), ('businesses', 'web')},
#  {('businesses', 'web')} -> {('businesses', 'mobile'), ('vehicles', 'web')},
#  {('businesses', 'mobile')} -> {('businesses', 'web'), ('vehicles', 'web')},
#  {('electronic-devices', 'mobile'), ('electronic-devices', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('electronic-devices', 'web')} -> {('electronic-devices', 'mobile')},
#  {('businesses', 'mobile'), ('electronic-devices', 'mobile')} -> {('electronic-devices', 'web')},
#  {('electronic-devices', 'web')} -> {('businesses', 'mobile'), ('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('businesses', 'mobile'), ('electronic-devices', 'web')},
#  {('businesses', 'mobile')} -> {('electronic-devices', 'mobile'), ('electronic-devices', 'web')},
#  {('electronic-devices', 'mobile'), ('for-the-home', 'mobile')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('for-the-home', 'mobile')} -> {('electronic-devices', 'mobile')},
#  {('businesses', 'mobile'), ('electronic-devices', 'mobile')} -> {('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('businesses', 'mobile'), ('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('businesses', 'mobile'), ('for-the-home', 'mobile')},
#  {('businesses', 'mobile')} -> {('electronic-devices', 'mobile'), ('for-the-home', 'mobile')},
#  {('electronic-devices', 'mobile'), ('for-the-home', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('for-the-home', 'web')} -> {('electronic-devices', 'mobile')},
#  {('businesses', 'mobile'), ('electronic-devices', 'mobile')} -> {('for-the-home', 'web')},
#  {('for-the-home', 'web')} -> {('businesses', 'mobile'), ('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('businesses', 'mobile'), ('for-the-home', 'web')},
#  {('businesses', 'mobile')} -> {('electronic-devices', 'mobile'), ('for-the-home', 'web')},
#  {('electronic-devices', 'mobile'), ('leisure-hobbies', 'mobile')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('leisure-hobbies', 'mobile')} -> {('electronic-devices', 'mobile')},
#  {('businesses', 'mobile'), ('electronic-devices', 'mobile')} -> {('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'mobile')} -> {('businesses', 'mobile'), ('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('businesses', 'mobile'), ('leisure-hobbies', 'mobile')},
#  {('businesses', 'mobile')} -> {('electronic-devices', 'mobile'), ('leisure-hobbies', 'mobile')},
#  {('electronic-devices', 'mobile'), ('leisure-hobbies', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('leisure-hobbies', 'web')} -> {('electronic-devices', 'mobile')},
#  {('businesses', 'mobile'), ('electronic-devices', 'mobile')} -> {('leisure-hobbies', 'web')},
#  {('leisure-hobbies', 'web')} -> {('businesses', 'mobile'), ('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('businesses', 'mobile'), ('leisure-hobbies', 'web')},
#  {('businesses', 'mobile')} -> {('electronic-devices', 'mobile'), ('leisure-hobbies', 'web')},
#  {('electronic-devices', 'mobile'), ('personal', 'mobile')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('personal', 'mobile')} -> {('electronic-devices', 'mobile')},
#  {('businesses', 'mobile'), ('electronic-devices', 'mobile')} -> {('personal', 'mobile')},
#  {('personal', 'mobile')} -> {('businesses', 'mobile'), ('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('businesses', 'mobile'), ('personal', 'mobile')},
#  {('businesses', 'mobile')} -> {('electronic-devices', 'mobile'), ('personal', 'mobile')},
#  {('electronic-devices', 'mobile'), ('personal', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('personal', 'web')} -> {('electronic-devices', 'mobile')},
#  {('businesses', 'mobile'), ('electronic-devices', 'mobile')} -> {('personal', 'web')},
#  {('personal', 'web')} -> {('businesses', 'mobile'), ('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('businesses', 'mobile'), ('personal', 'web')},
#  {('businesses', 'mobile')} -> {('electronic-devices', 'mobile'), ('personal', 'web')},
#  {('electronic-devices', 'mobile'), ('vehicles', 'mobile')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('vehicles', 'mobile')} -> {('electronic-devices', 'mobile')},
#  {('businesses', 'mobile'), ('electronic-devices', 'mobile')} -> {('vehicles', 'mobile')},
#  {('vehicles', 'mobile')} -> {('businesses', 'mobile'), ('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('businesses', 'mobile'), ('vehicles', 'mobile')},
#  {('businesses', 'mobile')} -> {('electronic-devices', 'mobile'), ('vehicles', 'mobile')},
#  {('electronic-devices', 'mobile'), ('vehicles', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('vehicles', 'web')} -> {('electronic-devices', 'mobile')},
#  {('businesses', 'mobile'), ('electronic-devices', 'mobile')} -> {('vehicles', 'web')},
#  {('vehicles', 'web')} -> {('businesses', 'mobile'), ('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('businesses', 'mobile'), ('vehicles', 'web')},
#  {('businesses', 'mobile')} -> {('electronic-devices', 'mobile'), ('vehicles', 'web')},
#  {('electronic-devices', 'web'), ('for-the-home', 'mobile')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('for-the-home', 'mobile')} -> {('electronic-devices', 'web')},
#  {('businesses', 'mobile'), ('electronic-devices', 'web')} -> {('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('businesses', 'mobile'), ('electronic-devices', 'web')},
#  {('electronic-devices', 'web')} -> {('businesses', 'mobile'), ('for-the-home', 'mobile')},
#  {('businesses', 'mobile')} -> {('electronic-devices', 'web'), ('for-the-home', 'mobile')},
#  {('electronic-devices', 'web'), ('for-the-home', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('for-the-home', 'web')} -> {('electronic-devices', 'web')},
#  {('businesses', 'mobile'), ('electronic-devices', 'web')} -> {('for-the-home', 'web')},
#  {('for-the-home', 'web')} -> {('businesses', 'mobile'), ('electronic-devices', 'web')},
#  {('electronic-devices', 'web')} -> {('businesses', 'mobile'), ('for-the-home', 'web')},
#  {('businesses', 'mobile')} -> {('electronic-devices', 'web'), ('for-the-home', 'web')},
#  {('electronic-devices', 'web'), ('leisure-hobbies', 'mobile')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('leisure-hobbies', 'mobile')} -> {('electronic-devices', 'web')},
#  {('businesses', 'mobile'), ('electronic-devices', 'web')} -> {('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'mobile')} -> {('businesses', 'mobile'), ('electronic-devices', 'web')},
#  {('electronic-devices', 'web')} -> {('businesses', 'mobile'), ('leisure-hobbies', 'mobile')},
#  {('businesses', 'mobile')} -> {('electronic-devices', 'web'), ('leisure-hobbies', 'mobile')},
#  {('electronic-devices', 'web'), ('leisure-hobbies', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('leisure-hobbies', 'web')} -> {('electronic-devices', 'web')},
#  {('businesses', 'mobile'), ('electronic-devices', 'web')} -> {('leisure-hobbies', 'web')},
#  {('leisure-hobbies', 'web')} -> {('businesses', 'mobile'), ('electronic-devices', 'web')},
#  {('electronic-devices', 'web')} -> {('businesses', 'mobile'), ('leisure-hobbies', 'web')},
#  {('businesses', 'mobile')} -> {('electronic-devices', 'web'), ('leisure-hobbies', 'web')},
#  {('electronic-devices', 'web'), ('personal', 'mobile')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('personal', 'mobile')} -> {('electronic-devices', 'web')},
#  {('businesses', 'mobile'), ('electronic-devices', 'web')} -> {('personal', 'mobile')},
#  {('personal', 'mobile')} -> {('businesses', 'mobile'), ('electronic-devices', 'web')},
#  {('electronic-devices', 'web')} -> {('businesses', 'mobile'), ('personal', 'mobile')},
#  {('businesses', 'mobile')} -> {('electronic-devices', 'web'), ('personal', 'mobile')},
#  {('electronic-devices', 'web'), ('personal', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('personal', 'web')} -> {('electronic-devices', 'web')},
#  {('businesses', 'mobile'), ('electronic-devices', 'web')} -> {('personal', 'web')},
#  {('personal', 'web')} -> {('businesses', 'mobile'), ('electronic-devices', 'web')},
#  {('electronic-devices', 'web')} -> {('businesses', 'mobile'), ('personal', 'web')},
#  {('businesses', 'mobile')} -> {('electronic-devices', 'web'), ('personal', 'web')},
#  {('electronic-devices', 'web'), ('vehicles', 'mobile')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('vehicles', 'mobile')} -> {('electronic-devices', 'web')},
#  {('businesses', 'mobile'), ('electronic-devices', 'web')} -> {('vehicles', 'mobile')},
#  {('vehicles', 'mobile')} -> {('businesses', 'mobile'), ('electronic-devices', 'web')},
#  {('electronic-devices', 'web')} -> {('businesses', 'mobile'), ('vehicles', 'mobile')},
#  {('businesses', 'mobile')} -> {('electronic-devices', 'web'), ('vehicles', 'mobile')},
#  {('electronic-devices', 'web'), ('vehicles', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('vehicles', 'web')} -> {('electronic-devices', 'web')},
#  {('businesses', 'mobile'), ('electronic-devices', 'web')} -> {('vehicles', 'web')},
#  {('vehicles', 'web')} -> {('businesses', 'mobile'), ('electronic-devices', 'web')},
#  {('electronic-devices', 'web')} -> {('businesses', 'mobile'), ('vehicles', 'web')},
#  {('businesses', 'mobile')} -> {('electronic-devices', 'web'), ('vehicles', 'web')},
#  {('for-the-home', 'mobile'), ('for-the-home', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('for-the-home', 'web')} -> {('for-the-home', 'mobile')},
#  {('businesses', 'mobile'), ('for-the-home', 'mobile')} -> {('for-the-home', 'web')},
#  {('for-the-home', 'web')} -> {('businesses', 'mobile'), ('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('businesses', 'mobile'), ('for-the-home', 'web')},
#  {('businesses', 'mobile')} -> {('for-the-home', 'mobile'), ('for-the-home', 'web')},
#  {('for-the-home', 'mobile'), ('leisure-hobbies', 'mobile')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('leisure-hobbies', 'mobile')} -> {('for-the-home', 'mobile')},
#  {('businesses', 'mobile'), ('for-the-home', 'mobile')} -> {('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'mobile')} -> {('businesses', 'mobile'), ('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('businesses', 'mobile'), ('leisure-hobbies', 'mobile')},
#  {('businesses', 'mobile')} -> {('for-the-home', 'mobile'), ('leisure-hobbies', 'mobile')},
#  {('for-the-home', 'mobile'), ('leisure-hobbies', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('leisure-hobbies', 'web')} -> {('for-the-home', 'mobile')},
#  {('businesses', 'mobile'), ('for-the-home', 'mobile')} -> {('leisure-hobbies', 'web')},
#  {('leisure-hobbies', 'web')} -> {('businesses', 'mobile'), ('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('businesses', 'mobile'), ('leisure-hobbies', 'web')},
#  {('businesses', 'mobile')} -> {('for-the-home', 'mobile'), ('leisure-hobbies', 'web')},
#  {('for-the-home', 'mobile'), ('personal', 'mobile')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('personal', 'mobile')} -> {('for-the-home', 'mobile')},
#  {('businesses', 'mobile'), ('for-the-home', 'mobile')} -> {('personal', 'mobile')},
#  {('personal', 'mobile')} -> {('businesses', 'mobile'), ('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('businesses', 'mobile'), ('personal', 'mobile')},
#  {('businesses', 'mobile')} -> {('for-the-home', 'mobile'), ('personal', 'mobile')},
#  {('for-the-home', 'mobile'), ('personal', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('personal', 'web')} -> {('for-the-home', 'mobile')},
#  {('businesses', 'mobile'), ('for-the-home', 'mobile')} -> {('personal', 'web')},
#  {('personal', 'web')} -> {('businesses', 'mobile'), ('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('businesses', 'mobile'), ('personal', 'web')},
#  {('businesses', 'mobile')} -> {('for-the-home', 'mobile'), ('personal', 'web')},
#  {('for-the-home', 'mobile'), ('vehicles', 'mobile')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('vehicles', 'mobile')} -> {('for-the-home', 'mobile')},
#  {('businesses', 'mobile'), ('for-the-home', 'mobile')} -> {('vehicles', 'mobile')},
#  {('vehicles', 'mobile')} -> {('businesses', 'mobile'), ('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('businesses', 'mobile'), ('vehicles', 'mobile')},
#  {('businesses', 'mobile')} -> {('for-the-home', 'mobile'), ('vehicles', 'mobile')},
#  {('for-the-home', 'mobile'), ('vehicles', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('vehicles', 'web')} -> {('for-the-home', 'mobile')},
#  {('businesses', 'mobile'), ('for-the-home', 'mobile')} -> {('vehicles', 'web')},
#  {('vehicles', 'web')} -> {('businesses', 'mobile'), ('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('businesses', 'mobile'), ('vehicles', 'web')},
#  {('businesses', 'mobile')} -> {('for-the-home', 'mobile'), ('vehicles', 'web')},
#  {('for-the-home', 'web'), ('leisure-hobbies', 'mobile')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('leisure-hobbies', 'mobile')} -> {('for-the-home', 'web')},
#  {('businesses', 'mobile'), ('for-the-home', 'web')} -> {('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'mobile')} -> {('businesses', 'mobile'), ('for-the-home', 'web')},
#  {('for-the-home', 'web')} -> {('businesses', 'mobile'), ('leisure-hobbies', 'mobile')},
#  {('businesses', 'mobile')} -> {('for-the-home', 'web'), ('leisure-hobbies', 'mobile')},
#  {('for-the-home', 'web'), ('leisure-hobbies', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('leisure-hobbies', 'web')} -> {('for-the-home', 'web')},
#  {('businesses', 'mobile'), ('for-the-home', 'web')} -> {('leisure-hobbies', 'web')},
#  {('leisure-hobbies', 'web')} -> {('businesses', 'mobile'), ('for-the-home', 'web')},
#  {('for-the-home', 'web')} -> {('businesses', 'mobile'), ('leisure-hobbies', 'web')},
#  {('businesses', 'mobile')} -> {('for-the-home', 'web'), ('leisure-hobbies', 'web')},
#  {('for-the-home', 'web'), ('personal', 'mobile')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('personal', 'mobile')} -> {('for-the-home', 'web')},
#  {('businesses', 'mobile'), ('for-the-home', 'web')} -> {('personal', 'mobile')},
#  {('personal', 'mobile')} -> {('businesses', 'mobile'), ('for-the-home', 'web')},
#  {('for-the-home', 'web')} -> {('businesses', 'mobile'), ('personal', 'mobile')},
#  {('businesses', 'mobile')} -> {('for-the-home', 'web'), ('personal', 'mobile')},
#  {('for-the-home', 'web'), ('personal', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('personal', 'web')} -> {('for-the-home', 'web')},
#  {('businesses', 'mobile'), ('for-the-home', 'web')} -> {('personal', 'web')},
#  {('personal', 'web')} -> {('businesses', 'mobile'), ('for-the-home', 'web')},
#  {('for-the-home', 'web')} -> {('businesses', 'mobile'), ('personal', 'web')},
#  {('businesses', 'mobile')} -> {('for-the-home', 'web'), ('personal', 'web')},
#  {('for-the-home', 'web'), ('vehicles', 'mobile')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('vehicles', 'mobile')} -> {('for-the-home', 'web')},
#  {('businesses', 'mobile'), ('for-the-home', 'web')} -> {('vehicles', 'mobile')},
#  {('vehicles', 'mobile')} -> {('businesses', 'mobile'), ('for-the-home', 'web')},
#  {('for-the-home', 'web')} -> {('businesses', 'mobile'), ('vehicles', 'mobile')},
#  {('businesses', 'mobile')} -> {('for-the-home', 'web'), ('vehicles', 'mobile')},
#  {('for-the-home', 'web'), ('vehicles', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('vehicles', 'web')} -> {('for-the-home', 'web')},
#  {('businesses', 'mobile'), ('for-the-home', 'web')} -> {('vehicles', 'web')},
#  {('vehicles', 'web')} -> {('businesses', 'mobile'), ('for-the-home', 'web')},
#  {('for-the-home', 'web')} -> {('businesses', 'mobile'), ('vehicles', 'web')},
#  {('businesses', 'mobile')} -> {('for-the-home', 'web'), ('vehicles', 'web')},
#  {('leisure-hobbies', 'mobile'), ('leisure-hobbies', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('leisure-hobbies', 'web')} -> {('leisure-hobbies', 'mobile')},
#  {('businesses', 'mobile'), ('leisure-hobbies', 'mobile')} -> {('leisure-hobbies', 'web')},
#  {('leisure-hobbies', 'web')} -> {('businesses', 'mobile'), ('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'mobile')} -> {('businesses', 'mobile'), ('leisure-hobbies', 'web')},
#  {('businesses', 'mobile')} -> {('leisure-hobbies', 'mobile'), ('leisure-hobbies', 'web')},
#  {('leisure-hobbies', 'mobile'), ('personal', 'mobile')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('personal', 'mobile')} -> {('leisure-hobbies', 'mobile')},
#  {('businesses', 'mobile'), ('leisure-hobbies', 'mobile')} -> {('personal', 'mobile')},
#  {('personal', 'mobile')} -> {('businesses', 'mobile'), ('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'mobile')} -> {('businesses', 'mobile'), ('personal', 'mobile')},
#  {('businesses', 'mobile')} -> {('leisure-hobbies', 'mobile'), ('personal', 'mobile')},
#  {('leisure-hobbies', 'mobile'), ('personal', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('personal', 'web')} -> {('leisure-hobbies', 'mobile')},
#  {('businesses', 'mobile'), ('leisure-hobbies', 'mobile')} -> {('personal', 'web')},
#  {('personal', 'web')} -> {('businesses', 'mobile'), ('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'mobile')} -> {('businesses', 'mobile'), ('personal', 'web')},
#  {('businesses', 'mobile')} -> {('leisure-hobbies', 'mobile'), ('personal', 'web')},
#  {('leisure-hobbies', 'mobile'), ('vehicles', 'mobile')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('vehicles', 'mobile')} -> {('leisure-hobbies', 'mobile')},
#  {('businesses', 'mobile'), ('leisure-hobbies', 'mobile')} -> {('vehicles', 'mobile')},
#  {('vehicles', 'mobile')} -> {('businesses', 'mobile'), ('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'mobile')} -> {('businesses', 'mobile'), ('vehicles', 'mobile')},
#  {('businesses', 'mobile')} -> {('leisure-hobbies', 'mobile'), ('vehicles', 'mobile')},
#  {('leisure-hobbies', 'mobile'), ('vehicles', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('vehicles', 'web')} -> {('leisure-hobbies', 'mobile')},
#  {('businesses', 'mobile'), ('leisure-hobbies', 'mobile')} -> {('vehicles', 'web')},
#  {('vehicles', 'web')} -> {('businesses', 'mobile'), ('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'mobile')} -> {('businesses', 'mobile'), ('vehicles', 'web')},
#  {('businesses', 'mobile')} -> {('leisure-hobbies', 'mobile'), ('vehicles', 'web')},
#  {('leisure-hobbies', 'web'), ('personal', 'mobile')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('personal', 'mobile')} -> {('leisure-hobbies', 'web')},
#  {('businesses', 'mobile'), ('leisure-hobbies', 'web')} -> {('personal', 'mobile')},
#  {('personal', 'mobile')} -> {('businesses', 'mobile'), ('leisure-hobbies', 'web')},
#  {('leisure-hobbies', 'web')} -> {('businesses', 'mobile'), ('personal', 'mobile')},
#  {('businesses', 'mobile')} -> {('leisure-hobbies', 'web'), ('personal', 'mobile')},
#  {('leisure-hobbies', 'web'), ('personal', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('personal', 'web')} -> {('leisure-hobbies', 'web')},
#  {('businesses', 'mobile'), ('leisure-hobbies', 'web')} -> {('personal', 'web')},
#  {('personal', 'web')} -> {('businesses', 'mobile'), ('leisure-hobbies', 'web')},
#  {('leisure-hobbies', 'web')} -> {('businesses', 'mobile'), ('personal', 'web')},
#  {('businesses', 'mobile')} -> {('leisure-hobbies', 'web'), ('personal', 'web')},
#  {('leisure-hobbies', 'web'), ('vehicles', 'mobile')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('vehicles', 'mobile')} -> {('leisure-hobbies', 'web')},
#  {('businesses', 'mobile'), ('leisure-hobbies', 'web')} -> {('vehicles', 'mobile')},
#  {('vehicles', 'mobile')} -> {('businesses', 'mobile'), ('leisure-hobbies', 'web')},
#  {('leisure-hobbies', 'web')} -> {('businesses', 'mobile'), ('vehicles', 'mobile')},
#  {('businesses', 'mobile')} -> {('leisure-hobbies', 'web'), ('vehicles', 'mobile')},
#  {('leisure-hobbies', 'web'), ('vehicles', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('vehicles', 'web')} -> {('leisure-hobbies', 'web')},
#  {('businesses', 'mobile'), ('leisure-hobbies', 'web')} -> {('vehicles', 'web')},
#  {('vehicles', 'web')} -> {('businesses', 'mobile'), ('leisure-hobbies', 'web')},
#  {('leisure-hobbies', 'web')} -> {('businesses', 'mobile'), ('vehicles', 'web')},
#  {('businesses', 'mobile')} -> {('leisure-hobbies', 'web'), ('vehicles', 'web')},
#  {('personal', 'mobile'), ('personal', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('personal', 'web')} -> {('personal', 'mobile')},
#  {('businesses', 'mobile'), ('personal', 'mobile')} -> {('personal', 'web')},
#  {('personal', 'web')} -> {('businesses', 'mobile'), ('personal', 'mobile')},
#  {('personal', 'mobile')} -> {('businesses', 'mobile'), ('personal', 'web')},
#  {('businesses', 'mobile')} -> {('personal', 'mobile'), ('personal', 'web')},
#  {('personal', 'mobile'), ('vehicles', 'mobile')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('vehicles', 'mobile')} -> {('personal', 'mobile')},
#  {('businesses', 'mobile'), ('personal', 'mobile')} -> {('vehicles', 'mobile')},
#  {('vehicles', 'mobile')} -> {('businesses', 'mobile'), ('personal', 'mobile')},
#  {('personal', 'mobile')} -> {('businesses', 'mobile'), ('vehicles', 'mobile')},
#  {('businesses', 'mobile')} -> {('personal', 'mobile'), ('vehicles', 'mobile')},
#  {('personal', 'mobile'), ('vehicles', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('vehicles', 'web')} -> {('personal', 'mobile')},
#  {('businesses', 'mobile'), ('personal', 'mobile')} -> {('vehicles', 'web')},
#  {('vehicles', 'web')} -> {('businesses', 'mobile'), ('personal', 'mobile')},
#  {('personal', 'mobile')} -> {('businesses', 'mobile'), ('vehicles', 'web')},
#  {('businesses', 'mobile')} -> {('personal', 'mobile'), ('vehicles', 'web')},
#  {('personal', 'web'), ('vehicles', 'mobile')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('vehicles', 'mobile')} -> {('personal', 'web')},
#  {('businesses', 'mobile'), ('personal', 'web')} -> {('vehicles', 'mobile')},
#  {('vehicles', 'mobile')} -> {('businesses', 'mobile'), ('personal', 'web')},
#  {('personal', 'web')} -> {('businesses', 'mobile'), ('vehicles', 'mobile')},
#  {('businesses', 'mobile')} -> {('personal', 'web'), ('vehicles', 'mobile')},
#  {('personal', 'web'), ('vehicles', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('vehicles', 'web')} -> {('personal', 'web')},
#  {('businesses', 'mobile'), ('personal', 'web')} -> {('vehicles', 'web')},
#  {('vehicles', 'web')} -> {('businesses', 'mobile'), ('personal', 'web')},
#  {('personal', 'web')} -> {('businesses', 'mobile'), ('vehicles', 'web')},
#  {('businesses', 'mobile')} -> {('personal', 'web'), ('vehicles', 'web')},
#  {('vehicles', 'mobile'), ('vehicles', 'web')} -> {('businesses', 'mobile')},
#  {('businesses', 'mobile'), ('vehicles', 'web')} -> {('vehicles', 'mobile')},
#  {('businesses', 'mobile'), ('vehicles', 'mobile')} -> {('vehicles', 'web')},
#  {('vehicles', 'web')} -> {('businesses', 'mobile'), ('vehicles', 'mobile')},
#  {('vehicles', 'mobile')} -> {('businesses', 'mobile'), ('vehicles', 'web')},
#  {('businesses', 'mobile')} -> {('vehicles', 'mobile'), ('vehicles', 'web')},
#  {('electronic-devices', 'mobile'), ('electronic-devices', 'web')} -> {('businesses', 'web')},
#  {('businesses', 'web'), ('electronic-devices', 'web')} -> {('electronic-devices', 'mobile')},
#  {('businesses', 'web'), ('electronic-devices', 'mobile')} -> {('electronic-devices', 'web')},
#  {('electronic-devices', 'web')} -> {('businesses', 'web'), ('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('businesses', 'web'), ('electronic-devices', 'web')},
#  {('businesses', 'web')} -> {('electronic-devices', 'mobile'), ('electronic-devices', 'web')},
#  {('electronic-devices', 'mobile'), ('for-the-home', 'mobile')} -> {('businesses', 'web')},
#  {('businesses', 'web'), ('for-the-home', 'mobile')} -> {('electronic-devices', 'mobile')},
#  {('businesses', 'web'), ('electronic-devices', 'mobile')} -> {('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('businesses', 'web'), ('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('businesses', 'web'), ('for-the-home', 'mobile')},
#  {('businesses', 'web')} -> {('electronic-devices', 'mobile'), ('for-the-home', 'mobile')},
#  {('electronic-devices', 'mobile'), ('for-the-home', 'web')} -> {('businesses', 'web')},
#  {('businesses', 'web'), ('for-the-home', 'web')} -> {('electronic-devices', 'mobile')},
#  {('businesses', 'web'), ('electronic-devices', 'mobile')} -> {('for-the-home', 'web')},
#  {('for-the-home', 'web')} -> {('businesses', 'web'), ('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('businesses', 'web'), ('for-the-home', 'web')},
#  {('businesses', 'web')} -> {('electronic-devices', 'mobile'), ('for-the-home', 'web')},
#  {('electronic-devices', 'mobile'), ('leisure-hobbies', 'mobile')} -> {('businesses', 'web')},
#  {('businesses', 'web'), ('leisure-hobbies', 'mobile')} -> {('electronic-devices', 'mobile')},
#  {('businesses', 'web'), ('electronic-devices', 'mobile')} -> {('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'mobile')} -> {('businesses', 'web'), ('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('businesses', 'web'), ('leisure-hobbies', 'mobile')},
#  {('businesses', 'web')} -> {('electronic-devices', 'mobile'), ('leisure-hobbies', 'mobile')},
#  {('electronic-devices', 'mobile'), ('leisure-hobbies', 'web')} -> {('businesses', 'web')},
#  {('businesses', 'web'), ('leisure-hobbies', 'web')} -> {('electronic-devices', 'mobile')},
#  {('businesses', 'web'), ('electronic-devices', 'mobile')} -> {('leisure-hobbies', 'web')},
#  {('leisure-hobbies', 'web')} -> {('businesses', 'web'), ('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('businesses', 'web'), ('leisure-hobbies', 'web')},
#  {('businesses', 'web')} -> {('electronic-devices', 'mobile'), ('leisure-hobbies', 'web')},
#  {('electronic-devices', 'mobile'), ('personal', 'mobile')} -> {('businesses', 'web')},
#  {('businesses', 'web'), ('personal', 'mobile')} -> {('electronic-devices', 'mobile')},
#  {('businesses', 'web'), ('electronic-devices', 'mobile')} -> {('personal', 'mobile')},
#  {('personal', 'mobile')} -> {('businesses', 'web'), ('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('businesses', 'web'), ('personal', 'mobile')},
#  {('businesses', 'web')} -> {('electronic-devices', 'mobile'), ('personal', 'mobile')},
#  {('electronic-devices', 'mobile'), ('personal', 'web')} -> {('businesses', 'web')},
#  {('businesses', 'web'), ('personal', 'web')} -> {('electronic-devices', 'mobile')},
#  {('businesses', 'web'), ('electronic-devices', 'mobile')} -> {('personal', 'web')},
#  {('personal', 'web')} -> {('businesses', 'web'), ('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('businesses', 'web'), ('personal', 'web')},
#  {('businesses', 'web')} -> {('electronic-devices', 'mobile'), ('personal', 'web')},
#  {('electronic-devices', 'mobile'), ('vehicles', 'mobile')} -> {('businesses', 'web')},
#  {('businesses', 'web'), ('vehicles', 'mobile')} -> {('electronic-devices', 'mobile')},
#  {('businesses', 'web'), ('electronic-devices', 'mobile')} -> {('vehicles', 'mobile')},
#  {('vehicles', 'mobile')} -> {('businesses', 'web'), ('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('businesses', 'web'), ('vehicles', 'mobile')},
#  {('businesses', 'web')} -> {('electronic-devices', 'mobile'), ('vehicles', 'mobile')},
#  {('electronic-devices', 'mobile'), ('vehicles', 'web')} -> {('businesses', 'web')},
#  {('businesses', 'web'), ('vehicles', 'web')} -> {('electronic-devices', 'mobile')},
#  {('businesses', 'web'), ('electronic-devices', 'mobile')} -> {('vehicles', 'web')},
#  {('vehicles', 'web')} -> {('businesses', 'web'), ('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('businesses', 'web'), ('vehicles', 'web')},
#  {('businesses', 'web')} -> {('electronic-devices', 'mobile'), ('vehicles', 'web')},
#  {('electronic-devices', 'web'), ('for-the-home', 'mobile')} -> {('businesses', 'web')},
#  {('businesses', 'web'), ('for-the-home', 'mobile')} -> {('electronic-devices', 'web')},
#  {('businesses', 'web'), ('electronic-devices', 'web')} -> {('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('businesses', 'web'), ('electronic-devices', 'web')},
#  {('electronic-devices', 'web')} -> {('businesses', 'web'), ('for-the-home', 'mobile')},
#  {('businesses', 'web')} -> {('electronic-devices', 'web'), ('for-the-home', 'mobile')},
#  {('electronic-devices', 'web'), ('for-the-home', 'web')} -> {('businesses', 'web')},
#  {('businesses', 'web'), ('for-the-home', 'web')} -> {('electronic-devices', 'web')},
#  {('businesses', 'web'), ('electronic-devices', 'web')} -> {('for-the-home', 'web')},
#  {('for-the-home', 'web')} -> {('businesses', 'web'), ('electronic-devices', 'web')},
#  {('electronic-devices', 'web')} -> {('businesses', 'web'), ('for-the-home', 'web')},
#  {('businesses', 'web')} -> {('electronic-devices', 'web'), ('for-the-home', 'web')},
#  {('electronic-devices', 'web'), ('leisure-hobbies', 'mobile')} -> {('businesses', 'web')},
#  {('businesses', 'web'), ('leisure-hobbies', 'mobile')} -> {('electronic-devices', 'web')},
#  {('businesses', 'web'), ('electronic-devices', 'web')} -> {('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'mobile')} -> {('businesses', 'web'), ('electronic-devices', 'web')},
#  {('electronic-devices', 'web')} -> {('businesses', 'web'), ('leisure-hobbies', 'mobile')},
#  {('businesses', 'web')} -> {('electronic-devices', 'web'), ('leisure-hobbies', 'mobile')},
#  {('electronic-devices', 'web'), ('leisure-hobbies', 'web')} -> {('businesses', 'web')},
#  {('businesses', 'web'), ('leisure-hobbies', 'web')} -> {('electronic-devices', 'web')},
#  {('businesses', 'web'), ('electronic-devices', 'web')} -> {('leisure-hobbies', 'web')},
#  {('leisure-hobbies', 'web')} -> {('businesses', 'web'), ('electronic-devices', 'web')},
#  {('electronic-devices', 'web')} -> {('businesses', 'web'), ('leisure-hobbies', 'web')},
#  {('businesses', 'web')} -> {('electronic-devices', 'web'), ('leisure-hobbies', 'web')},
#  {('electronic-devices', 'web'), ('personal', 'mobile')} -> {('businesses', 'web')},
#  {('businesses', 'web'), ('personal', 'mobile')} -> {('electronic-devices', 'web')},
#  {('businesses', 'web'), ('electronic-devices', 'web')} -> {('personal', 'mobile')},
#  {('personal', 'mobile')} -> {('businesses', 'web'), ('electronic-devices', 'web')},
#  {('electronic-devices', 'web')} -> {('businesses', 'web'), ('personal', 'mobile')},
#  {('businesses', 'web')} -> {('electronic-devices', 'web'), ('personal', 'mobile')},
#  {('electronic-devices', 'web'), ('personal', 'web')} -> {('businesses', 'web')},
#  {('businesses', 'web'), ('personal', 'web')} -> {('electronic-devices', 'web')},
#  {('businesses', 'web'), ('electronic-devices', 'web')} -> {('personal', 'web')},
#  {('personal', 'web')} -> {('businesses', 'web'), ('electronic-devices', 'web')},
#  {('electronic-devices', 'web')} -> {('businesses', 'web'), ('personal', 'web')},
#  {('businesses', 'web')} -> {('electronic-devices', 'web'), ('personal', 'web')},
#  {('electronic-devices', 'web'), ('vehicles', 'mobile')} -> {('businesses', 'web')},
#  {('businesses', 'web'), ('vehicles', 'mobile')} -> {('electronic-devices', 'web')},
#  {('businesses', 'web'), ('electronic-devices', 'web')} -> {('vehicles', 'mobile')},
#  {('vehicles', 'mobile')} -> {('businesses', 'web'), ('electronic-devices', 'web')},
#  {('electronic-devices', 'web')} -> {('businesses', 'web'), ('vehicles', 'mobile')},
#  {('businesses', 'web')} -> {('electronic-devices', 'web'), ('vehicles', 'mobile')},
#  {('electronic-devices', 'web'), ('vehicles', 'web')} -> {('businesses', 'web')},
#  {('businesses', 'web'), ('vehicles', 'web')} -> {('electronic-devices', 'web')},
#  {('businesses', 'web'), ('electronic-devices', 'web')} -> {('vehicles', 'web')},
#  {('vehicles', 'web')} -> {('businesses', 'web'), ('electronic-devices', 'web')},
#  {('electronic-devices', 'web')} -> {('businesses', 'web'), ('vehicles', 'web')},
#  {('businesses', 'web')} -> {('electronic-devices', 'web'), ('vehicles', 'web')},
#  {('for-the-home', 'mobile'), ('for-the-home', 'web')} -> {('businesses', 'web')},
#  {('businesses', 'web'), ('for-the-home', 'web')} -> {('for-the-home', 'mobile')},
#  {('businesses', 'web'), ('for-the-home', 'mobile')} -> {('for-the-home', 'web')},
#  {('for-the-home', 'web')} -> {('businesses', 'web'), ('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('businesses', 'web'), ('for-the-home', 'web')},
#  {('businesses', 'web')} -> {('for-the-home', 'mobile'), ('for-the-home', 'web')},
#  {('for-the-home', 'mobile'), ('leisure-hobbies', 'mobile')} -> {('businesses', 'web')},
#  {('businesses', 'web'), ('leisure-hobbies', 'mobile')} -> {('for-the-home', 'mobile')},
#  {('businesses', 'web'), ('for-the-home', 'mobile')} -> {('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'mobile')} -> {('businesses', 'web'), ('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('businesses', 'web'), ('leisure-hobbies', 'mobile')},
#  {('businesses', 'web')} -> {('for-the-home', 'mobile'), ('leisure-hobbies', 'mobile')},
#  {('for-the-home', 'mobile'), ('leisure-hobbies', 'web')} -> {('businesses', 'web')},
#  {('businesses', 'web'), ('leisure-hobbies', 'web')} -> {('for-the-home', 'mobile')},
#  {('businesses', 'web'), ('for-the-home', 'mobile')} -> {('leisure-hobbies', 'web')},
#  {('leisure-hobbies', 'web')} -> {('businesses', 'web'), ('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('businesses', 'web'), ('leisure-hobbies', 'web')},
#  {('businesses', 'web')} -> {('for-the-home', 'mobile'), ('leisure-hobbies', 'web')},
#  {('for-the-home', 'mobile'), ('personal', 'mobile')} -> {('businesses', 'web')},
#  {('businesses', 'web'), ('personal', 'mobile')} -> {('for-the-home', 'mobile')},
#  {('businesses', 'web'), ('for-the-home', 'mobile')} -> {('personal', 'mobile')},
#  {('personal', 'mobile')} -> {('businesses', 'web'), ('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('businesses', 'web'), ('personal', 'mobile')},
#  {('businesses', 'web')} -> {('for-the-home', 'mobile'), ('personal', 'mobile')},
#  {('for-the-home', 'mobile'), ('personal', 'web')} -> {('businesses', 'web')},
#  {('businesses', 'web'), ('personal', 'web')} -> {('for-the-home', 'mobile')},
#  {('businesses', 'web'), ('for-the-home', 'mobile')} -> {('personal', 'web')},
#  {('personal', 'web')} -> {('businesses', 'web'), ('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('businesses', 'web'), ('personal', 'web')},
#  {('businesses', 'web')} -> {('for-the-home', 'mobile'), ('personal', 'web')},
#  {('for-the-home', 'mobile'), ('vehicles', 'mobile')} -> {('businesses', 'web')},
#  {('businesses', 'web'), ('vehicles', 'mobile')} -> {('for-the-home', 'mobile')},
#  {('businesses', 'web'), ('for-the-home', 'mobile')} -> {('vehicles', 'mobile')},
# ...
#  {('electronic-devices', 'mobile'), ('for-the-home', 'web')} -> {('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'mobile')} -> {('electronic-devices', 'mobile'), ('for-the-home', 'web')},
#  {('for-the-home', 'web')} -> {('electronic-devices', 'mobile'), ('leisure-hobbies', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('for-the-home', 'web'), ('leisure-hobbies', 'mobile')},
#  {('for-the-home', 'web'), ('leisure-hobbies', 'web')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile'), ('leisure-hobbies', 'web')} -> {('for-the-home', 'web')},
#  {('electronic-devices', 'mobile'), ('for-the-home', 'web')} -> {('leisure-hobbies', 'web')},
#  {('leisure-hobbies', 'web')} -> {('electronic-devices', 'mobile'), ('for-the-home', 'web')},
#  {('for-the-home', 'web')} -> {('electronic-devices', 'mobile'), ('leisure-hobbies', 'web')},
#  {('electronic-devices', 'mobile')} -> {('for-the-home', 'web'), ('leisure-hobbies', 'web')},
#  {('for-the-home', 'web'), ('personal', 'mobile')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile'), ('personal', 'mobile')} -> {('for-the-home', 'web')},
#  {('electronic-devices', 'mobile'), ('for-the-home', 'web')} -> {('personal', 'mobile')},
#  {('personal', 'mobile')} -> {('electronic-devices', 'mobile'), ('for-the-home', 'web')},
#  {('for-the-home', 'web')} -> {('electronic-devices', 'mobile'), ('personal', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('for-the-home', 'web'), ('personal', 'mobile')},
#  {('for-the-home', 'web'), ('personal', 'web')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile'), ('personal', 'web')} -> {('for-the-home', 'web')},
#  {('electronic-devices', 'mobile'), ('for-the-home', 'web')} -> {('personal', 'web')},
#  {('personal', 'web')} -> {('electronic-devices', 'mobile'), ('for-the-home', 'web')},
#  {('for-the-home', 'web')} -> {('electronic-devices', 'mobile'), ('personal', 'web')},
#  {('electronic-devices', 'mobile')} -> {('for-the-home', 'web'), ('personal', 'web')},
#  {('for-the-home', 'web'), ('vehicles', 'mobile')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile'), ('vehicles', 'mobile')} -> {('for-the-home', 'web')},
#  {('electronic-devices', 'mobile'), ('for-the-home', 'web')} -> {('vehicles', 'mobile')},
#  {('vehicles', 'mobile')} -> {('electronic-devices', 'mobile'), ('for-the-home', 'web')},
#  {('for-the-home', 'web')} -> {('electronic-devices', 'mobile'), ('vehicles', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('for-the-home', 'web'), ('vehicles', 'mobile')},
#  {('for-the-home', 'web'), ('vehicles', 'web')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile'), ('vehicles', 'web')} -> {('for-the-home', 'web')},
#  {('electronic-devices', 'mobile'), ('for-the-home', 'web')} -> {('vehicles', 'web')},
#  {('vehicles', 'web')} -> {('electronic-devices', 'mobile'), ('for-the-home', 'web')},
#  {('for-the-home', 'web')} -> {('electronic-devices', 'mobile'), ('vehicles', 'web')},
#  {('electronic-devices', 'mobile')} -> {('for-the-home', 'web'), ('vehicles', 'web')},
#  {('leisure-hobbies', 'mobile'), ('leisure-hobbies', 'web')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile'), ('leisure-hobbies', 'web')} -> {('leisure-hobbies', 'mobile')},
#  {('electronic-devices', 'mobile'), ('leisure-hobbies', 'mobile')} -> {('leisure-hobbies', 'web')},
#  {('leisure-hobbies', 'web')} -> {('electronic-devices', 'mobile'), ('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'mobile')} -> {('electronic-devices', 'mobile'), ('leisure-hobbies', 'web')},
#  {('electronic-devices', 'mobile')} -> {('leisure-hobbies', 'mobile'), ('leisure-hobbies', 'web')},
#  {('leisure-hobbies', 'mobile'), ('personal', 'mobile')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile'), ('personal', 'mobile')} -> {('leisure-hobbies', 'mobile')},
#  {('electronic-devices', 'mobile'), ('leisure-hobbies', 'mobile')} -> {('personal', 'mobile')},
#  {('personal', 'mobile')} -> {('electronic-devices', 'mobile'), ('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'mobile')} -> {('electronic-devices', 'mobile'), ('personal', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('leisure-hobbies', 'mobile'), ('personal', 'mobile')},
#  {('leisure-hobbies', 'mobile'), ('personal', 'web')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile'), ('personal', 'web')} -> {('leisure-hobbies', 'mobile')},
#  {('electronic-devices', 'mobile'), ('leisure-hobbies', 'mobile')} -> {('personal', 'web')},
#  {('personal', 'web')} -> {('electronic-devices', 'mobile'), ('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'mobile')} -> {('electronic-devices', 'mobile'), ('personal', 'web')},
#  {('electronic-devices', 'mobile')} -> {('leisure-hobbies', 'mobile'), ('personal', 'web')},
#  {('leisure-hobbies', 'mobile'), ('vehicles', 'mobile')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile'), ('vehicles', 'mobile')} -> {('leisure-hobbies', 'mobile')},
#  {('electronic-devices', 'mobile'), ('leisure-hobbies', 'mobile')} -> {('vehicles', 'mobile')},
#  {('vehicles', 'mobile')} -> {('electronic-devices', 'mobile'), ('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'mobile')} -> {('electronic-devices', 'mobile'), ('vehicles', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('leisure-hobbies', 'mobile'), ('vehicles', 'mobile')},
#  {('leisure-hobbies', 'mobile'), ('vehicles', 'web')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile'), ('vehicles', 'web')} -> {('leisure-hobbies', 'mobile')},
#  {('electronic-devices', 'mobile'), ('leisure-hobbies', 'mobile')} -> {('vehicles', 'web')},
#  {('vehicles', 'web')} -> {('electronic-devices', 'mobile'), ('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'mobile')} -> {('electronic-devices', 'mobile'), ('vehicles', 'web')},
#  {('electronic-devices', 'mobile')} -> {('leisure-hobbies', 'mobile'), ('vehicles', 'web')},
#  {('leisure-hobbies', 'web'), ('personal', 'mobile')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile'), ('personal', 'mobile')} -> {('leisure-hobbies', 'web')},
#  {('electronic-devices', 'mobile'), ('leisure-hobbies', 'web')} -> {('personal', 'mobile')},
#  {('personal', 'mobile')} -> {('electronic-devices', 'mobile'), ('leisure-hobbies', 'web')},
#  {('leisure-hobbies', 'web')} -> {('electronic-devices', 'mobile'), ('personal', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('leisure-hobbies', 'web'), ('personal', 'mobile')},
#  {('leisure-hobbies', 'web'), ('personal', 'web')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile'), ('personal', 'web')} -> {('leisure-hobbies', 'web')},
#  {('electronic-devices', 'mobile'), ('leisure-hobbies', 'web')} -> {('personal', 'web')},
#  {('personal', 'web')} -> {('electronic-devices', 'mobile'), ('leisure-hobbies', 'web')},
#  {('leisure-hobbies', 'web')} -> {('electronic-devices', 'mobile'), ('personal', 'web')},
#  {('electronic-devices', 'mobile')} -> {('leisure-hobbies', 'web'), ('personal', 'web')},
#  {('leisure-hobbies', 'web'), ('vehicles', 'mobile')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile'), ('vehicles', 'mobile')} -> {('leisure-hobbies', 'web')},
#  {('electronic-devices', 'mobile'), ('leisure-hobbies', 'web')} -> {('vehicles', 'mobile')},
#  {('vehicles', 'mobile')} -> {('electronic-devices', 'mobile'), ('leisure-hobbies', 'web')},
#  {('leisure-hobbies', 'web')} -> {('electronic-devices', 'mobile'), ('vehicles', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('leisure-hobbies', 'web'), ('vehicles', 'mobile')},
#  {('leisure-hobbies', 'web'), ('vehicles', 'web')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile'), ('vehicles', 'web')} -> {('leisure-hobbies', 'web')},
#  {('electronic-devices', 'mobile'), ('leisure-hobbies', 'web')} -> {('vehicles', 'web')},
#  {('vehicles', 'web')} -> {('electronic-devices', 'mobile'), ('leisure-hobbies', 'web')},
#  {('leisure-hobbies', 'web')} -> {('electronic-devices', 'mobile'), ('vehicles', 'web')},
#  {('electronic-devices', 'mobile')} -> {('leisure-hobbies', 'web'), ('vehicles', 'web')},
#  {('personal', 'mobile'), ('personal', 'web')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile'), ('personal', 'web')} -> {('personal', 'mobile')},
#  {('electronic-devices', 'mobile'), ('personal', 'mobile')} -> {('personal', 'web')},
#  {('personal', 'web')} -> {('electronic-devices', 'mobile'), ('personal', 'mobile')},
#  {('personal', 'mobile')} -> {('electronic-devices', 'mobile'), ('personal', 'web')},
#  {('electronic-devices', 'mobile')} -> {('personal', 'mobile'), ('personal', 'web')},
#  {('personal', 'mobile'), ('vehicles', 'mobile')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile'), ('vehicles', 'mobile')} -> {('personal', 'mobile')},
#  {('electronic-devices', 'mobile'), ('personal', 'mobile')} -> {('vehicles', 'mobile')},
#  {('vehicles', 'mobile')} -> {('electronic-devices', 'mobile'), ('personal', 'mobile')},
#  {('personal', 'mobile')} -> {('electronic-devices', 'mobile'), ('vehicles', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('personal', 'mobile'), ('vehicles', 'mobile')},
#  {('personal', 'mobile'), ('vehicles', 'web')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile'), ('vehicles', 'web')} -> {('personal', 'mobile')},
#  {('electronic-devices', 'mobile'), ('personal', 'mobile')} -> {('vehicles', 'web')},
#  {('vehicles', 'web')} -> {('electronic-devices', 'mobile'), ('personal', 'mobile')},
#  {('personal', 'mobile')} -> {('electronic-devices', 'mobile'), ('vehicles', 'web')},
#  {('electronic-devices', 'mobile')} -> {('personal', 'mobile'), ('vehicles', 'web')},
#  {('personal', 'web'), ('vehicles', 'mobile')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile'), ('vehicles', 'mobile')} -> {('personal', 'web')},
#  {('electronic-devices', 'mobile'), ('personal', 'web')} -> {('vehicles', 'mobile')},
#  {('vehicles', 'mobile')} -> {('electronic-devices', 'mobile'), ('personal', 'web')},
#  {('personal', 'web')} -> {('electronic-devices', 'mobile'), ('vehicles', 'mobile')},
#  {('electronic-devices', 'mobile')} -> {('personal', 'web'), ('vehicles', 'mobile')},
#  {('personal', 'web'), ('vehicles', 'web')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile'), ('vehicles', 'web')} -> {('personal', 'web')},
#  {('electronic-devices', 'mobile'), ('personal', 'web')} -> {('vehicles', 'web')},
#  {('vehicles', 'web')} -> {('electronic-devices', 'mobile'), ('personal', 'web')},
#  {('personal', 'web')} -> {('electronic-devices', 'mobile'), ('vehicles', 'web')},
#  {('electronic-devices', 'mobile')} -> {('personal', 'web'), ('vehicles', 'web')},
#  {('vehicles', 'mobile'), ('vehicles', 'web')} -> {('electronic-devices', 'mobile')},
#  {('electronic-devices', 'mobile'), ('vehicles', 'web')} -> {('vehicles', 'mobile')},
#  {('electronic-devices', 'mobile'), ('vehicles', 'mobile')} -> {('vehicles', 'web')},
#  {('vehicles', 'web')} -> {('electronic-devices', 'mobile'), ('vehicles', 'mobile')},
#  {('vehicles', 'mobile')} -> {('electronic-devices', 'mobile'), ('vehicles', 'web')},
#  {('electronic-devices', 'mobile')} -> {('vehicles', 'mobile'), ('vehicles', 'web')},
#  {('for-the-home', 'mobile'), ('for-the-home', 'web')} -> {('electronic-devices', 'web')},
#  {('electronic-devices', 'web'), ('for-the-home', 'web')} -> {('for-the-home', 'mobile')},
#  {('electronic-devices', 'web'), ('for-the-home', 'mobile')} -> {('for-the-home', 'web')},
#  {('for-the-home', 'web')} -> {('electronic-devices', 'web'), ('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('electronic-devices', 'web'), ('for-the-home', 'web')},
#  {('electronic-devices', 'web')} -> {('for-the-home', 'mobile'), ('for-the-home', 'web')},
#  {('for-the-home', 'mobile'), ('leisure-hobbies', 'mobile')} -> {('electronic-devices', 'web')},
#  {('electronic-devices', 'web'), ('leisure-hobbies', 'mobile')} -> {('for-the-home', 'mobile')},
#  {('electronic-devices', 'web'), ('for-the-home', 'mobile')} -> {('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'mobile')} -> {('electronic-devices', 'web'), ('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('electronic-devices', 'web'), ('leisure-hobbies', 'mobile')},
#  {('electronic-devices', 'web')} -> {('for-the-home', 'mobile'), ('leisure-hobbies', 'mobile')},
#  {('for-the-home', 'mobile'), ('leisure-hobbies', 'web')} -> {('electronic-devices', 'web')},
#  {('electronic-devices', 'web'), ('leisure-hobbies', 'web')} -> {('for-the-home', 'mobile')},
#  {('electronic-devices', 'web'), ('for-the-home', 'mobile')} -> {('leisure-hobbies', 'web')},
#  {('leisure-hobbies', 'web')} -> {('electronic-devices', 'web'), ('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('electronic-devices', 'web'), ('leisure-hobbies', 'web')},
#  {('electronic-devices', 'web')} -> {('for-the-home', 'mobile'), ('leisure-hobbies', 'web')},
#  {('for-the-home', 'mobile'), ('personal', 'mobile')} -> {('electronic-devices', 'web')},
#  {('electronic-devices', 'web'), ('personal', 'mobile')} -> {('for-the-home', 'mobile')},
#  {('electronic-devices', 'web'), ('for-the-home', 'mobile')} -> {('personal', 'mobile')},
#  {('personal', 'mobile')} -> {('electronic-devices', 'web'), ('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('electronic-devices', 'web'), ('personal', 'mobile')},
#  {('electronic-devices', 'web')} -> {('for-the-home', 'mobile'), ('personal', 'mobile')},
#  {('for-the-home', 'mobile'), ('personal', 'web')} -> {('electronic-devices', 'web')},
#  {('electronic-devices', 'web'), ('personal', 'web')} -> {('for-the-home', 'mobile')},
#  {('electronic-devices', 'web'), ('for-the-home', 'mobile')} -> {('personal', 'web')},
#  {('personal', 'web')} -> {('electronic-devices', 'web'), ('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('electronic-devices', 'web'), ('personal', 'web')},
#  {('electronic-devices', 'web')} -> {('for-the-home', 'mobile'), ('personal', 'web')},
#  {('for-the-home', 'mobile'), ('vehicles', 'mobile')} -> {('electronic-devices', 'web')},
#  {('electronic-devices', 'web'), ('vehicles', 'mobile')} -> {('for-the-home', 'mobile')},
#  {('electronic-devices', 'web'), ('for-the-home', 'mobile')} -> {('vehicles', 'mobile')},
#  {('vehicles', 'mobile')} -> {('electronic-devices', 'web'), ('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('electronic-devices', 'web'), ('vehicles', 'mobile')},
#  {('electronic-devices', 'web')} -> {('for-the-home', 'mobile'), ('vehicles', 'mobile')},
#  {('for-the-home', 'mobile'), ('vehicles', 'web')} -> {('electronic-devices', 'web')},
#  {('electronic-devices', 'web'), ('vehicles', 'web')} -> {('for-the-home', 'mobile')},
#  {('electronic-devices', 'web'), ('for-the-home', 'mobile')} -> {('vehicles', 'web')},
#  {('vehicles', 'web')} -> {('electronic-devices', 'web'), ('for-the-home', 'mobile')},
#  {('for-the-home', 'mobile')} -> {('electronic-devices', 'web'), ('vehicles', 'web')},
#  {('electronic-devices', 'web')} -> {('for-the-home', 'mobile'), ('vehicles', 'web')},
#  {('for-the-home', 'web'), ('leisure-hobbies', 'mobile')} -> {('electronic-devices', 'web')},
#  {('electronic-devices', 'web'), ('leisure-hobbies', 'mobile')} -> {('for-the-home', 'web')},
#  {('electronic-devices', 'web'), ('for-the-home', 'web')} -> {('leisure-hobbies', 'mobile')},
#  {('leisure-hobbies', 'mobile')} -> {('electronic-devices', 'web'), ('for-the-home', 'web')},
#  {('for-the-home', 'web')} -> {('electronic-devices', 'web'), ('leisure-hobbies', 'mobile')},
#  {('electronic-devices', 'web')} -> {('for-the-home', 'web'), ('leisure-hobbies', 'mobile')},
#  {('for-the-home', 'web'), ('leisure-hobbies', 'web')} -> {('electronic-devices', 'web')},
#  {('electronic-devices', 'web'), ('leisure-hobbies', 'web')} -> {('for-the-home', 'web')},
#  {('electronic-devices', 'web'), ('for-the-home', 'web')} -> {('leisure-hobbies', 'web')},
#  {('leisure-hobbies', 'web')} -> {('electronic-devices', 'web'), ('for-the-home', 'web')},
#  ...]
