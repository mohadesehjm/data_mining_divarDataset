# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv ("/Users/mohadeseh/Documents/me/session8/data_mining/FDM_Project_dataset-99-2/divar_dataset/divar_posts_dataset.csv")
df
# Out:
#         Unnamed: 0  archive_by_user                   brand  \
# 0                0            False                     NaN
# 1                1            False                     NaN
# 2                2            False                     NaN
# 3                3            False                     NaN
# 4                4            False                     NaN
# ...            ...              ...                     ...
# 947630      947630             True                     NaN
# 947631      947631             True                     NaN
# 947632      947632             True  پراید صندوق‌دار::Pride
# 947633      947633             True                     NaN
# 947634      947634             True                     NaN
#
#                       cat1                       cat2  \
# 0             for-the-home  furniture-and-home-decore
# 1             for-the-home  furniture-and-home-decore
# 2                 vehicles                       cars
# ...

# %% [markdown]
# # first method

# %%
df_records_without_null = df.dropna()
df_null_percentage_first_method = (df_records_without_null.shape[0]/df.shape[0])*100
df_null_percentage_first_method
# Out:
# 0.0

# %% [markdown]
# # second method

# %%
df_recods_price_city = df.loc[:,['title','brand','cat1','mileage','city','price']]
df_recods_price_city
# Out:
#                                     title                   brand  \
# 0             ست مبلمان و نهارخوری ٩ نفره                     NaN
# 1                        گلدون مصنوعی نخل                     NaN
# 2                     لودر کاتر پیلار 950                     NaN
# 3       مبل راحتی هفت نفره بامیز جلو مبلی                     NaN
# 4                             ماشین شارژی                     NaN
# ...                                   ...                     ...
# 947630               رادیاتور پنلی نو ترک                     NaN
# 947631               دوربین هندی کم  کنون                     NaN
# 947632         پراید دوگانه کارخانه مدل93  پراید صندوق‌دار::Pride
# 947633      مونوپد یانگ تد خیلی تمیز و نو                     NaN
# 947634                          ساعت مارک                     NaN
#
#                       cat1  mileage     city     price
# 0             for-the-home      NaN   Tehran   3850000
# 1             for-the-home      NaN  Mashhad     30000
# ...

# %%
df_recods_price_city_mileage_withoutnull = df_recods_price_city.dropna()
df_recods_price_city_mileage_method2 = (df_recods_price_city_mileage_withoutnull.shape[0]/df_recods_price_city.shape[0])*100
df_recods_price_city_mileage_method2
# Out:
# 12.710695573717729

# %% [markdown]
# # third method

# %%
df_field_containing_values = df.notnull().sum().sum()
df_all_datas = df.shape[0] * df.shape[1]
df_att_containing_values_third_method = (df_field_containing_values / df_all_datas)*100
df_att_containing_values_third_method
# Out:
# 78.68185783866275
